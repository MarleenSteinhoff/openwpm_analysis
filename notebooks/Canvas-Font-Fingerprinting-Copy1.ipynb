# %% [markdown]
# # Canvas-Font Fingerprinting detection
# - Based on https://github.com/mozilla/openwpm-crawler/blob/master/analysis/Sample%20Analysis.ipynb
# - See our 2016 study for background on Canvas-Font Fingerprinting: https://webtransparency.cs.princeton.edu/webcensus/#canvas-font-fp

# %%
import re
import json
import sqlite3
import pandas as pd

# %%
# import some analysis utilities from https://github.com/englehardt/crawl_utils
import sys
sys.path.append('./crawl_utils/')
import domain_utils as du
import analysis_utils as au

# %%
# use the sample sqlite for the 2018-06 stateless crawl
DB = '/home/marleensteinhoff/UNi/Projektseminar/Datenanalyse/sample_2018-06_1m_stateless_census_crawl.sqlite'
con = sqlite3.connect(DB)
con.row_factory = sqlite3.Row

# %% [markdown]
# ### Load JavaScript Calls

# %%
js = pd.read_sql_query("SELECT * FROM javascript", con)
print("Number of javascript calls", len(js))
# Out:
# Number of javascript calls 501207

# %%
# Add the public suffix + 1 of a bunch of the URL columns
js['script_ps1'] = js['script_url'].apply(lambda x: du.get_ps_plus_1(x) if x is not None else None)
js['top_ps1'] = js['top_level_url'].apply(lambda x: du.get_ps_plus_1(x) if x is not None else None)
js['document_ps1'] = js['document_url'].apply(lambda x: du.get_ps_plus_1(x) if x is not None else None)

# %% [markdown]
# #### Canvas function calls
#
# Filter JS calls and inspect for the use of canvas font fingerprinting

# %%
js[
    (js.symbol == 'CanvasRenderingContext2D.measureText') &
    (js.script_ps1 != js.top_ps1)
].groupby('script_ps1').top_ps1.count().sort_values(ascending=False)
# Out:
# script_ps1
# mathtag.com                      2000
# cloudflare.com                    295
# musthird.com                      174
# walmartimages.com                 102
# targetimg1.com                     95
# jrjimg.cn                          88
# d309knd7es5f10.cloudfront.net      30
# cdn-apple.com                      27
# js                                 26
# sndcdn.com                          2
# boxcdn.net                          1
# cdn-net.com                         1
# cdnst.net                           1
# Name: top_ps1, dtype: int64

# %%
font_shorthand = re.compile(r"^\s*(?=(?:(?:[-a-z]+\s*){0,2}(italic|oblique))?)(?=(?:(?:[-a-z]+\s*){0,2}(small-caps))?)(?=(?:(?:[-a-z]+\s*){0,2}(bold(?:er)?|lighter|[1-9]00))?)(?:(?:normal|\1|\2|\3)\s*){0,3}((?:xx?-)?(?:small|large)|medium|smaller|larger|[.\d]+(?:\%|in|[cem]m|ex|p[ctx]))(?:\s*\/\s*(normal|[.\d]+(?:\%|in|[cem]m|ex|p[ctx])))?\s*([-_\{\}\(\)\&!\',\*\.\"\sa-zA-Z0-9]+?)\s*$")

# %%
js[
    (js.symbol == 'CanvasRenderingContext2D.measureText') &
    (js.script_ps1 != js.top_ps1) & 
    (js.script_ps1 == 'mathtag.com')
].arguments.apply(lambda x: json.loads(x)["0"]).unique()
# Out:
# array(['mmmmmmmmmmlli'], dtype=object)

# %%
js[
    (js.symbol == 'CanvasRenderingContext2D.font') &
    (js.script_ps1 != js.top_ps1) & 
    (js.script_ps1 == 'mathtag.com')
].value.apply(lambda x: re.match(font_shorthand, x).group(6)).unique()
# Out:
# array(['monospace', 'sans-serif', 'serif', 'AR DARLING,monospace',
#        'AR DARLING,sans-serif', 'AR DARLING,serif',
#        'Earwig Factory,monospace', 'Earwig Factory,sans-serif',
#        'Earwig Factory,serif', 'Minya Nouvelle,monospace',
#        'Minya Nouvelle,sans-serif', 'Minya Nouvelle,serif',
#        'Burnstown Dam,monospace', 'Burnstown Dam,sans-serif',
#        'Burnstown Dam,serif', 'Sybil Green,monospace',
#        'Sybil Green,sans-serif', 'Sybil Green,serif',
#        'Stereofidelic,monospace', 'Stereofidelic,sans-serif',
#        'Stereofidelic,serif', 'Urdu Typesetting,monospace',
#        'Urdu Typesetting,sans-serif', 'Urdu Typesetting,serif',
#        'Blue Highway Linocut,monospace',
#        'Blue Highway Linocut,sans-serif', 'Blue Highway Linocut,serif',
#        'Credit Valley,monospace', 'Credit Valley,sans-serif',
#        'Credit Valley,serif', 'Velvenda Cooler,monospace',
#        'Velvenda Cooler,sans-serif', 'Velvenda Cooler,serif',
#        'Mufferaw,monospace', 'Mufferaw,sans-serif', 'Mufferaw,serif',
#        'Huxtable,monospace', 'Huxtable,sans-serif', 'Huxtable,serif',
#        'Boopee,monospace', 'Boopee,sans-serif', 'Boopee,serif',
#        'Kefa,monospace', 'Kefa,sans-serif', 'Kefa,serif',
#        'Nanum Myeongjo,monospace', 'Nanum Myeongjo,sans-serif',
#        'Nanum Myeongjo,serif', 'LuzSans-Book,monospace',
#        'LuzSans-Book,sans-serif', 'LuzSans-Book,serif',
#        'Castro Script PERSONAL USE ONLY,monospace',
#        'Castro Script PERSONAL USE ONLY,sans-serif',
#        'Castro Script PERSONAL USE ONLY,serif', '8514oem,monospace',
#        '8514oem,sans-serif', '8514oem,serif',
#        'Gentium Book Basic,monospace', 'Gentium Book Basic,sans-serif',
#        'Gentium Book Basic,serif', 'Sitka Subheading,monospace',
#        'Sitka Subheading,sans-serif', 'Sitka Subheading,serif',
#        'Mishafi,monospace', 'Mishafi,sans-serif', 'Mishafi,serif',
#        'Wickenden Cafe NDP,monospace', 'Wickenden Cafe NDP,sans-serif',
#        'Wickenden Cafe NDP,serif', 'Jenna Sue,monospace',
#        'Jenna Sue,sans-serif', 'Jenna Sue,serif', 'Symusic,monospace',
#        'Symusic,sans-serif', 'Symusic,serif', 'Monotxt,monospace',
#        'Monotxt,sans-serif', 'Monotxt,serif', 'CG Omega,monospace',
#        'CG Omega,sans-serif', 'CG Omega,serif',
#        'Reprise Metronome,monospace', 'Reprise Metronome,sans-serif',
#        'Reprise Metronome,serif', 'CAMPBELL,monospace',
#        'CAMPBELL,sans-serif', 'CAMPBELL,serif', 'MAXIMO,monospace',
#        'MAXIMO,sans-serif', 'MAXIMO,serif', 'IRIS,monospace',
#        'IRIS,sans-serif', 'IRIS,serif', 'HUNTSON,monospace',
#        'HUNTSON,sans-serif', 'HUNTSON,serif', 'AcadEref,monospace',
#        'AcadEref,sans-serif', 'AcadEref,serif',
#        'Lucida Grande CY,monospace', 'Lucida Grande CY,sans-serif',
#        'Lucida Grande CY,serif', 'Tall Paul,monospace',
#        'Tall Paul,sans-serif', 'Tall Paul,serif',
#        'Simply*Glamorous,monospace', 'Simply*Glamorous,sans-serif',
#        'Simply*Glamorous,serif', 'Australian Sunrise,monospace',
#        'Australian Sunrise,sans-serif', 'Australian Sunrise,serif',
#        'Photoshop Large,monospace', 'Photoshop Large,sans-serif',
#        'Photoshop Large,serif', 'Circus,monospace', 'Circus,sans-serif',
#        'Circus,serif', 'Outright Televism,monospace',
#        'Outright Televism,sans-serif', 'Outright Televism,serif',
#        'Contribute_FREE-version,monospace',
#        'Contribute_FREE-version,sans-serif',
#        'Contribute_FREE-version,serif', 'KENDRIC,monospace',
#        'KENDRIC,sans-serif', 'KENDRIC,serif',
#        'HGP-AGothic2-Latin1K,monospace',
#        'HGP-AGothic2-Latin1K,sans-serif', 'HGP-AGothic2-Latin1K,serif',
#        'AVGmdBU,monospace', 'AVGmdBU,sans-serif', 'AVGmdBU,serif',
#        'ReservoirGrunge,monospace', 'ReservoirGrunge,sans-serif',
#        'ReservoirGrunge,serif', 'FIRSTHOME,monospace',
#        'FIRSTHOME,sans-serif', 'FIRSTHOME,serif', 'LYNN,monospace',
#        'LYNN,sans-serif', 'LYNN,serif', 'BRODY,monospace',
#        'BRODY,sans-serif', 'BRODY,serif', 'Bergamot Ornaments,monospace',
#        'Bergamot Ornaments,sans-serif', 'Bergamot Ornaments,serif',
#        'Return To Sender,monospace', 'Return To Sender,sans-serif',
#        'Return To Sender,serif', 'Bleeding Cowboys,monospace',
#        'Bleeding Cowboys,sans-serif', 'Bleeding Cowboys,serif',
#        'LCD,monospace', 'LCD,sans-serif', 'LCD,serif', 'Goudy,monospace',
#        'Goudy,sans-serif', 'Goudy,serif', 'Oxford,monospace',
#        'Oxford,sans-serif', 'Oxford,serif', 'Budmo Jiggler,monospace',
#        'Budmo Jiggler,sans-serif', 'Budmo Jiggler,serif',
#        'Alba Matter,monospace', 'Alba Matter,sans-serif',
#        'Alba Matter,serif', 'Denmark,monospace', 'Denmark,sans-serif',
#        'Denmark,serif', 'Girls are Weird,monospace',
#        'Girls are Weird,sans-serif', 'Girls are Weird,serif',
#        'Channel Left-Slanted,monospace',
#        'Channel Left-Slanted,sans-serif', 'Channel Left-Slanted,serif',
#        'Traveling _Typewriter,monospace',
#        'Traveling _Typewriter,sans-serif', 'Traveling _Typewriter,serif',
#        'Teletype,monospace', 'Teletype,sans-serif', 'Teletype,serif',
#        'Cuckoo,monospace', 'Cuckoo,sans-serif', 'Cuckoo,serif',
#        'MARKETPRO,monospace', 'MARKETPRO,sans-serif', 'MARKETPRO,serif',
#        'ABIGAIL,monospace', 'ABIGAIL,sans-serif', 'ABIGAIL,serif',
#        'JACKIE,monospace', 'JACKIE,sans-serif', 'JACKIE,serif',
#        'Carnivalee Freakshow,monospace',
#        'Carnivalee Freakshow,sans-serif', 'Carnivalee Freakshow,serif',
#        'NewZurica,monospace', 'NewZurica,sans-serif', 'NewZurica,serif',
#        'OldCentury,monospace', 'OldCentury,sans-serif',
#        'OldCentury,serif', 'LongIsland,monospace',
#        'LongIsland,sans-serif', 'LongIsland,serif',
#        'Fontdinerdotcom Sparkly,monospace',
#        'Fontdinerdotcom Sparkly,sans-serif',
#        'Fontdinerdotcom Sparkly,serif', 'PAINTSTROKE,monospace',
#        'PAINTSTROKE,sans-serif', 'PAINTSTROKE,serif',
#        'Mona Lisa Recut,monospace', 'Mona Lisa Recut,sans-serif',
#        'Mona Lisa Recut,serif', 'Times New Roman Symbol,monospace',
#        'Times New Roman Symbol,sans-serif',
#        'Times New Roman Symbol,serif',
#        'ESRI Enviro Hazard Incident,monospace',
#        'ESRI Enviro Hazard Incident,sans-serif',
#        'ESRI Enviro Hazard Incident,serif', 'TextilePiEF,monospace',
#        'TextilePiEF,sans-serif', 'TextilePiEF,serif', 'Edda,monospace',
#        'Edda,sans-serif', 'Edda,serif', 'EcuyerDAX,monospace',
#        'EcuyerDAX,sans-serif', 'EcuyerDAX,serif',
#        'Bodoni PosterCompressed,monospace',
#        'Bodoni PosterCompressed,sans-serif',
#        'Bodoni PosterCompressed,serif', 'MapInfo Cartographic,monospace',
#        'MapInfo Cartographic,sans-serif', 'MapInfo Cartographic,serif',
#        'ESRI NIMA City Graphic LN,monospace',
#        'ESRI NIMA City Graphic LN,sans-serif',
#        'ESRI NIMA City Graphic LN,serif', 'Virtual DJ,monospace',
#        'Virtual DJ,sans-serif', 'Virtual DJ,serif',
#        'MS SystemEx,monospace', 'MS SystemEx,sans-serif',
#        'MS SystemEx,serif', 'AdineKirnberg-Script,monospace',
#        'AdineKirnberg-Script,sans-serif', 'AdineKirnberg-Script,serif',
#        'Exmouth,monospace', 'Exmouth,sans-serif', 'Exmouth,serif',
#        'OPENCLASSIC,monospace', 'OPENCLASSIC,sans-serif',
#        'OPENCLASSIC,serif', 'Sweetly Broken,monospace',
#        'Sweetly Broken,sans-serif', 'Sweetly Broken,serif',
#        'English Essay,monospace', 'English Essay,sans-serif',
#        'English Essay,serif', 'Jenkins v2.0,monospace',
#        'Jenkins v2.0,sans-serif', 'Jenkins v2.0,serif',
#        'Architects Daughter,monospace', 'Architects Daughter,sans-serif',
#        'Architects Daughter,serif', 'Taffy,monospace', 'Taffy,sans-serif',
#        'Taffy,serif', 'Weltron Urban,monospace',
#        'Weltron Urban,sans-serif', 'Weltron Urban,serif',
#        '1942 report,monospace', '1942 report,sans-serif',
#        '1942 report,serif', 'Fat,monospace', 'Fat,sans-serif',
#        'Fat,serif', 'Rod Transparent,monospace',
#        'Rod Transparent,sans-serif', 'Rod Transparent,serif',
#        'SimSun-PUA,monospace', 'SimSun-PUA,sans-serif',
#        'SimSun-PUA,serif', 'Before the Rain Swashes DEMO,monospace',
#        'Before the Rain Swashes DEMO,sans-serif',
#        'Before the Rain Swashes DEMO,serif', 'Abraham Lincoln,monospace',
#        'Abraham Lincoln,sans-serif', 'Abraham Lincoln,serif',
#        'Opus Japanese Chords,monospace',
#        'Opus Japanese Chords,sans-serif', 'Opus Japanese Chords,serif',
#        'Agent Orange,monospace', 'Agent Orange,sans-serif',
#        'Agent Orange,serif', 'Almonte Snow,monospace',
#        'Almonte Snow,sans-serif', 'Almonte Snow,serif',
#        'Luciano,monospace', 'Luciano,sans-serif', 'Luciano,serif',
#        'HenryMorganHand,monospace', 'HenryMorganHand,sans-serif',
#        'HenryMorganHand,serif', 'KG Skinny Latte,monospace',
#        'KG Skinny Latte,sans-serif', 'KG Skinny Latte,serif',
#        'CANDY INC.,monospace', 'CANDY INC.,sans-serif',
#        'CANDY INC.,serif', 'Tango BT,monospace', 'Tango BT,sans-serif',
#        'Tango BT,serif', 'GrutchShaded,monospace',
#        'GrutchShaded,sans-serif', 'GrutchShaded,serif',
#        'Segoe Media Center Semibold,monospace',
#        'Segoe Media Center Semibold,sans-serif',
#        'Segoe Media Center Semibold,serif', 'Kiev,monospace',
#        'Kiev,sans-serif', 'Kiev,serif', 'Lobster 1.3,monospace',
#        'Lobster 1.3,sans-serif', 'Lobster 1.3,serif', 'Tabitha,monospace',
#        'Tabitha,sans-serif', 'Tabitha,serif', 'Bimini,monospace',
#        'Bimini,sans-serif', 'Bimini,serif', 'OptimusPrinceps,monospace',
#        'OptimusPrinceps,sans-serif', 'OptimusPrinceps,serif',
#        'Ostrich Sans Dashed Medium,monospace',
#        'Ostrich Sans Dashed Medium,sans-serif',
#        'Ostrich Sans Dashed Medium,serif', 'DK Crayon Crumble,monospace',
#        'DK Crayon Crumble,sans-serif', 'DK Crayon Crumble,serif',
#        'DYMObvba,monospace', 'DYMObvba,sans-serif', 'DYMObvba,serif',
#        '28 Days Later,monospace', '28 Days Later,sans-serif',
#        '28 Days Later,serif', 'Engaged,monospace', 'Engaged,sans-serif',
#        'Engaged,serif', 'always * forever,monospace',
#        'always * forever,sans-serif', 'always * forever,serif',
#        'Loki Cola,monospace', 'Loki Cola,sans-serif', 'Loki Cola,serif',
#        'Connecticut,monospace', 'Connecticut,sans-serif',
#        'Connecticut,serif', 'Pea Ellie Bellie,monospace',
#        'Pea Ellie Bellie,sans-serif', 'Pea Ellie Bellie,serif',
#        'Utah,monospace', 'Utah,sans-serif', 'Utah,serif',
#        'MICR,monospace', 'MICR,sans-serif', 'MICR,serif',
#        'Things We Said,monospace', 'Things We Said,sans-serif',
#        'Things We Said,serif', 'Stars & Stripes,monospace',
#        'Stars & Stripes,sans-serif', 'Stars & Stripes,serif',
#        'Rope MF,monospace', 'Rope MF,sans-serif', 'Rope MF,serif',
#        'Lato Hairline,monospace', 'Lato Hairline,sans-serif',
#        'Lato Hairline,serif', 'GilliesGotDLig,monospace',
#        'GilliesGotDLig,sans-serif', 'GilliesGotDLig,serif',
#        'Antique Olive CompactPS,monospace',
#        'Antique Olive CompactPS,sans-serif',
#        'Antique Olive CompactPS,serif', 'CaslonNo540SwaD,monospace',
#        'CaslonNo540SwaD,sans-serif', 'CaslonNo540SwaD,serif',
#        'SF Movie Poster,monospace', 'SF Movie Poster,sans-serif',
#        'SF Movie Poster,serif', 'CaslonAntT,monospace',
#        'CaslonAntT,sans-serif', 'CaslonAntT,serif',
#        'Josefin Slab,monospace', 'Josefin Slab,sans-serif',
#        'Josefin Slab,serif', 'PegsannaHMK,monospace',
#        'PegsannaHMK,sans-serif', 'PegsannaHMK,serif',
#        'Impact Label Reversed,monospace',
#        'Impact Label Reversed,sans-serif', 'Impact Label Reversed,serif',
#        'Ubuntu,monospace', 'Ubuntu,sans-serif', 'Ubuntu,serif',
#        'Oh {Photo} Shoot!,monospace', 'Oh {Photo} Shoot!,sans-serif',
#        'Oh {Photo} Shoot!,serif', 'Deftone Stylus,monospace',
#        'Deftone Stylus,sans-serif', 'Deftone Stylus,serif',
#        'CluffHmk,monospace', 'CluffHmk,sans-serif', 'CluffHmk,serif',
#        'Incised901 BdCn BT,monospace', 'Incised901 BdCn BT,sans-serif',
#        'Incised901 BdCn BT,serif', 'Respective 2.0,monospace',
#        'Respective 2.0,sans-serif', 'Respective 2.0,serif',
#        'Parry Hotter,monospace', 'Parry Hotter,sans-serif',
#        'Parry Hotter,serif', 'NotnorvalHmk,monospace',
#        'NotnorvalHmk,sans-serif', 'NotnorvalHmk,serif',
#        'odstemplik,monospace', 'odstemplik,sans-serif',
#        'odstemplik,serif', 'Ethnocentric,monospace',
#        'Ethnocentric,sans-serif', 'Ethnocentric,serif',
#        'Miserably Lose,monospace', 'Miserably Lose,sans-serif',
#        'Miserably Lose,serif', 'SAS Monospace,monospace',
#        'SAS Monospace,sans-serif', 'SAS Monospace,serif',
#        'Stonehenge,monospace', 'Stonehenge,sans-serif',
#        'Stonehenge,serif', 'BethsCuteHmk,monospace',
#        'BethsCuteHmk,sans-serif', 'BethsCuteHmk,serif',
#        'BixAntiqueScriptHmk,monospace', 'BixAntiqueScriptHmk,sans-serif',
#        'BixAntiqueScriptHmk,serif', 'MicrogrammaDMedExt,monospace',
#        'MicrogrammaDMedExt,sans-serif', 'MicrogrammaDMedExt,serif',
#        'StarbabeHmk,monospace', 'StarbabeHmk,sans-serif',
#        'StarbabeHmk,serif', 'FFF Tusj,monospace', 'FFF Tusj,sans-serif',
#        'FFF Tusj,serif', 'BoogieWoogieHmk,monospace',
#        'BoogieWoogieHmk,sans-serif', 'BoogieWoogieHmk,serif',
#        'Star Jedi Hollow,monospace', 'Star Jedi Hollow,sans-serif',
#        'Star Jedi Hollow,serif', 'Eight Fifteen,monospace',
#        'Eight Fifteen,sans-serif', 'Eight Fifteen,serif',
#        'Ribbon,monospace', 'Ribbon,sans-serif', 'Ribbon,serif',
#        'Helsinki Narrow,monospace', 'Helsinki Narrow,sans-serif',
#        'Helsinki Narrow,serif', 'San Diego,monospace',
#        'San Diego,sans-serif', 'San Diego,serif', 'Jewels,monospace',
#        'Jewels,sans-serif', 'Jewels,serif',
#        'Baskerville-Old-Face,monospace',
#        'Baskerville-Old-Face,sans-serif', 'Baskerville-Old-Face,serif',
#        'OCR-A,monospace', 'OCR-A,sans-serif', 'OCR-A,serif',
#        'OttumHmk,monospace', 'OttumHmk,sans-serif', 'OttumHmk,serif',
#        'Mr and Mrs Popsicle,monospace', 'Mr and Mrs Popsicle,sans-serif',
#        'Mr and Mrs Popsicle,serif', 'Symbol Tiger Expert,monospace',
#        'Symbol Tiger Expert,sans-serif', 'Symbol Tiger Expert,serif',
#        'URWAlcuinT,monospace', 'URWAlcuinT,sans-serif',
#        'URWAlcuinT,serif', 'DynameBlackSSK,monospace',
#        'DynameBlackSSK,sans-serif'], dtype=object)

# %%
print(js[(js.symbol == 'CanvasRenderingContext2D.font') & (js.script_ps1 != js.top_ps1)])
test=js[(js.symbol == 'CanvasRenderingContext2D.font') & (js.script_ps1 != js.top_ps1)]
# Out:
#             id  crawl_id  visit_id  \
# 1144      1145         3         3
# 1174      1175         3         3
# 1182      1183         3         3
# 1194      1195         3         3
# 1224      1225         3         3
# ...        ...       ...       ...
# 492372  492373         2       971
# 492404  492405         2       971
# 495009  495010         4       985
# 495012  495013         4       985
# 497272  497273        13       997
#
#                                                script_url script_line  \
# 1144    https://static.xx.fbcdn.net/rsrc.php/v3iYXl4/y...          19
# 1174    https://static.xx.fbcdn.net/rsrc.php/v3iYXl4/y...          19
# 1182    https://static.xx.fbcdn.net/rsrc.php/v3iYXl4/y...          19
# 1194    https://static.xx.fbcdn.net/rsrc.php/v3iYXl4/y...          19
# 1224    https://static.xx.fbcdn.net/rsrc.php/v3iYXl4/y...          19
# ...                                                   ...         ...
# 492372  https://cdn.doubleverify.com/dv-measurements23...         353
# 492404  https://cdn.doubleverify.com/dv-measurements23...         353
# 495009            https://cdn.pulpix.com/static/pulpix.js           8
# 495012            https://cdn.pulpix.com/static/pulpix.js           8
# 497272  https://cdn.doubleverify.com/dvbs_src_internal...         758
#
#        script_col                            func_name script_loc_eval  \
# 1144         1402                g.prototype.drawEmoji
# 1174         1086                 g.prototype.drawText
# 1182         1402                g.prototype.drawEmoji
# 1194         1402                g.prototype.drawEmoji
# 1224         1086                 g.prototype.drawText
# ...           ...                                  ...             ...
# 492372        385                    g</a.prototype.Qs
# 492404        385                    g</a.prototype.Qs
# 495009       1958  pxLoadReq/</e.prototype.getCanvasFp
# 495012       2137  pxLoadReq/</e.prototype.getCanvasFp
# 497272        391                                    f
#
#                       document_url               top_level_url call_stack  \
# 1144     https://www.facebook.com/   https://www.facebook.com/
# 1174     https://www.facebook.com/   https://www.facebook.com/
# 1182     https://www.facebook.com/   https://www.facebook.com/
# 1194     https://www.facebook.com/   https://www.facebook.com/
# 1224     https://www.facebook.com/   https://www.facebook.com/
# ...                            ...                         ...        ...
# 492372  https://www.zerohedge.com/  https://www.zerohedge.com/
# 492404  https://www.zerohedge.com/  https://www.zerohedge.com/
# 495009     https://www.lequipe.fr/     https://www.lequipe.fr/
# 495012     https://www.lequipe.fr/     https://www.lequipe.fr/
# 497272  https://www.techradar.com/  https://www.techradar.com/
#
#                                symbol operation                  value  \
# 1144    CanvasRenderingContext2D.font       set            123px Arial
# 1174    CanvasRenderingContext2D.font       set            123px Arial
# 1182    CanvasRenderingContext2D.font       set            106px Arial
# 1194    CanvasRenderingContext2D.font       set            118px Arial
# 1224    CanvasRenderingContext2D.font       set            114px Arial
# ...                               ...       ...                    ...
# 492372  CanvasRenderingContext2D.font       set             14px Arial
# 492404  CanvasRenderingContext2D.font       set             14px Arial
# 495009  CanvasRenderingContext2D.font       set  11pt no-real-font-123
# 495012  CanvasRenderingContext2D.font       set             18pt Arial
# 497272  CanvasRenderingContext2D.font       set           14px 'Arial'
#
#        arguments                time_stamp        script_ps1        top_ps1  \
# 1144        None  2018-06-27T14:19:44.144Z         fbcdn.net   facebook.com
# 1174        None  2018-06-27T14:19:44.154Z         fbcdn.net   facebook.com
# 1182        None  2018-06-27T14:19:44.158Z         fbcdn.net   facebook.com
# 1194        None  2018-06-27T14:19:44.188Z         fbcdn.net   facebook.com
# 1224        None  2018-06-27T14:19:44.210Z         fbcdn.net   facebook.com
# ...          ...                       ...               ...            ...
# 492372      None  2018-06-27T14:49:39.438Z  doubleverify.com  zerohedge.com
# 492404      None  2018-06-27T14:49:34.488Z  doubleverify.com  zerohedge.com
# 495009      None  2018-06-27T14:49:54.158Z        pulpix.com     lequipe.fr
# 495012      None  2018-06-27T14:49:54.160Z        pulpix.com     lequipe.fr
# 497272      None  2018-06-27T14:50:02.796Z  doubleverify.com  techradar.com
#
#          document_ps1
# 1144     facebook.com
# 1174     facebook.com
# 1182     facebook.com
# 1194     facebook.com
# 1224     facebook.com
# ...               ...
# 492372  zerohedge.com
# 492404  zerohedge.com
# 495009     lequipe.fr
# 495012     lequipe.fr
# 497272  techradar.com
#
# [2723 rows x 19 columns]

# %%
test.groupby(['script_ps1', 'top_ps1', 'value']).count()
# Out:
#                                                                                       id  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                       2
# 360buyimg.com     jd.com          11pt no-real-font-123                                2
#                                   18pt Arial                                           2
# adsco.re          tamilrockers.gy 14px 'Arial'                                         1
# adtima.vn         zing.vn         11pt no-real-font-123                                1
# ...                                                                                   ..
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...   1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...   2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...   1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...   2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...   2
#
#                                                                                       crawl_id  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                             2
# 360buyimg.com     jd.com          11pt no-real-font-123                                      2
#                                   18pt Arial                                                 2
# adsco.re          tamilrockers.gy 14px 'Arial'                                               1
# adtima.vn         zing.vn         11pt no-real-font-123                                      1
# ...                                                                                        ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...         1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...         2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...         1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...         2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...         2
#
#                                                                                       visit_id  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                             2
# 360buyimg.com     jd.com          11pt no-real-font-123                                      2
#                                   18pt Arial                                                 2
# adsco.re          tamilrockers.gy 14px 'Arial'                                               1
# adtima.vn         zing.vn         11pt no-real-font-123                                      1
# ...                                                                                        ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...         1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...         2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...         1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...         2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...         2
#
#                                                                                       script_url  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                               2
# 360buyimg.com     jd.com          11pt no-real-font-123                                        2
#                                   18pt Arial                                                   2
# adsco.re          tamilrockers.gy 14px 'Arial'                                                 1
# adtima.vn         zing.vn         11pt no-real-font-123                                        1
# ...                                                                                          ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...           1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...           2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...           1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...           2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...           2
#
#                                                                                       script_line  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                                2
# 360buyimg.com     jd.com          11pt no-real-font-123                                         2
#                                   18pt Arial                                                    2
# adsco.re          tamilrockers.gy 14px 'Arial'                                                  1
# adtima.vn         zing.vn         11pt no-real-font-123                                         1
# ...                                                                                           ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...            1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...            2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...            1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...            2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...            2
#
#                                                                                       script_col  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                               2
# 360buyimg.com     jd.com          11pt no-real-font-123                                        2
#                                   18pt Arial                                                   2
# adsco.re          tamilrockers.gy 14px 'Arial'                                                 1
# adtima.vn         zing.vn         11pt no-real-font-123                                        1
# ...                                                                                          ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...           1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...           2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...           1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...           2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...           2
#
#                                                                                       func_name  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                              2
# 360buyimg.com     jd.com          11pt no-real-font-123                                       2
#                                   18pt Arial                                                  2
# adsco.re          tamilrockers.gy 14px 'Arial'                                                1
# adtima.vn         zing.vn         11pt no-real-font-123                                       1
# ...                                                                                         ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...          1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...          2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...          1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...          2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...          2
#
#                                                                                       script_loc_eval  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                                    2
# 360buyimg.com     jd.com          11pt no-real-font-123                                             2
#                                   18pt Arial                                                        2
# adsco.re          tamilrockers.gy 14px 'Arial'                                                      1
# adtima.vn         zing.vn         11pt no-real-font-123                                             1
# ...                                                                                               ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...                1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...                2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...                1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...                2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...                2
#
#                                                                                       document_url  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                                 2
# 360buyimg.com     jd.com          11pt no-real-font-123                                          2
#                                   18pt Arial                                                     2
# adsco.re          tamilrockers.gy 14px 'Arial'                                                   1
# adtima.vn         zing.vn         11pt no-real-font-123                                          1
# ...                                                                                            ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...             1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...             2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...             1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...             2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...             2
#
#                                                                                       top_level_url  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                                  2
# 360buyimg.com     jd.com          11pt no-real-font-123                                           2
#                                   18pt Arial                                                      2
# adsco.re          tamilrockers.gy 14px 'Arial'                                                    1
# adtima.vn         zing.vn         11pt no-real-font-123                                           1
# ...                                                                                             ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...              1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...              2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...              1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...              2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...              2
#
#                                                                                       call_stack  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                               2
# 360buyimg.com     jd.com          11pt no-real-font-123                                        2
#                                   18pt Arial                                                   2
# adsco.re          tamilrockers.gy 14px 'Arial'                                                 1
# adtima.vn         zing.vn         11pt no-real-font-123                                        1
# ...                                                                                          ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...           1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...           2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...           1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...           2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...           2
#
#                                                                                       symbol  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                           2
# 360buyimg.com     jd.com          11pt no-real-font-123                                    2
#                                   18pt Arial                                               2
# adsco.re          tamilrockers.gy 14px 'Arial'                                             1
# adtima.vn         zing.vn         11pt no-real-font-123                                    1
# ...                                                                                      ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...       1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...       2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...       1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...       2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...       2
#
#                                                                                       operation  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                              2
# 360buyimg.com     jd.com          11pt no-real-font-123                                       2
#                                   18pt Arial                                                  2
# adsco.re          tamilrockers.gy 14px 'Arial'                                                1
# adtima.vn         zing.vn         11pt no-real-font-123                                       1
# ...                                                                                         ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...          1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...          2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...          1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...          2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...          2
#
#                                                                                       arguments  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                              0
# 360buyimg.com     jd.com          11pt no-real-font-123                                       0
#                                   18pt Arial                                                  0
# adsco.re          tamilrockers.gy 14px 'Arial'                                                0
# adtima.vn         zing.vn         11pt no-real-font-123                                       0
# ...                                                                                         ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...          0
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...          0
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...          0
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...          0
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...          0
#
#                                                                                       time_stamp  \
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                               2
# 360buyimg.com     jd.com          11pt no-real-font-123                                        2
#                                   18pt Arial                                                   2
# adsco.re          tamilrockers.gy 14px 'Arial'                                                 1
# adtima.vn         zing.vn         11pt no-real-font-123                                        1
# ...                                                                                          ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...           1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...           2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...           1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...           2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...           2
#
#                                                                                       document_ps1
# script_ps1        top_ps1         value
#                   fanpage.gr      600 32px Arial                                                 2
# 360buyimg.com     jd.com          11pt no-real-font-123                                          2
#                                   18pt Arial                                                     2
# adsco.re          tamilrockers.gy 14px 'Arial'                                                   1
# adtima.vn         zing.vn         11pt no-real-font-123                                          1
# ...                                                                                            ...
# walmartimages.com walmart.com     400 normal 18px BogleWeb,Helvetica Neue,Helveti...             1
#                                   400 normal 19px BogleWeb,Helvetica Neue,Helveti...             2
#                                   400 normal 36px BogleWeb,Helvetica Neue,Helveti...             1
#                                   400 normal 44px BogleWeb,Helvetica Neue,Helveti...             2
#                                   600 normal 19px BogleWeb,Helvetica Neue,Helveti...             2
#
# [2463 rows x 16 columns]

# %%
test.value.apply(lambda x: re.match(font_shorthand, x))
# Out:
# 1144      <re.Match object; span=(0, 11), match='123px A...
# 1174      <re.Match object; span=(0, 11), match='123px A...
# 1182      <re.Match object; span=(0, 11), match='106px A...
# 1194      <re.Match object; span=(0, 11), match='118px A...
# 1224      <re.Match object; span=(0, 11), match='114px A...
#                                 ...
# 492372    <re.Match object; span=(0, 10), match='14px Ar...
# 492404    <re.Match object; span=(0, 10), match='14px Ar...
# 495009    <re.Match object; span=(0, 21), match='11pt no...
# 495012    <re.Match object; span=(0, 10), match='18pt Ar...
# 497272    <re.Match object; span=(0, 12), match="14px 'A...
# Name: value, Length: 2723, dtype: object

# %%
def regex_value(row):
    s=re.match(font_shorthand, row['value'])
    print(s)
    return s

# %%
test['value_b'] = test.apply(lambda row: regex_value(row), axis=1)
# Out:
# <re.Match object; span=(0, 11), match='123px Arial'>
# <re.Match object; span=(0, 11), match='123px Arial'>
# <re.Match object; span=(0, 11), match='106px Arial'>
# <re.Match object; span=(0, 11), match='118px Arial'>
# <re.Match object; span=(0, 11), match='114px Arial'>
# <re.Match object; span=(0, 11), match='108px Arial'>
# <re.Match object; span=(0, 11), match='123px Arial'>
# <re.Match object; span=(0, 11), match='123px Arial'>
# <re.Match object; span=(0, 11), match='106px Arial'>
# <re.Match object; span=(0, 11), match='118px Arial'>
# <re.Match object; span=(0, 11), match='114px Arial'>
# <re.Match object; span=(0, 11), match='108px Arial'>
# <re.Match object; span=(0, 10), match='15px Arial'>
# <re.Match object; span=(0, 10), match='15px Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 14), match='72px monospace'>
# <re.Match object; span=(0, 15), match='72px sans-serif'>
# <re.Match object; span=(0, 10), match='72px serif'>
# <re.Match object; span=(0, 25), match='72px AR DARLING,monospace'>
# <re.Match object; span=(0, 26), match='72px AR DARLING,sans-serif'>
# <re.Match object; span=(0, 21), match='72px AR DARLING,serif'>
# <re.Match object; span=(0, 29), match='72px Earwig Factory,monospace'>
# <re.Match object; span=(0, 30), match='72px Earwig Factory,sans-serif'>
# <re.Match object; span=(0, 25), match='72px Earwig Factory,serif'>
# <re.Match object; span=(0, 29), match='72px Minya Nouvelle,monospace'>
# <re.Match object; span=(0, 30), match='72px Minya Nouvelle,sans-serif'>
# <re.Match object; span=(0, 25), match='72px Minya Nouvelle,serif'>
# <re.Match object; span=(0, 28), match='72px Burnstown Dam,monospace'>
# <re.Match object; span=(0, 29), match='72px Burnstown Dam,sans-serif'>
# <re.Match object; span=(0, 24), match='72px Burnstown Dam,serif'>
# <re.Match object; span=(0, 26), match='72px Sybil Green,monospace'>
# <re.Match object; span=(0, 27), match='72px Sybil Green,sans-serif'>
# <re.Match object; span=(0, 22), match='72px Sybil Green,serif'>
# <re.Match object; span=(0, 28), match='72px Stereofidelic,monospace'>
# <re.Match object; span=(0, 29), match='72px Stereofidelic,sans-serif'>
# <re.Match object; span=(0, 24), match='72px Stereofidelic,serif'>
# <re.Match object; span=(0, 31), match='72px Urdu Typesetting,monospace'>
# <re.Match object; span=(0, 32), match='72px Urdu Typesetting,sans-serif'>
# <re.Match object; span=(0, 27), match='72px Urdu Typesetting,serif'>
# <re.Match object; span=(0, 35), match='72px Blue Highway Linocut,monospace'>
# <re.Match object; span=(0, 36), match='72px Blue Highway Linocut,sans-serif'>
# <re.Match object; span=(0, 31), match='72px Blue Highway Linocut,serif'>
# <re.Match object; span=(0, 28), match='72px Credit Valley,monospace'>
# <re.Match object; span=(0, 29), match='72px Credit Valley,sans-serif'>
# <re.Match object; span=(0, 24), match='72px Credit Valley,serif'>
# <re.Match object; span=(0, 30), match='72px Velvenda Cooler,monospace'>
# <re.Match object; span=(0, 31), match='72px Velvenda Cooler,sans-serif'>
# <re.Match object; span=(0, 26), match='72px Velvenda Cooler,serif'>
# <re.Match object; span=(0, 23), match='72px Mufferaw,monospace'>
# <re.Match object; span=(0, 24), match='72px Mufferaw,sans-serif'>
# <re.Match object; span=(0, 19), match='72px Mufferaw,serif'>
# <re.Match object; span=(0, 23), match='72px Huxtable,monospace'>
# <re.Match object; span=(0, 24), match='72px Huxtable,sans-serif'>
# <re.Match object; span=(0, 19), match='72px Huxtable,serif'>
# <re.Match object; span=(0, 21), match='72px Boopee,monospace'>
# <re.Match object; span=(0, 22), match='72px Boopee,sans-serif'>
# <re.Match object; span=(0, 17), match='72px Boopee,serif'>
# <re.Match object; span=(0, 19), match='72px Kefa,monospace'>
# <re.Match object; span=(0, 20), match='72px Kefa,sans-serif'>
# <re.Match object; span=(0, 15), match='72px Kefa,serif'>
# <re.Match object; span=(0, 29), match='72px Nanum Myeongjo,monospace'>
# <re.Match object; span=(0, 30), match='72px Nanum Myeongjo,sans-serif'>
# <re.Match object; span=(0, 25), match='72px Nanum Myeongjo,serif'>
# <re.Match object; span=(0, 27), match='72px LuzSans-Book,monospace'>
# <re.Match object; span=(0, 28), match='72px LuzSans-Book,sans-serif'>
# <re.Match object; span=(0, 23), match='72px LuzSans-Book,serif'>
# <re.Match object; span=(0, 46), match='72px Castro Script PERSONAL USE ONLY,monospace'>
# <re.Match object; span=(0, 47), match='72px Castro Script PERSONAL USE ONLY,sans-serif'>
# <re.Match object; span=(0, 42), match='72px Castro Script PERSONAL USE ONLY,serif'>
# <re.Match object; span=(0, 22), match='72px 8514oem,monospace'>
# <re.Match object; span=(0, 23), match='72px 8514oem,sans-serif'>
# <re.Match object; span=(0, 18), match='72px 8514oem,serif'>
# <re.Match object; span=(0, 33), match='72px Gentium Book Basic,monospace'>
# <re.Match object; span=(0, 34), match='72px Gentium Book Basic,sans-serif'>
# <re.Match object; span=(0, 29), match='72px Gentium Book Basic,serif'>
# <re.Match object; span=(0, 31), match='72px Sitka Subheading,monospace'>
# <re.Match object; span=(0, 32), match='72px Sitka Subheading,sans-serif'>
# <re.Match object; span=(0, 27), match='72px Sitka Subheading,serif'>
# <re.Match object; span=(0, 22), match='72px Mishafi,monospace'>
# <re.Match object; span=(0, 23), match='72px Mishafi,sans-serif'>
# <re.Match object; span=(0, 18), match='72px Mishafi,serif'>
# <re.Match object; span=(0, 33), match='72px Wickenden Cafe NDP,monospace'>
# <re.Match object; span=(0, 34), match='72px Wickenden Cafe NDP,sans-serif'>
# <re.Match object; span=(0, 29), match='72px Wickenden Cafe NDP,serif'>
# <re.Match object; span=(0, 24), match='72px Jenna Sue,monospace'>
# <re.Match object; span=(0, 25), match='72px Jenna Sue,sans-serif'>
# <re.Match object; span=(0, 20), match='72px Jenna Sue,serif'>
# <re.Match object; span=(0, 22), match='72px Symusic,monospace'>
# <re.Match object; span=(0, 23), match='72px Symusic,sans-serif'>
# <re.Match object; span=(0, 18), match='72px Symusic,serif'>
# <re.Match object; span=(0, 22), match='72px Monotxt,monospace'>
# <re.Match object; span=(0, 23), match='72px Monotxt,sans-serif'>
# <re.Match object; span=(0, 18), match='72px Monotxt,serif'>
# <re.Match object; span=(0, 23), match='72px CG Omega,monospace'>
# <re.Match object; span=(0, 24), match='72px CG Omega,sans-serif'>
# <re.Match object; span=(0, 19), match='72px CG Omega,serif'>
# <re.Match object; span=(0, 32), match='72px Reprise Metronome,monospace'>
# <re.Match object; span=(0, 33), match='72px Reprise Metronome,sans-serif'>
# <re.Match object; span=(0, 28), match='72px Reprise Metronome,serif'>
# <re.Match object; span=(0, 23), match='72px CAMPBELL,monospace'>
# <re.Match object; span=(0, 24), match='72px CAMPBELL,sans-serif'>
# <re.Match object; span=(0, 19), match='72px CAMPBELL,serif'>
# <re.Match object; span=(0, 21), match='72px MAXIMO,monospace'>
# <re.Match object; span=(0, 22), match='72px MAXIMO,sans-serif'>
# <re.Match object; span=(0, 17), match='72px MAXIMO,serif'>
# <re.Match object; span=(0, 19), match='72px IRIS,monospace'>
# <re.Match object; span=(0, 20), match='72px IRIS,sans-serif'>
# <re.Match object; span=(0, 15), match='72px IRIS,serif'>
# <re.Match object; span=(0, 22), match='72px HUNTSON,monospace'>
# <re.Match object; span=(0, 23), match='72px HUNTSON,sans-serif'>
# <re.Match object; span=(0, 18), match='72px HUNTSON,serif'>
# <re.Match object; span=(0, 23), match='72px AcadEref,monospace'>
# <re.Match object; span=(0, 24), match='72px AcadEref,sans-serif'>
# <re.Match object; span=(0, 19), match='72px AcadEref,serif'>
# <re.Match object; span=(0, 31), match='72px Lucida Grande CY,monospace'>
# <re.Match object; span=(0, 32), match='72px Lucida Grande CY,sans-serif'>
# <re.Match object; span=(0, 27), match='72px Lucida Grande CY,serif'>
# <re.Match object; span=(0, 24), match='72px Tall Paul,monospace'>
# <re.Match object; span=(0, 25), match='72px Tall Paul,sans-serif'>
# <re.Match object; span=(0, 20), match='72px Tall Paul,serif'>
# <re.Match object; span=(0, 31), match='72px Simply*Glamorous,monospace'>
# <re.Match object; span=(0, 32), match='72px Simply*Glamorous,sans-serif'>
# <re.Match object; span=(0, 27), match='72px Simply*Glamorous,serif'>
# <re.Match object; span=(0, 33), match='72px Australian Sunrise,monospace'>
# <re.Match object; span=(0, 34), match='72px Australian Sunrise,sans-serif'>
# <re.Match object; span=(0, 29), match='72px Australian Sunrise,serif'>
# <re.Match object; span=(0, 30), match='72px Photoshop Large,monospace'>
# <re.Match object; span=(0, 31), match='72px Photoshop Large,sans-serif'>
# <re.Match object; span=(0, 26), match='72px Photoshop Large,serif'>
# <re.Match object; span=(0, 21), match='72px Circus,monospace'>
# <re.Match object; span=(0, 22), match='72px Circus,sans-serif'>
# <re.Match object; span=(0, 17), match='72px Circus,serif'>
# <re.Match object; span=(0, 32), match='72px Outright Televism,monospace'>
# <re.Match object; span=(0, 33), match='72px Outright Televism,sans-serif'>
# <re.Match object; span=(0, 28), match='72px Outright Televism,serif'>
# <re.Match object; span=(0, 38), match='72px Contribute_FREE-version,monospace'>
# <re.Match object; span=(0, 39), match='72px Contribute_FREE-version,sans-serif'>
# <re.Match object; span=(0, 34), match='72px Contribute_FREE-version,serif'>
# <re.Match object; span=(0, 22), match='72px KENDRIC,monospace'>
# <re.Match object; span=(0, 23), match='72px KENDRIC,sans-serif'>
# <re.Match object; span=(0, 18), match='72px KENDRIC,serif'>
# <re.Match object; span=(0, 35), match='72px HGP-AGothic2-Latin1K,monospace'>
# <re.Match object; span=(0, 36), match='72px HGP-AGothic2-Latin1K,sans-serif'>
# <re.Match object; span=(0, 31), match='72px HGP-AGothic2-Latin1K,serif'>
# <re.Match object; span=(0, 22), match='72px AVGmdBU,monospace'>
# <re.Match object; span=(0, 23), match='72px AVGmdBU,sans-serif'>
# <re.Match object; span=(0, 18), match='72px AVGmdBU,serif'>
# <re.Match object; span=(0, 30), match='72px ReservoirGrunge,monospace'>
# <re.Match object; span=(0, 31), match='72px ReservoirGrunge,sans-serif'>
# <re.Match object; span=(0, 26), match='72px ReservoirGrunge,serif'>
# <re.Match object; span=(0, 24), match='72px FIRSTHOME,monospace'>
# <re.Match object; span=(0, 25), match='72px FIRSTHOME,sans-serif'>
# <re.Match object; span=(0, 20), match='72px FIRSTHOME,serif'>
# <re.Match object; span=(0, 19), match='72px LYNN,monospace'>
# <re.Match object; span=(0, 20), match='72px LYNN,sans-serif'>
# <re.Match object; span=(0, 15), match='72px LYNN,serif'>
# <re.Match object; span=(0, 20), match='72px BRODY,monospace'>
# <re.Match object; span=(0, 21), match='72px BRODY,sans-serif'>
# <re.Match object; span=(0, 16), match='72px BRODY,serif'>
# <re.Match object; span=(0, 33), match='72px Bergamot Ornaments,monospace'>
# <re.Match object; span=(0, 34), match='72px Bergamot Ornaments,sans-serif'>
# <re.Match object; span=(0, 29), match='72px Bergamot Ornaments,serif'>
# <re.Match object; span=(0, 31), match='72px Return To Sender,monospace'>
# <re.Match object; span=(0, 32), match='72px Return To Sender,sans-serif'>
# <re.Match object; span=(0, 27), match='72px Return To Sender,serif'>
# <re.Match object; span=(0, 31), match='72px Bleeding Cowboys,monospace'>
# <re.Match object; span=(0, 32), match='72px Bleeding Cowboys,sans-serif'>
# <re.Match object; span=(0, 27), match='72px Bleeding Cowboys,serif'>
# <re.Match object; span=(0, 18), match='72px LCD,monospace'>
# <re.Match object; span=(0, 19), match='72px LCD,sans-serif'>
# <re.Match object; span=(0, 14), match='72px LCD,serif'>
# <re.Match object; span=(0, 20), match='72px Goudy,monospace'>
# <re.Match object; span=(0, 21), match='72px Goudy,sans-serif'>
# <re.Match object; span=(0, 16), match='72px Goudy,serif'>
# <re.Match object; span=(0, 21), match='72px Oxford,monospace'>
# <re.Match object; span=(0, 22), match='72px Oxford,sans-serif'>
# <re.Match object; span=(0, 17), match='72px Oxford,serif'>
# <re.Match object; span=(0, 28), match='72px Budmo Jiggler,monospace'>
# <re.Match object; span=(0, 29), match='72px Budmo Jiggler,sans-serif'>
# <re.Match object; span=(0, 24), match='72px Budmo Jiggler,serif'>
# <re.Match object; span=(0, 26), match='72px Alba Matter,monospace'>
# <re.Match object; span=(0, 27), match='72px Alba Matter,sans-serif'>
# <re.Match object; span=(0, 22), match='72px Alba Matter,serif'>
# <re.Match object; span=(0, 22), match='72px Denmark,monospace'>
# <re.Match object; span=(0, 23), match='72px Denmark,sans-serif'>
# <re.Match object; span=(0, 18), match='72px Denmark,serif'>
# <re.Match object; span=(0, 30), match='72px Girls are Weird,monospace'>
# <re.Match object; span=(0, 31), match='72px Girls are Weird,sans-serif'>
# <re.Match object; span=(0, 26), match='72px Girls are Weird,serif'>
# <re.Match object; span=(0, 35), match='72px Channel Left-Slanted,monospace'>
# <re.Match object; span=(0, 36), match='72px Channel Left-Slanted,sans-serif'>
# <re.Match object; span=(0, 31), match='72px Channel Left-Slanted,serif'>
# <re.Match object; span=(0, 36), match='72px Traveling _Typewriter,monospace'>
# <re.Match object; span=(0, 37), match='72px Traveling _Typewriter,sans-serif'>
# <re.Match object; span=(0, 32), match='72px Traveling _Typewriter,serif'>
# <re.Match object; span=(0, 23), match='72px Teletype,monospace'>
# <re.Match object; span=(0, 24), match='72px Teletype,sans-serif'>
# <re.Match object; span=(0, 19), match='72px Teletype,serif'>
# <re.Match object; span=(0, 21), match='72px Cuckoo,monospace'>
# <re.Match object; span=(0, 22), match='72px Cuckoo,sans-serif'>
# <re.Match object; span=(0, 17), match='72px Cuckoo,serif'>
# <re.Match object; span=(0, 24), match='72px MARKETPRO,monospace'>
# <re.Match object; span=(0, 25), match='72px MARKETPRO,sans-serif'>
# <re.Match object; span=(0, 20), match='72px MARKETPRO,serif'>
# <re.Match object; span=(0, 22), match='72px ABIGAIL,monospace'>
# <re.Match object; span=(0, 23), match='72px ABIGAIL,sans-serif'>
# <re.Match object; span=(0, 18), match='72px ABIGAIL,serif'>
# <re.Match object; span=(0, 21), match='72px JACKIE,monospace'>
# <re.Match object; span=(0, 22), match='72px JACKIE,sans-serif'>
# <re.Match object; span=(0, 17), match='72px JACKIE,serif'>
# <re.Match object; span=(0, 35), match='72px Carnivalee Freakshow,monospace'>
# <re.Match object; span=(0, 36), match='72px Carnivalee Freakshow,sans-serif'>
# <re.Match object; span=(0, 31), match='72px Carnivalee Freakshow,serif'>
# <re.Match object; span=(0, 24), match='72px NewZurica,monospace'>
# <re.Match object; span=(0, 25), match='72px NewZurica,sans-serif'>
# <re.Match object; span=(0, 20), match='72px NewZurica,serif'>
# <re.Match object; span=(0, 25), match='72px OldCentury,monospace'>
# <re.Match object; span=(0, 26), match='72px OldCentury,sans-serif'>
# <re.Match object; span=(0, 21), match='72px OldCentury,serif'>
# <re.Match object; span=(0, 25), match='72px LongIsland,monospace'>
# <re.Match object; span=(0, 26), match='72px LongIsland,sans-serif'>
# <re.Match object; span=(0, 21), match='72px LongIsland,serif'>
# <re.Match object; span=(0, 38), match='72px Fontdinerdotcom Sparkly,monospace'>
# <re.Match object; span=(0, 39), match='72px Fontdinerdotcom Sparkly,sans-serif'>
# <re.Match object; span=(0, 34), match='72px Fontdinerdotcom Sparkly,serif'>
# <re.Match object; span=(0, 26), match='72px PAINTSTROKE,monospace'>
# <re.Match object; span=(0, 27), match='72px PAINTSTROKE,sans-serif'>
# <re.Match object; span=(0, 22), match='72px PAINTSTROKE,serif'>
# <re.Match object; span=(0, 30), match='72px Mona Lisa Recut,monospace'>
# <re.Match object; span=(0, 31), match='72px Mona Lisa Recut,sans-serif'>
# <re.Match object; span=(0, 26), match='72px Mona Lisa Recut,serif'>
# <re.Match object; span=(0, 37), match='72px Times New Roman Symbol,monospace'>
# <re.Match object; span=(0, 38), match='72px Times New Roman Symbol,sans-serif'>
# <re.Match object; span=(0, 33), match='72px Times New Roman Symbol,serif'>
# <re.Match object; span=(0, 42), match='72px ESRI Enviro Hazard Incident,monospace'>
# <re.Match object; span=(0, 43), match='72px ESRI Enviro Hazard Incident,sans-serif'>
# <re.Match object; span=(0, 38), match='72px ESRI Enviro Hazard Incident,serif'>
# <re.Match object; span=(0, 26), match='72px TextilePiEF,monospace'>
# <re.Match object; span=(0, 27), match='72px TextilePiEF,sans-serif'>
# <re.Match object; span=(0, 22), match='72px TextilePiEF,serif'>
# <re.Match object; span=(0, 19), match='72px Edda,monospace'>
# <re.Match object; span=(0, 20), match='72px Edda,sans-serif'>
# <re.Match object; span=(0, 15), match='72px Edda,serif'>
# <re.Match object; span=(0, 24), match='72px EcuyerDAX,monospace'>
# <re.Match object; span=(0, 25), match='72px EcuyerDAX,sans-serif'>
# <re.Match object; span=(0, 20), match='72px EcuyerDAX,serif'>
# <re.Match object; span=(0, 38), match='72px Bodoni PosterCompressed,monospace'>
# <re.Match object; span=(0, 39), match='72px Bodoni PosterCompressed,sans-serif'>
# <re.Match object; span=(0, 34), match='72px Bodoni PosterCompressed,serif'>
# <re.Match object; span=(0, 35), match='72px MapInfo Cartographic,monospace'>
# <re.Match object; span=(0, 36), match='72px MapInfo Cartographic,sans-serif'>
# <re.Match object; span=(0, 31), match='72px MapInfo Cartographic,serif'>
# <re.Match object; span=(0, 40), match='72px ESRI NIMA City Graphic LN,monospace'>
# <re.Match object; span=(0, 41), match='72px ESRI NIMA City Graphic LN,sans-serif'>
# <re.Match object; span=(0, 36), match='72px ESRI NIMA City Graphic LN,serif'>
# <re.Match object; span=(0, 25), match='72px Virtual DJ,monospace'>
# <re.Match object; span=(0, 26), match='72px Virtual DJ,sans-serif'>
# <re.Match object; span=(0, 21), match='72px Virtual DJ,serif'>
# <re.Match object; span=(0, 26), match='72px MS SystemEx,monospace'>
# <re.Match object; span=(0, 27), match='72px MS SystemEx,sans-serif'>
# <re.Match object; span=(0, 22), match='72px MS SystemEx,serif'>
# <re.Match object; span=(0, 35), match='72px AdineKirnberg-Script,monospace'>
# <re.Match object; span=(0, 36), match='72px AdineKirnberg-Script,sans-serif'>
# <re.Match object; span=(0, 31), match='72px AdineKirnberg-Script,serif'>
# <re.Match object; span=(0, 22), match='72px Exmouth,monospace'>
# <re.Match object; span=(0, 23), match='72px Exmouth,sans-serif'>
# <re.Match object; span=(0, 18), match='72px Exmouth,serif'>
# <re.Match object; span=(0, 26), match='72px OPENCLASSIC,monospace'>
# <re.Match object; span=(0, 27), match='72px OPENCLASSIC,sans-serif'>
# <re.Match object; span=(0, 22), match='72px OPENCLASSIC,serif'>
# <re.Match object; span=(0, 29), match='72px Sweetly Broken,monospace'>
# <re.Match object; span=(0, 30), match='72px Sweetly Broken,sans-serif'>
# <re.Match object; span=(0, 25), match='72px Sweetly Broken,serif'>
# <re.Match object; span=(0, 28), match='72px English Essay,monospace'>
# <re.Match object; span=(0, 29), match='72px English Essay,sans-serif'>
# <re.Match object; span=(0, 24), match='72px English Essay,serif'>
# <re.Match object; span=(0, 27), match='72px Jenkins v2.0,monospace'>
# <re.Match object; span=(0, 28), match='72px Jenkins v2.0,sans-serif'>
# <re.Match object; span=(0, 23), match='72px Jenkins v2.0,serif'>
# <re.Match object; span=(0, 34), match='72px Architects Daughter,monospace'>
# <re.Match object; span=(0, 35), match='72px Architects Daughter,sans-serif'>
# <re.Match object; span=(0, 30), match='72px Architects Daughter,serif'>
# <re.Match object; span=(0, 20), match='72px Taffy,monospace'>
# <re.Match object; span=(0, 21), match='72px Taffy,sans-serif'>
# <re.Match object; span=(0, 16), match='72px Taffy,serif'>
# <re.Match object; span=(0, 28), match='72px Weltron Urban,monospace'>
# <re.Match object; span=(0, 29), match='72px Weltron Urban,sans-serif'>
# <re.Match object; span=(0, 24), match='72px Weltron Urban,serif'>
# <re.Match object; span=(0, 26), match='72px 1942 report,monospace'>
# <re.Match object; span=(0, 27), match='72px 1942 report,sans-serif'>
# <re.Match object; span=(0, 22), match='72px 1942 report,serif'>
# <re.Match object; span=(0, 18), match='72px Fat,monospace'>
# <re.Match object; span=(0, 19), match='72px Fat,sans-serif'>
# <re.Match object; span=(0, 14), match='72px Fat,serif'>
# <re.Match object; span=(0, 30), match='72px Rod Transparent,monospace'>
# <re.Match object; span=(0, 31), match='72px Rod Transparent,sans-serif'>
# <re.Match object; span=(0, 26), match='72px Rod Transparent,serif'>
# <re.Match object; span=(0, 25), match='72px SimSun-PUA,monospace'>
# <re.Match object; span=(0, 26), match='72px SimSun-PUA,sans-serif'>
# <re.Match object; span=(0, 21), match='72px SimSun-PUA,serif'>
# <re.Match object; span=(0, 43), match='72px Before the Rain Swashes DEMO,monospace'>
# <re.Match object; span=(0, 44), match='72px Before the Rain Swashes DEMO,sans-serif'>
# <re.Match object; span=(0, 39), match='72px Before the Rain Swashes DEMO,serif'>
# <re.Match object; span=(0, 30), match='72px Abraham Lincoln,monospace'>
# <re.Match object; span=(0, 31), match='72px Abraham Lincoln,sans-serif'>
# <re.Match object; span=(0, 26), match='72px Abraham Lincoln,serif'>
# <re.Match object; span=(0, 35), match='72px Opus Japanese Chords,monospace'>
# <re.Match object; span=(0, 36), match='72px Opus Japanese Chords,sans-serif'>
# <re.Match object; span=(0, 31), match='72px Opus Japanese Chords,serif'>
# <re.Match object; span=(0, 27), match='72px Agent Orange,monospace'>
# <re.Match object; span=(0, 28), match='72px Agent Orange,sans-serif'>
# <re.Match object; span=(0, 23), match='72px Agent Orange,serif'>
# <re.Match object; span=(0, 27), match='72px Almonte Snow,monospace'>
# <re.Match object; span=(0, 28), match='72px Almonte Snow,sans-serif'>
# <re.Match object; span=(0, 23), match='72px Almonte Snow,serif'>
# <re.Match object; span=(0, 22), match='72px Luciano,monospace'>
# <re.Match object; span=(0, 23), match='72px Luciano,sans-serif'>
# <re.Match object; span=(0, 18), match='72px Luciano,serif'>
# <re.Match object; span=(0, 30), match='72px HenryMorganHand,monospace'>
# <re.Match object; span=(0, 31), match='72px HenryMorganHand,sans-serif'>
# <re.Match object; span=(0, 26), match='72px HenryMorganHand,serif'>
# <re.Match object; span=(0, 30), match='72px KG Skinny Latte,monospace'>
# <re.Match object; span=(0, 31), match='72px KG Skinny Latte,sans-serif'>
# <re.Match object; span=(0, 26), match='72px KG Skinny Latte,serif'>
# <re.Match object; span=(0, 25), match='72px CANDY INC.,monospace'>
# <re.Match object; span=(0, 26), match='72px CANDY INC.,sans-serif'>
# <re.Match object; span=(0, 21), match='72px CANDY INC.,serif'>
# <re.Match object; span=(0, 23), match='72px Tango BT,monospace'>
# <re.Match object; span=(0, 24), match='72px Tango BT,sans-serif'>
# <re.Match object; span=(0, 19), match='72px Tango BT,serif'>
# <re.Match object; span=(0, 27), match='72px GrutchShaded,monospace'>
# <re.Match object; span=(0, 28), match='72px GrutchShaded,sans-serif'>
# <re.Match object; span=(0, 23), match='72px GrutchShaded,serif'>
# <re.Match object; span=(0, 42), match='72px Segoe Media Center Semibold,monospace'>
# <re.Match object; span=(0, 43), match='72px Segoe Media Center Semibold,sans-serif'>
# <re.Match object; span=(0, 38), match='72px Segoe Media Center Semibold,serif'>
# <re.Match object; span=(0, 19), match='72px Kiev,monospace'>
# <re.Match object; span=(0, 20), match='72px Kiev,sans-serif'>
# <re.Match object; span=(0, 15), match='72px Kiev,serif'>
# <re.Match object; span=(0, 26), match='72px Lobster 1.3,monospace'>
# <re.Match object; span=(0, 27), match='72px Lobster 1.3,sans-serif'>
# <re.Match object; span=(0, 22), match='72px Lobster 1.3,serif'>
# <re.Match object; span=(0, 22), match='72px Tabitha,monospace'>
# <re.Match object; span=(0, 23), match='72px Tabitha,sans-serif'>
# <re.Match object; span=(0, 18), match='72px Tabitha,serif'>
# <re.Match object; span=(0, 21), match='72px Bimini,monospace'>
# <re.Match object; span=(0, 22), match='72px Bimini,sans-serif'>
# <re.Match object; span=(0, 17), match='72px Bimini,serif'>
# <re.Match object; span=(0, 30), match='72px OptimusPrinceps,monospace'>
# <re.Match object; span=(0, 31), match='72px OptimusPrinceps,sans-serif'>
# <re.Match object; span=(0, 26), match='72px OptimusPrinceps,serif'>
# <re.Match object; span=(0, 41), match='72px Ostrich Sans Dashed Medium,monospace'>
# <re.Match object; span=(0, 42), match='72px Ostrich Sans Dashed Medium,sans-serif'>
# <re.Match object; span=(0, 37), match='72px Ostrich Sans Dashed Medium,serif'>
# <re.Match object; span=(0, 32), match='72px DK Crayon Crumble,monospace'>
# <re.Match object; span=(0, 33), match='72px DK Crayon Crumble,sans-serif'>
# <re.Match object; span=(0, 28), match='72px DK Crayon Crumble,serif'>
# <re.Match object; span=(0, 23), match='72px DYMObvba,monospace'>
# <re.Match object; span=(0, 24), match='72px DYMObvba,sans-serif'>
# <re.Match object; span=(0, 19), match='72px DYMObvba,serif'>
# <re.Match object; span=(0, 28), match='72px 28 Days Later,monospace'>
# <re.Match object; span=(0, 29), match='72px 28 Days Later,sans-serif'>
# <re.Match object; span=(0, 24), match='72px 28 Days Later,serif'>
# <re.Match object; span=(0, 22), match='72px Engaged,monospace'>
# <re.Match object; span=(0, 23), match='72px Engaged,sans-serif'>
# <re.Match object; span=(0, 18), match='72px Engaged,serif'>
# <re.Match object; span=(0, 31), match='72px always * forever,monospace'>
# <re.Match object; span=(0, 32), match='72px always * forever,sans-serif'>
# <re.Match object; span=(0, 27), match='72px always * forever,serif'>
# <re.Match object; span=(0, 24), match='72px Loki Cola,monospace'>
# <re.Match object; span=(0, 25), match='72px Loki Cola,sans-serif'>
# <re.Match object; span=(0, 20), match='72px Loki Cola,serif'>
# <re.Match object; span=(0, 26), match='72px Connecticut,monospace'>
# <re.Match object; span=(0, 27), match='72px Connecticut,sans-serif'>
# <re.Match object; span=(0, 22), match='72px Connecticut,serif'>
# <re.Match object; span=(0, 31), match='72px Pea Ellie Bellie,monospace'>
# <re.Match object; span=(0, 32), match='72px Pea Ellie Bellie,sans-serif'>
# <re.Match object; span=(0, 27), match='72px Pea Ellie Bellie,serif'>
# <re.Match object; span=(0, 19), match='72px Utah,monospace'>
# <re.Match object; span=(0, 20), match='72px Utah,sans-serif'>
# <re.Match object; span=(0, 15), match='72px Utah,serif'>
# <re.Match object; span=(0, 19), match='72px MICR,monospace'>
# <re.Match object; span=(0, 20), match='72px MICR,sans-serif'>
# <re.Match object; span=(0, 15), match='72px MICR,serif'>
# <re.Match object; span=(0, 29), match='72px Things We Said,monospace'>
# <re.Match object; span=(0, 30), match='72px Things We Said,sans-serif'>
# <re.Match object; span=(0, 25), match='72px Things We Said,serif'>
# <re.Match object; span=(0, 30), match='72px Stars & Stripes,monospace'>
# <re.Match object; span=(0, 31), match='72px Stars & Stripes,sans-serif'>
# <re.Match object; span=(0, 26), match='72px Stars & Stripes,serif'>
# <re.Match object; span=(0, 22), match='72px Rope MF,monospace'>
# <re.Match object; span=(0, 23), match='72px Rope MF,sans-serif'>
# <re.Match object; span=(0, 18), match='72px Rope MF,serif'>
# <re.Match object; span=(0, 28), match='72px Lato Hairline,monospace'>
# <re.Match object; span=(0, 29), match='72px Lato Hairline,sans-serif'>
# <re.Match object; span=(0, 24), match='72px Lato Hairline,serif'>
# <re.Match object; span=(0, 29), match='72px GilliesGotDLig,monospace'>
# <re.Match object; span=(0, 30), match='72px GilliesGotDLig,sans-serif'>
# <re.Match object; span=(0, 25), match='72px GilliesGotDLig,serif'>
# <re.Match object; span=(0, 38), match='72px Antique Olive CompactPS,monospace'>
# <re.Match object; span=(0, 39), match='72px Antique Olive CompactPS,sans-serif'>
# <re.Match object; span=(0, 34), match='72px Antique Olive CompactPS,serif'>
# <re.Match object; span=(0, 30), match='72px CaslonNo540SwaD,monospace'>
# <re.Match object; span=(0, 31), match='72px CaslonNo540SwaD,sans-serif'>
# <re.Match object; span=(0, 26), match='72px CaslonNo540SwaD,serif'>
# <re.Match object; span=(0, 30), match='72px SF Movie Poster,monospace'>
# <re.Match object; span=(0, 31), match='72px SF Movie Poster,sans-serif'>
# <re.Match object; span=(0, 26), match='72px SF Movie Poster,serif'>
# <re.Match object; span=(0, 25), match='72px CaslonAntT,monospace'>
# <re.Match object; span=(0, 26), match='72px CaslonAntT,sans-serif'>
# <re.Match object; span=(0, 21), match='72px CaslonAntT,serif'>
# <re.Match object; span=(0, 27), match='72px Josefin Slab,monospace'>
# <re.Match object; span=(0, 28), match='72px Josefin Slab,sans-serif'>
# <re.Match object; span=(0, 23), match='72px Josefin Slab,serif'>
# <re.Match object; span=(0, 26), match='72px PegsannaHMK,monospace'>
# <re.Match object; span=(0, 27), match='72px PegsannaHMK,sans-serif'>
# <re.Match object; span=(0, 22), match='72px PegsannaHMK,serif'>
# <re.Match object; span=(0, 36), match='72px Impact Label Reversed,monospace'>
# <re.Match object; span=(0, 37), match='72px Impact Label Reversed,sans-serif'>
# <re.Match object; span=(0, 32), match='72px Impact Label Reversed,serif'>
# <re.Match object; span=(0, 21), match='72px Ubuntu,monospace'>
# <re.Match object; span=(0, 22), match='72px Ubuntu,sans-serif'>
# <re.Match object; span=(0, 17), match='72px Ubuntu,serif'>
# <re.Match object; span=(0, 32), match='72px Oh {Photo} Shoot!,monospace'>
# <re.Match object; span=(0, 33), match='72px Oh {Photo} Shoot!,sans-serif'>
# <re.Match object; span=(0, 28), match='72px Oh {Photo} Shoot!,serif'>
# <re.Match object; span=(0, 29), match='72px Deftone Stylus,monospace'>
# <re.Match object; span=(0, 30), match='72px Deftone Stylus,sans-serif'>
# <re.Match object; span=(0, 25), match='72px Deftone Stylus,serif'>
# <re.Match object; span=(0, 23), match='72px CluffHmk,monospace'>
# <re.Match object; span=(0, 24), match='72px CluffHmk,sans-serif'>
# <re.Match object; span=(0, 19), match='72px CluffHmk,serif'>
# <re.Match object; span=(0, 33), match='72px Incised901 BdCn BT,monospace'>
# <re.Match object; span=(0, 34), match='72px Incised901 BdCn BT,sans-serif'>
# <re.Match object; span=(0, 29), match='72px Incised901 BdCn BT,serif'>
# <re.Match object; span=(0, 29), match='72px Respective 2.0,monospace'>
# <re.Match object; span=(0, 30), match='72px Respective 2.0,sans-serif'>
# <re.Match object; span=(0, 25), match='72px Respective 2.0,serif'>
# <re.Match object; span=(0, 27), match='72px Parry Hotter,monospace'>
# <re.Match object; span=(0, 28), match='72px Parry Hotter,sans-serif'>
# <re.Match object; span=(0, 23), match='72px Parry Hotter,serif'>
# <re.Match object; span=(0, 27), match='72px NotnorvalHmk,monospace'>
# <re.Match object; span=(0, 28), match='72px NotnorvalHmk,sans-serif'>
# <re.Match object; span=(0, 23), match='72px NotnorvalHmk,serif'>
# <re.Match object; span=(0, 25), match='72px odstemplik,monospace'>
# <re.Match object; span=(0, 26), match='72px odstemplik,sans-serif'>
# <re.Match object; span=(0, 21), match='72px odstemplik,serif'>
# <re.Match object; span=(0, 27), match='72px Ethnocentric,monospace'>
# <re.Match object; span=(0, 28), match='72px Ethnocentric,sans-serif'>
# <re.Match object; span=(0, 23), match='72px Ethnocentric,serif'>
# <re.Match object; span=(0, 29), match='72px Miserably Lose,monospace'>
# <re.Match object; span=(0, 30), match='72px Miserably Lose,sans-serif'>
# <re.Match object; span=(0, 25), match='72px Miserably Lose,serif'>
# <re.Match object; span=(0, 28), match='72px SAS Monospace,monospace'>
# <re.Match object; span=(0, 29), match='72px SAS Monospace,sans-serif'>
# <re.Match object; span=(0, 24), match='72px SAS Monospace,serif'>
# <re.Match object; span=(0, 25), match='72px Stonehenge,monospace'>
# <re.Match object; span=(0, 26), match='72px Stonehenge,sans-serif'>
# <re.Match object; span=(0, 21), match='72px Stonehenge,serif'>
# <re.Match object; span=(0, 27), match='72px BethsCuteHmk,monospace'>
# <re.Match object; span=(0, 28), match='72px BethsCuteHmk,sans-serif'>
# <re.Match object; span=(0, 23), match='72px BethsCuteHmk,serif'>
# <re.Match object; span=(0, 34), match='72px BixAntiqueScriptHmk,monospace'>
# <re.Match object; span=(0, 35), match='72px BixAntiqueScriptHmk,sans-serif'>
# <re.Match object; span=(0, 30), match='72px BixAntiqueScriptHmk,serif'>
# <re.Match object; span=(0, 33), match='72px MicrogrammaDMedExt,monospace'>
# <re.Match object; span=(0, 34), match='72px MicrogrammaDMedExt,sans-serif'>
# <re.Match object; span=(0, 29), match='72px MicrogrammaDMedExt,serif'>
# <re.Match object; span=(0, 26), match='72px StarbabeHmk,monospace'>
# <re.Match object; span=(0, 27), match='72px StarbabeHmk,sans-serif'>
# <re.Match object; span=(0, 22), match='72px StarbabeHmk,serif'>
# <re.Match object; span=(0, 23), match='72px FFF Tusj,monospace'>
# <re.Match object; span=(0, 24), match='72px FFF Tusj,sans-serif'>
# <re.Match object; span=(0, 19), match='72px FFF Tusj,serif'>
# <re.Match object; span=(0, 30), match='72px BoogieWoogieHmk,monospace'>
# <re.Match object; span=(0, 31), match='72px BoogieWoogieHmk,sans-serif'>
# <re.Match object; span=(0, 26), match='72px BoogieWoogieHmk,serif'>
# <re.Match object; span=(0, 31), match='72px Star Jedi Hollow,monospace'>
# <re.Match object; span=(0, 32), match='72px Star Jedi Hollow,sans-serif'>
# <re.Match object; span=(0, 27), match='72px Star Jedi Hollow,serif'>
# <re.Match object; span=(0, 28), match='72px Eight Fifteen,monospace'>
# <re.Match object; span=(0, 29), match='72px Eight Fifteen,sans-serif'>
# <re.Match object; span=(0, 24), match='72px Eight Fifteen,serif'>
# <re.Match object; span=(0, 21), match='72px Ribbon,monospace'>
# <re.Match object; span=(0, 22), match='72px Ribbon,sans-serif'>
# <re.Match object; span=(0, 17), match='72px Ribbon,serif'>
# <re.Match object; span=(0, 30), match='72px Helsinki Narrow,monospace'>
# <re.Match object; span=(0, 31), match='72px Helsinki Narrow,sans-serif'>
# <re.Match object; span=(0, 26), match='72px Helsinki Narrow,serif'>
# <re.Match object; span=(0, 24), match='72px San Diego,monospace'>
# <re.Match object; span=(0, 25), match='72px San Diego,sans-serif'>
# <re.Match object; span=(0, 20), match='72px San Diego,serif'>
# <re.Match object; span=(0, 21), match='72px Jewels,monospace'>
# <re.Match object; span=(0, 22), match='72px Jewels,sans-serif'>
# <re.Match object; span=(0, 17), match='72px Jewels,serif'>
# <re.Match object; span=(0, 35), match='72px Baskerville-Old-Face,monospace'>
# <re.Match object; span=(0, 36), match='72px Baskerville-Old-Face,sans-serif'>
# <re.Match object; span=(0, 31), match='72px Baskerville-Old-Face,serif'>
# <re.Match object; span=(0, 20), match='72px OCR-A,monospace'>
# <re.Match object; span=(0, 21), match='72px OCR-A,sans-serif'>
# <re.Match object; span=(0, 16), match='72px OCR-A,serif'>
# <re.Match object; span=(0, 23), match='72px OttumHmk,monospace'>
# <re.Match object; span=(0, 24), match='72px OttumHmk,sans-serif'>
# <re.Match object; span=(0, 19), match='72px OttumHmk,serif'>
# <re.Match object; span=(0, 34), match='72px Mr and Mrs Popsicle,monospace'>
# <re.Match object; span=(0, 35), match='72px Mr and Mrs Popsicle,sans-serif'>
# <re.Match object; span=(0, 30), match='72px Mr and Mrs Popsicle,serif'>
# <re.Match object; span=(0, 34), match='72px Symbol Tiger Expert,monospace'>
# <re.Match object; span=(0, 35), match='72px Symbol Tiger Expert,sans-serif'>
# <re.Match object; span=(0, 30), match='72px Symbol Tiger Expert,serif'>
# <re.Match object; span=(0, 25), match='72px URWAlcuinT,monospace'>
# <re.Match object; span=(0, 26), match='72px URWAlcuinT,sans-serif'>
# <re.Match object; span=(0, 21), match='72px URWAlcuinT,serif'>
# <re.Match object; span=(0, 29), match='72px DynameBlackSSK,monospace'>
# <re.Match object; span=(0, 30), match='72px DynameBlackSSK,sans-serif'>
# <re.Match object; span=(0, 27), match='100px -no-font-family-here-'>
# <re.Match object; span=(0, 27), match='100px -no-font-family-here-'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 11), match='123px Arial'>
# <re.Match object; span=(0, 11), match='123px Arial'>
# <re.Match object; span=(0, 11), match='106px Arial'>
# <re.Match object; span=(0, 11), match='118px Arial'>
# <re.Match object; span=(0, 11), match='114px Arial'>
# <re.Match object; span=(0, 11), match='108px Arial'>
# <re.Match object; span=(0, 11), match='123px Arial'>
# <re.Match object; span=(0, 11), match='123px Arial'>
# <re.Match object; span=(0, 11), match='106px Arial'>
# <re.Match object; span=(0, 11), match='118px Arial'>
# <re.Match object; span=(0, 11), match='114px Arial'>
# <re.Match object; span=(0, 11), match='108px Arial'>
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 66), match='600 normal 19px BogleWeb,Helvetica Neue,Helvetica>
# <re.Match object; span=(0, 66), match='400 normal 44px BogleWeb,Helvetica Neue,Helvetica>
# <re.Match object; span=(0, 66), match='400 normal 19px BogleWeb,Helvetica Neue,Helvetica>
# <re.Match object; span=(0, 66), match='600 normal 19px BogleWeb,Helvetica Neue,Helvetica>
# <re.Match object; span=(0, 66), match='400 normal 44px BogleWeb,Helvetica Neue,Helvetica>
# <re.Match object; span=(0, 66), match='400 normal 19px BogleWeb,Helvetica Neue,Helvetica>
# <re.Match object; span=(0, 66), match='400 normal 36px BogleWeb,Helvetica Neue,Helvetica>
# <re.Match object; span=(0, 66), match='400 normal 18px BogleWeb,Helvetica Neue,Helvetica>
# <re.Match object; span=(0, 41), match='133.33333333333334px LorZarozzorArbgwaoth'>
# <re.Match object; span=(0, 41), match='133.33333333333334px LorZarozzorArbgwaoth'>
# <re.Match object; span=(0, 41), match='133.33333333333334px LorZarozzorArbgwaoth'>
# <re.Match object; span=(0, 41), match='133.33333333333334px LorZarozzorArbgwaoth'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 51), match='400 50px "gauge-mono", Helvetica, Arial, sans-ser>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 12), match="16px 'Arial'">
# <re.Match object; span=(0, 12), match="16px 'Arial'">
# <re.Match object; span=(0, 12), match="70px 'Arial'">
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 10), match='32px Arial'>
# <re.Match object; span=(0, 41), match='133.33333333333334px LorZarozzorArbgwaoth'>
# <re.Match object; span=(0, 41), match='133.33333333333334px LorZarozzorArbgwaoth'>
# <re.Match object; span=(0, 41), match='133.33333333333334px LorZarozzorArbgwaoth'>
# <re.Match object; span=(0, 41), match='133.33333333333334px LorZarozzorArbgwaoth'>
# <re.Match object; span=(0, 15), match='500 300px Arial'>
# <re.Match object; span=(0, 27), match='500 300px "SFNSText", Arial'>
# <re.Match object; span=(0, 27), match='500 300px "SFNSText", Arial'>
# <re.Match object; span=(0, 25), match='500 300px "Comic Sans MS"'>
# <re.Match object; span=(0, 48), match='500 300px "SFNSDisplay-Numbers", "Comic Sans MS"'>
# <re.Match object; span=(0, 17), match='400 26px SFNSText'>
# <re.Match object; span=(0, 17), match='400 25px SFNSText'>
# <re.Match object; span=(0, 17), match='400 24px SFNSText'>
# <re.Match object; span=(0, 17), match='400 23px SFNSText'>
# <re.Match object; span=(0, 17), match='400 22px SFNSText'>
# <re.Match object; span=(0, 17), match='400 21px SFNSText'>
# <re.Match object; span=(0, 17), match='400 20px SFNSText'>
# <re.Match object; span=(0, 17), match='400 19px SFNSText'>
# <re.Match object; span=(0, 17), match='400 18px SFNSText'>
# <re.Match object; span=(0, 17), match='400 17px SFNSText'>
# <re.Match object; span=(0, 28), match='300 91px SFNSDisplay-Numbers'>
# <re.Match object; span=(0, 17), match='400 26px SFNSText'>
# <re.Match object; span=(0, 17), match='400 25px SFNSText'>
# <re.Match object; span=(0, 17), match='400 24px SFNSText'>
# <re.Match object; span=(0, 17), match='400 23px SFNSText'>
# <re.Match object; span=(0, 17), match='400 22px SFNSText'>
# <re.Match object; span=(0, 17), match='400 21px SFNSText'>
# <re.Match object; span=(0, 17), match='400 20px SFNSText'>
# <re.Match object; span=(0, 17), match='400 19px SFNSText'>
# <re.Match object; span=(0, 17), match='400 18px SFNSText'>
# <re.Match object; span=(0, 17), match='400 17px SFNSText'>
# <re.Match object; span=(0, 28), match='300 91px SFNSDisplay-Numbers'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 9), match='18pt Sans'>
# <re.Match object; span=(0, 29), match="50px 'sans-serif', sans-serif">
# <re.Match object; span=(0, 19), match="50px 'serif', serif">
# <re.Match object; span=(0, 30), match="50px 'Andale Mono', sans-serif">
# <re.Match object; span=(0, 25), match="50px 'Andale Mono', serif">
# <re.Match object; span=(0, 31), match="50px 'Arial Narrow', sans-serif">
# <re.Match object; span=(0, 26), match="50px 'Arial Narrow', serif">
# <re.Match object; span=(0, 35), match="50px 'Arial Unicode MS', sans-serif">
# <re.Match object; span=(0, 30), match="50px 'Arial Unicode MS', serif">
# <re.Match object; span=(0, 25), match="50px 'Batang', sans-serif">
# <re.Match object; span=(0, 20), match="50px 'Batang', serif">
# <re.Match object; span=(0, 26), match="50px 'Bell MT', sans-serif">
# <re.Match object; span=(0, 21), match="50px 'Bell MT', serif">
# <re.Match object; span=(0, 31), match="50px 'Brush Script', sans-serif">
# <re.Match object; span=(0, 26), match="50px 'Brush Script', serif">
# <re.Match object; span=(0, 34), match="50px 'Brush Script MT', sans-serif">
# <re.Match object; span=(0, 29), match="50px 'Brush Script MT', serif">
# <re.Match object; span=(0, 26), match="50px 'Calibri', sans-serif">
# <re.Match object; span=(0, 21), match="50px 'Calibri', serif">
# <re.Match object; span=(0, 26), match="50px 'Charter', sans-serif">
# <re.Match object; span=(0, 21), match="50px 'Charter', serif">
# <re.Match object; span=(0, 26), match="50px 'Courier', sans-serif">
# <re.Match object; span=(0, 21), match="50px 'Courier', serif">
# <re.Match object; span=(0, 30), match="50px 'Courier New', sans-serif">
# <re.Match object; span=(0, 25), match="50px 'Courier New', serif">
# <re.Match object; span=(0, 27), match="50px 'Curlz MT', sans-serif">
# <re.Match object; span=(0, 22), match="50px 'Curlz MT', serif">
# <re.Match object; span=(0, 30), match="50px 'DejaVu Sans', sans-serif">
# <re.Match object; span=(0, 25), match="50px 'DejaVu Sans', serif">
# <re.Match object; span=(0, 35), match="50px 'DejaVu Sans Mono', sans-serif">
# <re.Match object; span=(0, 41), match="50px 'DejaVu Serif Condensed', sans-serif">
# <re.Match object; span=(0, 36), match="50px 'DejaVu Serif Condensed', serif">
# <re.Match object; span=(0, 29), match="50px 'Droid Sans', sans-serif">
# <re.Match object; span=(0, 24), match="50px 'Droid Sans', serif">
# <re.Match object; span=(0, 38), match="50px 'Droid Sans Fallback', sans-serif">
# <re.Match object; span=(0, 33), match="50px 'Droid Sans Fallback', serif">
# <re.Match object; span=(0, 30), match="50px 'Droid Serif', sans-serif">
# <re.Match object; span=(0, 25), match="50px 'Droid Serif', serif">
# <re.Match object; span=(0, 24), match="50px 'Forte', sans-serif">
# <re.Match object; span=(0, 19), match="50px 'Forte', serif">
# <re.Match object; span=(0, 25), match="50px 'Futura', sans-serif">
# <re.Match object; span=(0, 20), match="50px 'Futura', serif">
# <re.Match object; span=(0, 25), match="50px 'Geneva', sans-serif">
# <re.Match object; span=(0, 20), match="50px 'Geneva', serif">
# <re.Match object; span=(0, 22), match="50px 'Hei', sans-serif">
# <re.Match object; span=(0, 17), match="50px 'Hei', serif">
# <re.Match object; span=(0, 29), match="50px 'Leelawadee', sans-serif">
# <re.Match object; span=(0, 24), match="50px 'Leelawadee', serif">
# <re.Match object; span=(0, 29), match="50px 'Levenim MT', sans-serif">
# <re.Match object; span=(0, 24), match="50px 'Levenim MT', serif">
# <re.Match object; span=(0, 34), match="50px 'Liberation Sans', sans-serif">
# <re.Match object; span=(0, 29), match="50px 'Liberation Sans', serif">
# <re.Match object; span=(0, 41), match="50px 'Liberation Sans Narrow', sans-serif">
# <re.Match object; span=(0, 36), match="50px 'Liberation Sans Narrow', serif">
# <re.Match object; span=(0, 26), match="50px 'Marlett', sans-serif">
# <re.Match object; span=(0, 21), match="50px 'Marlett', serif">
# <re.Match object; span=(0, 28), match="50px 'Meiryo UI', sans-serif">
# <re.Match object; span=(0, 23), match="50px 'Meiryo UI', serif">
# <re.Match object; span=(0, 35), match="50px 'Microsoft Uighur', sans-serif">
# <re.Match object; span=(0, 30), match="50px 'Microsoft Uighur', serif">
# <re.Match object; span=(0, 37), match="50px 'Microsoft YaHei UI', sans-serif">
# ...
# <re.Match object; span=(0, 15), match='72px Utah,serif'>
# <re.Match object; span=(0, 19), match='72px MICR,monospace'>
# <re.Match object; span=(0, 20), match='72px MICR,sans-serif'>
# <re.Match object; span=(0, 15), match='72px MICR,serif'>
# <re.Match object; span=(0, 29), match='72px Things We Said,monospace'>
# <re.Match object; span=(0, 30), match='72px Things We Said,sans-serif'>
# <re.Match object; span=(0, 25), match='72px Things We Said,serif'>
# <re.Match object; span=(0, 30), match='72px Stars & Stripes,monospace'>
# <re.Match object; span=(0, 31), match='72px Stars & Stripes,sans-serif'>
# <re.Match object; span=(0, 26), match='72px Stars & Stripes,serif'>
# <re.Match object; span=(0, 22), match='72px Rope MF,monospace'>
# <re.Match object; span=(0, 23), match='72px Rope MF,sans-serif'>
# <re.Match object; span=(0, 18), match='72px Rope MF,serif'>
# <re.Match object; span=(0, 28), match='72px Lato Hairline,monospace'>
# <re.Match object; span=(0, 29), match='72px Lato Hairline,sans-serif'>
# <re.Match object; span=(0, 24), match='72px Lato Hairline,serif'>
# <re.Match object; span=(0, 29), match='72px GilliesGotDLig,monospace'>
# <re.Match object; span=(0, 30), match='72px GilliesGotDLig,sans-serif'>
# <re.Match object; span=(0, 25), match='72px GilliesGotDLig,serif'>
# <re.Match object; span=(0, 38), match='72px Antique Olive CompactPS,monospace'>
# <re.Match object; span=(0, 39), match='72px Antique Olive CompactPS,sans-serif'>
# <re.Match object; span=(0, 34), match='72px Antique Olive CompactPS,serif'>
# <re.Match object; span=(0, 30), match='72px CaslonNo540SwaD,monospace'>
# <re.Match object; span=(0, 31), match='72px CaslonNo540SwaD,sans-serif'>
# <re.Match object; span=(0, 26), match='72px CaslonNo540SwaD,serif'>
# <re.Match object; span=(0, 30), match='72px SF Movie Poster,monospace'>
# <re.Match object; span=(0, 31), match='72px SF Movie Poster,sans-serif'>
# <re.Match object; span=(0, 26), match='72px SF Movie Poster,serif'>
# <re.Match object; span=(0, 25), match='72px CaslonAntT,monospace'>
# <re.Match object; span=(0, 26), match='72px CaslonAntT,sans-serif'>
# <re.Match object; span=(0, 21), match='72px CaslonAntT,serif'>
# <re.Match object; span=(0, 27), match='72px Josefin Slab,monospace'>
# <re.Match object; span=(0, 28), match='72px Josefin Slab,sans-serif'>
# <re.Match object; span=(0, 23), match='72px Josefin Slab,serif'>
# <re.Match object; span=(0, 26), match='72px PegsannaHMK,monospace'>
# <re.Match object; span=(0, 27), match='72px PegsannaHMK,sans-serif'>
# <re.Match object; span=(0, 22), match='72px PegsannaHMK,serif'>
# <re.Match object; span=(0, 36), match='72px Impact Label Reversed,monospace'>
# <re.Match object; span=(0, 37), match='72px Impact Label Reversed,sans-serif'>
# <re.Match object; span=(0, 32), match='72px Impact Label Reversed,serif'>
# <re.Match object; span=(0, 21), match='72px Ubuntu,monospace'>
# <re.Match object; span=(0, 22), match='72px Ubuntu,sans-serif'>
# <re.Match object; span=(0, 17), match='72px Ubuntu,serif'>
# <re.Match object; span=(0, 32), match='72px Oh {Photo} Shoot!,monospace'>
# <re.Match object; span=(0, 33), match='72px Oh {Photo} Shoot!,sans-serif'>
# <re.Match object; span=(0, 28), match='72px Oh {Photo} Shoot!,serif'>
# <re.Match object; span=(0, 29), match='72px Deftone Stylus,monospace'>
# <re.Match object; span=(0, 30), match='72px Deftone Stylus,sans-serif'>
# <re.Match object; span=(0, 25), match='72px Deftone Stylus,serif'>
# <re.Match object; span=(0, 23), match='72px CluffHmk,monospace'>
# <re.Match object; span=(0, 24), match='72px CluffHmk,sans-serif'>
# <re.Match object; span=(0, 19), match='72px CluffHmk,serif'>
# <re.Match object; span=(0, 33), match='72px Incised901 BdCn BT,monospace'>
# <re.Match object; span=(0, 34), match='72px Incised901 BdCn BT,sans-serif'>
# <re.Match object; span=(0, 29), match='72px Incised901 BdCn BT,serif'>
# <re.Match object; span=(0, 29), match='72px Respective 2.0,monospace'>
# <re.Match object; span=(0, 30), match='72px Respective 2.0,sans-serif'>
# <re.Match object; span=(0, 25), match='72px Respective 2.0,serif'>
# <re.Match object; span=(0, 27), match='72px Parry Hotter,monospace'>
# <re.Match object; span=(0, 28), match='72px Parry Hotter,sans-serif'>
# <re.Match object; span=(0, 23), match='72px Parry Hotter,serif'>
# <re.Match object; span=(0, 27), match='72px NotnorvalHmk,monospace'>
# <re.Match object; span=(0, 28), match='72px NotnorvalHmk,sans-serif'>
# <re.Match object; span=(0, 23), match='72px NotnorvalHmk,serif'>
# <re.Match object; span=(0, 25), match='72px odstemplik,monospace'>
# <re.Match object; span=(0, 26), match='72px odstemplik,sans-serif'>
# <re.Match object; span=(0, 21), match='72px odstemplik,serif'>
# <re.Match object; span=(0, 27), match='72px Ethnocentric,monospace'>
# <re.Match object; span=(0, 28), match='72px Ethnocentric,sans-serif'>
# <re.Match object; span=(0, 23), match='72px Ethnocentric,serif'>
# <re.Match object; span=(0, 29), match='72px Miserably Lose,monospace'>
# <re.Match object; span=(0, 30), match='72px Miserably Lose,sans-serif'>
# <re.Match object; span=(0, 25), match='72px Miserably Lose,serif'>
# <re.Match object; span=(0, 28), match='72px SAS Monospace,monospace'>
# <re.Match object; span=(0, 29), match='72px SAS Monospace,sans-serif'>
# <re.Match object; span=(0, 24), match='72px SAS Monospace,serif'>
# <re.Match object; span=(0, 25), match='72px Stonehenge,monospace'>
# <re.Match object; span=(0, 26), match='72px Stonehenge,sans-serif'>
# <re.Match object; span=(0, 21), match='72px Stonehenge,serif'>
# <re.Match object; span=(0, 27), match='72px BethsCuteHmk,monospace'>
# <re.Match object; span=(0, 28), match='72px BethsCuteHmk,sans-serif'>
# <re.Match object; span=(0, 23), match='72px BethsCuteHmk,serif'>
# <re.Match object; span=(0, 34), match='72px BixAntiqueScriptHmk,monospace'>
# <re.Match object; span=(0, 35), match='72px BixAntiqueScriptHmk,sans-serif'>
# <re.Match object; span=(0, 30), match='72px BixAntiqueScriptHmk,serif'>
# <re.Match object; span=(0, 33), match='72px MicrogrammaDMedExt,monospace'>
# <re.Match object; span=(0, 34), match='72px MicrogrammaDMedExt,sans-serif'>
# <re.Match object; span=(0, 29), match='72px MicrogrammaDMedExt,serif'>
# <re.Match object; span=(0, 26), match='72px StarbabeHmk,monospace'>
# <re.Match object; span=(0, 27), match='72px StarbabeHmk,sans-serif'>
# <re.Match object; span=(0, 22), match='72px StarbabeHmk,serif'>
# <re.Match object; span=(0, 23), match='72px FFF Tusj,monospace'>
# <re.Match object; span=(0, 24), match='72px FFF Tusj,sans-serif'>
# <re.Match object; span=(0, 19), match='72px FFF Tusj,serif'>
# <re.Match object; span=(0, 30), match='72px BoogieWoogieHmk,monospace'>
# <re.Match object; span=(0, 31), match='72px BoogieWoogieHmk,sans-serif'>
# <re.Match object; span=(0, 26), match='72px BoogieWoogieHmk,serif'>
# <re.Match object; span=(0, 31), match='72px Star Jedi Hollow,monospace'>
# <re.Match object; span=(0, 32), match='72px Star Jedi Hollow,sans-serif'>
# <re.Match object; span=(0, 27), match='72px Star Jedi Hollow,serif'>
# <re.Match object; span=(0, 28), match='72px Eight Fifteen,monospace'>
# <re.Match object; span=(0, 29), match='72px Eight Fifteen,sans-serif'>
# <re.Match object; span=(0, 24), match='72px Eight Fifteen,serif'>
# <re.Match object; span=(0, 21), match='72px Ribbon,monospace'>
# <re.Match object; span=(0, 22), match='72px Ribbon,sans-serif'>
# <re.Match object; span=(0, 17), match='72px Ribbon,serif'>
# <re.Match object; span=(0, 30), match='72px Helsinki Narrow,monospace'>
# <re.Match object; span=(0, 31), match='72px Helsinki Narrow,sans-serif'>
# <re.Match object; span=(0, 26), match='72px Helsinki Narrow,serif'>
# <re.Match object; span=(0, 24), match='72px San Diego,monospace'>
# <re.Match object; span=(0, 25), match='72px San Diego,sans-serif'>
# <re.Match object; span=(0, 20), match='72px San Diego,serif'>
# <re.Match object; span=(0, 21), match='72px Jewels,monospace'>
# <re.Match object; span=(0, 22), match='72px Jewels,sans-serif'>
# <re.Match object; span=(0, 17), match='72px Jewels,serif'>
# <re.Match object; span=(0, 35), match='72px Baskerville-Old-Face,monospace'>
# <re.Match object; span=(0, 36), match='72px Baskerville-Old-Face,sans-serif'>
# <re.Match object; span=(0, 31), match='72px Baskerville-Old-Face,serif'>
# <re.Match object; span=(0, 20), match='72px OCR-A,monospace'>
# <re.Match object; span=(0, 21), match='72px OCR-A,sans-serif'>
# <re.Match object; span=(0, 16), match='72px OCR-A,serif'>
# <re.Match object; span=(0, 23), match='72px OttumHmk,monospace'>
# <re.Match object; span=(0, 24), match='72px OttumHmk,sans-serif'>
# <re.Match object; span=(0, 19), match='72px OttumHmk,serif'>
# <re.Match object; span=(0, 34), match='72px Mr and Mrs Popsicle,monospace'>
# <re.Match object; span=(0, 35), match='72px Mr and Mrs Popsicle,sans-serif'>
# <re.Match object; span=(0, 30), match='72px Mr and Mrs Popsicle,serif'>
# <re.Match object; span=(0, 34), match='72px Symbol Tiger Expert,monospace'>
# <re.Match object; span=(0, 35), match='72px Symbol Tiger Expert,sans-serif'>
# <re.Match object; span=(0, 30), match='72px Symbol Tiger Expert,serif'>
# <re.Match object; span=(0, 25), match='72px URWAlcuinT,monospace'>
# <re.Match object; span=(0, 26), match='72px URWAlcuinT,sans-serif'>
# <re.Match object; span=(0, 21), match='72px URWAlcuinT,serif'>
# <re.Match object; span=(0, 29), match='72px DynameBlackSSK,monospace'>
# <re.Match object; span=(0, 30), match='72px DynameBlackSSK,sans-serif'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 15), match="18pt 'BKNOFONT'">
# <re.Match object; span=(0, 10), match='11pt Arial'>
# <re.Match object; span=(0, 15), match="15pt 'BKNOFONT'">
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 15), match="18pt 'BKNOFONT'">
# <re.Match object; span=(0, 10), match='11pt Arial'>
# <re.Match object; span=(0, 15), match="15pt 'BKNOFONT'">
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 15), match="18pt 'BKNOFONT'">
# <re.Match object; span=(0, 10), match='11pt Arial'>
# <re.Match object; span=(0, 15), match="15pt 'BKNOFONT'">
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 15), match="18pt 'BKNOFONT'">
# <re.Match object; span=(0, 10), match='11pt Arial'>
# <re.Match object; span=(0, 15), match="15pt 'BKNOFONT'">
# <re.Match object; span=(0, 11), match='100pt Arial'>
# <re.Match object; span=(0, 11), match='100pt Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 10), match='32px Arial'>
# <re.Match object; span=(0, 26), match='100px Fredericka the Great'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 24px arial'>
# <re.Match object; span=(0, 11), match=' 24px arial'>
# <re.Match object; span=(0, 11), match=' 24px arial'>
# <re.Match object; span=(0, 11), match=' 24px arial'>
# <re.Match object; span=(0, 11), match=' 24px arial'>
# <re.Match object; span=(0, 11), match=' 24px arial'>
# <re.Match object; span=(0, 11), match=' 24px arial'>
# <re.Match object; span=(0, 11), match=' 24px arial'>
# <re.Match object; span=(0, 11), match=' 24px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 24px arial'>
# <re.Match object; span=(0, 11), match=' 24px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 11), match=' 36px arial'>
# <re.Match object; span=(0, 10), match='100px Lato'>
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 12), match="16px 'Arial'">
# <re.Match object; span=(0, 12), match="16px 'Arial'">
# <re.Match object; span=(0, 14), match='600 32px Arial'>
# <re.Match object; span=(0, 14), match='600 32px Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 12), match="70px 'Arial'">
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 15), match="18pt 'BKNOFONT'">
# <re.Match object; span=(0, 10), match='11pt Arial'>
# <re.Match object; span=(0, 15), match="15pt 'BKNOFONT'">
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 15), match="18pt 'BKNOFONT'">
# <re.Match object; span=(0, 10), match='11pt Arial'>
# <re.Match object; span=(0, 15), match="15pt 'BKNOFONT'">
# <re.Match object; span=(0, 33), match='14px droid sand mono,ubuntu,serif'>
# <re.Match object; span=(0, 31), match='12pt helvetica,arial,sans-serif'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 10), match='14px Arial'>
# <re.Match object; span=(0, 21), match='11pt no-real-font-123'>
# <re.Match object; span=(0, 10), match='18pt Arial'>
# <re.Match object; span=(0, 12), match="14px 'Arial'">
# /tmp/ipykernel_58029/2333624771.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['value_b'] = test.apply(lambda row: regex_value(row), axis=1)

# %%
test
# Out:
#             id  crawl_id  visit_id  \
# 1144      1145         3         3
# 1174      1175         3         3
# 1182      1183         3         3
# 1194      1195         3         3
# 1224      1225         3         3
# ...        ...       ...       ...
# 492372  492373         2       971
# 492404  492405         2       971
# 495009  495010         4       985
# 495012  495013         4       985
# 497272  497273        13       997
#
#                                                script_url script_line  \
# 1144    https://static.xx.fbcdn.net/rsrc.php/v3iYXl4/y...          19
# 1174    https://static.xx.fbcdn.net/rsrc.php/v3iYXl4/y...          19
# 1182    https://static.xx.fbcdn.net/rsrc.php/v3iYXl4/y...          19
# 1194    https://static.xx.fbcdn.net/rsrc.php/v3iYXl4/y...          19
# 1224    https://static.xx.fbcdn.net/rsrc.php/v3iYXl4/y...          19
# ...                                                   ...         ...
# 492372  https://cdn.doubleverify.com/dv-measurements23...         353
# 492404  https://cdn.doubleverify.com/dv-measurements23...         353
# 495009            https://cdn.pulpix.com/static/pulpix.js           8
# 495012            https://cdn.pulpix.com/static/pulpix.js           8
# 497272  https://cdn.doubleverify.com/dvbs_src_internal...         758
#
#        script_col                            func_name script_loc_eval  \
# 1144         1402                g.prototype.drawEmoji
# 1174         1086                 g.prototype.drawText
# 1182         1402                g.prototype.drawEmoji
# 1194         1402                g.prototype.drawEmoji
# 1224         1086                 g.prototype.drawText
# ...           ...                                  ...             ...
# 492372        385                    g</a.prototype.Qs
# 492404        385                    g</a.prototype.Qs
# 495009       1958  pxLoadReq/</e.prototype.getCanvasFp
# 495012       2137  pxLoadReq/</e.prototype.getCanvasFp
# 497272        391                                    f
#
#                       document_url               top_level_url call_stack  \
# 1144     https://www.facebook.com/   https://www.facebook.com/
# 1174     https://www.facebook.com/   https://www.facebook.com/
# 1182     https://www.facebook.com/   https://www.facebook.com/
# 1194     https://www.facebook.com/   https://www.facebook.com/
# 1224     https://www.facebook.com/   https://www.facebook.com/
# ...                            ...                         ...        ...
# 492372  https://www.zerohedge.com/  https://www.zerohedge.com/
# 492404  https://www.zerohedge.com/  https://www.zerohedge.com/
# 495009     https://www.lequipe.fr/     https://www.lequipe.fr/
# 495012     https://www.lequipe.fr/     https://www.lequipe.fr/
# 497272  https://www.techradar.com/  https://www.techradar.com/
#
#                                symbol operation                  value  \
# 1144    CanvasRenderingContext2D.font       set            123px Arial
# 1174    CanvasRenderingContext2D.font       set            123px Arial
# 1182    CanvasRenderingContext2D.font       set            106px Arial
# 1194    CanvasRenderingContext2D.font       set            118px Arial
# 1224    CanvasRenderingContext2D.font       set            114px Arial
# ...                               ...       ...                    ...
# 492372  CanvasRenderingContext2D.font       set             14px Arial
# 492404  CanvasRenderingContext2D.font       set             14px Arial
# 495009  CanvasRenderingContext2D.font       set  11pt no-real-font-123
# 495012  CanvasRenderingContext2D.font       set             18pt Arial
# 497272  CanvasRenderingContext2D.font       set           14px 'Arial'
#
#        arguments                time_stamp        script_ps1        top_ps1  \
# 1144        None  2018-06-27T14:19:44.144Z         fbcdn.net   facebook.com
# 1174        None  2018-06-27T14:19:44.154Z         fbcdn.net   facebook.com
# 1182        None  2018-06-27T14:19:44.158Z         fbcdn.net   facebook.com
# 1194        None  2018-06-27T14:19:44.188Z         fbcdn.net   facebook.com
# 1224        None  2018-06-27T14:19:44.210Z         fbcdn.net   facebook.com
# ...          ...                       ...               ...            ...
# 492372      None  2018-06-27T14:49:39.438Z  doubleverify.com  zerohedge.com
# 492404      None  2018-06-27T14:49:34.488Z  doubleverify.com  zerohedge.com
# 495009      None  2018-06-27T14:49:54.158Z        pulpix.com     lequipe.fr
# 495012      None  2018-06-27T14:49:54.160Z        pulpix.com     lequipe.fr
# 497272      None  2018-06-27T14:50:02.796Z  doubleverify.com  techradar.com
#
#          document_ps1                                            value_b
# 1144     facebook.com  <re.Match object; span=(0, 11), match='123px A...
# 1174     facebook.com  <re.Match object; span=(0, 11), match='123px A...
# 1182     facebook.com  <re.Match object; span=(0, 11), match='106px A...
# 1194     facebook.com  <re.Match object; span=(0, 11), match='118px A...
# 1224     facebook.com  <re.Match object; span=(0, 11), match='114px A...
# ...               ...                                                ...
# 492372  zerohedge.com  <re.Match object; span=(0, 10), match='14px Ar...
# 492404  zerohedge.com  <re.Match object; span=(0, 10), match='14px Ar...
# 495009     lequipe.fr  <re.Match object; span=(0, 21), match='11pt no...
# 495012     lequipe.fr  <re.Match object; span=(0, 10), match='18pt Ar...
# 497272  techradar.com  <re.Match object; span=(0, 12), match="14px 'A...
#
# [2723 rows x 20 columns]

# %%
test.groupby(['script_ps1']).count().rename({"id": "count"}, axis='columns')[["count", "value_b"]]
# Out:
#                                count  value_b
# script_ps1
#                                    2        2
# 360buyimg.com                      4        4
# adsco.re                           1        1
# adtima.vn                          2        2
# alicdn.com                        56       56
# answerscloud.com                   2        2
# areyouahuman.com                   3        3
# atlassbx.com                       4        4
# azureedge.net                      2        2
# boxcdn.net                         1        1
# buckridge.link                     2        2
# cdn-apple.com                     27       27
# cdn-net.com                        2        2
# cdnst.net                          1        1
# cloudflare.com                     1        1
# consumable.com                     8        8
# d2fbkzyicji7c4.cloudfront.net      8        8
# d309knd7es5f10.cloudfront.net     33       33
# dditscdn.com                       2        2
# distiltag.com                      1        1
# doubleverify.com                  39       39
# fbcdn.net                         24       24
# foresee.com                        4        4
# fqtag.com                          8        8
# guoshipartners.com                 3        3
# hdslb.com                          1        1
# imedia.cz                          4        4
# jrjimg.cn                        106       50
# js                                 1        1
# kuikr.com                          1        1
# libertystmedia.com                 8        8
# licdn.com                          2        2
# mathtag.com                     2000     2000
# musthird.com                     177      177
# perimeterx.net                    10       10
# pixanalytics.com                   2        2
# pulpix.com                         2        2
# qiyipic.com                        2        2
# redditstatic.com                   2        2
# sciencedirectassets.com            2        2
# selectablemedia.com                2        2
# simility.com                       1        1
# sndcdn.com                         3        3
# static6.com                       10       10
# suning.cn                          1        1
# targetimg1.com                    96       96
# tiqcdn.com                        32       32
# tokopedia.net                      6        6
# viafoura.net                       4        4
# walmartimages.com                  8        8

# %%
test.groupby('script_ps1').top_ps1.count().sort_values(ascending=False)
# Out:
# script_ps1
# mathtag.com                      2000
# musthird.com                      177
# jrjimg.cn                         106
# targetimg1.com                     96
# alicdn.com                         56
# doubleverify.com                   39
# d309knd7es5f10.cloudfront.net      33
# tiqcdn.com                         32
# cdn-apple.com                      27
# fbcdn.net                          24
# perimeterx.net                     10
# static6.com                        10
# consumable.com                      8
# libertystmedia.com                  8
# fqtag.com                           8
# walmartimages.com                   8
# d2fbkzyicji7c4.cloudfront.net       8
# tokopedia.net                       6
# foresee.com                         4
# atlassbx.com                        4
# 360buyimg.com                       4
# imedia.cz                           4
# viafoura.net                        4
# sndcdn.com                          3
# guoshipartners.com                  3
# areyouahuman.com                    3
# redditstatic.com                    2
# sciencedirectassets.com             2
# qiyipic.com                         2
# pulpix.com                          2
# selectablemedia.com                 2
# pixanalytics.com                    2
#                                     2
# licdn.com                           2
# adtima.vn                           2
# dditscdn.com                        2
# answerscloud.com                    2
# azureedge.net                       2
# cdn-net.com                         2
# buckridge.link                      2
# boxcdn.net                          1
# adsco.re                            1
# suning.cn                           1
# simility.com                        1
# kuikr.com                           1
# cdnst.net                           1
# cloudflare.com                      1
# distiltag.com                       1
# js                                  1
# hdslb.com                           1
# Name: top_ps1, dtype: int64

# %%
import numpy as np
np.sum([(test["top_ps1"]!=test["document_ps1"]) & (test["symbol"]=="CanvasRenderingContext2D.font")])
# Out:
# 213

# %%
np.sum(test["symbol"]=="CanvasRenderingContext2D.font")
# Out:
# 2723
