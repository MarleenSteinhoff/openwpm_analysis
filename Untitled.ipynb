# %%
# -*- coding: utf-8 -*-
# packages changed for python 3
# pip install adblockparser

import sys
import sqlite3
import time
import json
import pickle
from functools import reduce
from urllib.parse import urlparse
from os.path import realpath, isfile, join
from _collections import defaultdict

# https://github.com/scrapinghub/adblockparser
from adblockparser import AdblockRules
from util import dump_as_json
from analysis_utils.utils import (is_third_party, is_blocked_by_disconnect,
                                  get_disconnect_blocked_hosts)
from analysis_utils.utils import get_ps1_or_host


SCRIPT_COUNTRY_JSON = "script_country_map_top10k.json"
SCRIPT_CATEGORY_JSON = "script_categories_top10k.json"

DEBUG = False

# search for the occurences of ublock after enabling this switch
ENABLE_UBLOCK = False

# Only lookup scripts with sensor access
CHECK_ADBLOCK_STATUS_OF_ALL_JS = False  # False means we only check
# scripts with sensor access
DB = ''
DB_NAME = ''
RESULTS_PATH = "/home/marleensteinhoff/UNi/Projektseminar/Datenanalyse/analysis/data/results"
# standard JavaScript, DOM events
JS_EVENTS = \
    ["DOMContentLoaded", "DOMMouseScroll", "abort", "afterprint",
     "animationend", "animationiteration", "animationstart",
     "appinstalled", "auxclick", "beforeinstallprompt",
     "beforeprint", "beforescriptexecute", "beforeunload",
     "blur", "canplay", "canplaythrough", "change",
     "chargingchange", "chargingtimechange", "click",
     "compassneedscalibration", "complete", "contextmenu",
     "copy", "cut", "dblclick", "devicechange", "devicelight",
     "devicemotion", "deviceorientation", "deviceproximity",
     "dischargingtimechange", "drag", "dragend", "dragenter",
     "dragleave", "dragover", "dragstart", "drop", "durationchange",
     "emptied", "ended", "error", "focus", "focusin", "focusout",
     "fullscreenchange", "gamepadconnected", "hashchange", "input",
     "invalid", "keydown", "keypress", "keyup", "levelchange",
     "load", "loadeddata", "loadedmetadata", "loadstart", "localized",
     "message", "mousedown", "mouseenter", "mouseleave", "mousemove",
     "mouseout", "mouseover", "mouseup", "notificationclick",
     "offline", "online", "orientationchange", "overflow", "pagehide",
     "pageshow", "paste", "pause", "play", "playing", "pointercancel",
     "pointerdown", "pointerleave", "pointermove", "pointerover",
     "pointerup", "popstate", "progress", "push", "ratechange",
     "readystatechange", "reset", "resize", "scroll", "seeked",
     "seeking", "select", "show", "stalled", "start", "statechange",
     "storage", "submit", "suspend", "timeupdate", "touchcancel",
     "touchend", "touchenter", "touchleave", "touchmove", "touchstart",
     "transitionend", "transitionstart", "unload", "userproximity",
     "visibilitychange", "volumechange", "vrdisplayactivate",
     "vrdisplaydeactivate", "vrdisplaypresentchange", "waiting", "wheel"]

# %%
PENIS= defaultdict()

g_SCRIPT_FEATURES= defaultdict()
   
g_sorted_feature_list= []
    
g_high_level_feat_dict= defaultdict()
g_script_ranks= []
  
g_overall_script_ranks= []
g_script_categories= defaultdict()
    
g_script_countries= []

# %%
def get_event_feature(arguments, symbol):
    arguments_obj = json.loads(arguments)
    event_name = arguments_obj["0"]
    if event_name in JS_EVENTS:
        return "addEventListener_" + event_name
    else:  # custom event
        if DEBUG and event_name != "test":
            print()
            "Custom Event:", event_name
        return "addEventListener_CUSTOM_EVENT"


def get_simple_feature_from_js_info(operation, arguments, symbol):
    if symbol.endswith("addEventListener") and operation == "call":
        return get_event_feature(arguments, symbol)
    elif operation == "call":
        return "call_" + symbol
    elif operation == "get":
        return "get_" + symbol
    elif operation == "set":
        return "set_" + symbol


CANVAS_READ_FUNCS = [
    "HTMLCanvasElement.toDataURL",
    "CanvasRenderingContext2D.getImageData"
]

CANVAS_WRITE_FUNCS = [
    "CanvasRenderingContext2D.fillText",
    "CanvasRenderingContext2D.strokeText"
]

"""
Criteria 3 from Englehardt & Narayanan, 2016
"3. The script should not call the save, restore, or addEventListener
methods of the rendering context."
`addEventListener` is (can) only called for HTMLCanvasElement, so we use that.
"""
CANVAS_FP_DO_NOT_CALL_LIST = ["CanvasRenderingContext2D.save",
                              "CanvasRenderingContext2D.restore",
                              "HTMLCanvasElement.addEventListener"]
AUDIO_CONTEXT_FUNCS = [
    "OfflineAudioContext.createOscillator",
    "OfflineAudioContext.createDynamicsCompressor",
    "OfflineAudioContext.destination",
    "OfflineAudioContext.startRendering",
    "OfflineAudioContext.oncomplete"
]

WEBRTC_FP_CALLS = ["RTCPeerConnection.createDataChannel",
                   "RTCPeerConnection.createOffer"]

# Functions to get the charging time
BATTERY_CHARGING_TIME_CALLS = ["BatteryManager.chargingTime",
                               "BatteryManager.onchargingtimechange"]

# Functions to get the discharging time
BATTERY_DISCHARGING_TIME_CALLS = ["BatteryManager.dischargingTime",
                                  "BatteryManager.ondischargingtimechange"]

# High level features
CANVAS_FP = "canvas_fingerprinting"
CANVAS_FONT_FP = "canvas_font_fingerprinting"
AUDIO_CTX_FP = "audio_context_fingerprinting"
WEBRTC_FP = "webrtc_fingerprinting"
BATTERY_FP = "battery_fingerprinting"
TRIGGERS_REQUEST = "triggers_requests"
TRIGGERS_TP_REQUEST = "triggers_third_party_requests"
EASYLIST_BLOCKED = "easylist_blocked"
EASYPRIVACY_BLOCKED = "easyprivacy_blocked"
UBLOCK_ORIGIN_BLOCKED = "ublockorigin_blocked"
DISCONNECT_BLOCKED = "disconnect_blocked"
THIRD_PARTY_SCRIPT = "third_party_script"

HIGH_LEVEL_FEATURES = [CANVAS_FP, CANVAS_FONT_FP, AUDIO_CTX_FP,
                       WEBRTC_FP, BATTERY_FP,
                       TRIGGERS_REQUEST, TRIGGERS_TP_REQUEST,
                       EASYLIST_BLOCKED, EASYPRIVACY_BLOCKED,
                       # UBLOCK_ORIGIN_BLOCKED,
                       DISCONNECT_BLOCKED,
                       THIRD_PARTY_SCRIPT]

MIN_CANVAS_TEXT_LEN = 10
MIN_CANVAS_IMAGE_WIDTH = 16
MIN_CANVAS_IMAGE_HEIGHT = 16


def get_canvas_text(arguments):
    if not arguments:
        return ""
    canvas_write_args = json.loads(arguments)
    try:
        # cast numbers etc. to string
        return str(canvas_write_args["0"])
    except Exception:
        try:
            # for non-ascii strings
            return str(canvas_write_args["0"].encode("utf-8"))
        except Exception:
            # if we cannot decode a call's arguments we exclude it
            # from the analysis to prevent false positives
            return ""


def safe_int(string):
    """Convert string to int, return 0 if conversion fails."""
    try:
        return int(string)
    except ValueError:
        return 0


def is_get_image_data_dimensions_too_small(arguments):
    """Check if the retrieved canvas data is greater than min dimensions."""
    # https://developer.mozilla.org/en-US/docs/Web/API/CanvasRenderingContext2D/getImageData#Parameters  # noqa
    get_image_data_args = json.loads(arguments)
    sw = safe_int(get_image_data_args.get("2", 0))
    sh = safe_int(get_image_data_args.get("3", 0))
    MIN_CANVAS_IMAGE_WIDTH = 16
    return (sw < MIN_CANVAS_IMAGE_WIDTH) or (sh < MIN_CANVAS_IMAGE_HEIGHT)


def get_base_script_url(script_url):
    script_url_no_param = script_url.split("?")[0].split("&")[0].split("#")[0]
    return script_url_no_param.split("://")[-1].strip()


def get_script_freqs_from_db(db_file, max_rank=None):
    """Return a frequency count for each script."""
    connection = sqlite3.connect(db_file)
    c = connection.cursor()

    query = """SELECT visit_id, script_url FROM javascript WHERE
        script_url <> ''
        """
    if max_rank is not None:
        query += " AND visit_id <= %i" % max_rank

    overall_script_ranks = defaultdict(set)
    for row in c.execute(query):
        visit_id, script_url = row[0:2]
        # Exclude scripts with visit_id = -1
        # This happens when OpenWPM doesn't know which visit a script belong to
        if visit_id == -1:
            continue
        # Exclude relative URLs, data urls, blobs
        if not (script_url.startswith("http://")
                or script_url.startswith("https://")):
            continue
        script_adress = get_base_script_url(script_url)
        overall_script_ranks[script_adress].add(visit_id)
    return overall_script_ranks


# This list is only used to decide if
# we want to check adblock status of scripts.
# We'll probably won'tuse userprosimity
# but let's save the adblocked status of the scripts accessing userproximity
SENSOR_FEATURES = [
    "addEventListener_devicelight",
    "addEventListener_deviceorientation",
    "addEventListener_deviceproximity",
    "addEventListener_devicemotion"
    # ,"addEventListener_userproximity"
]


def extract_features(db_file, out_csv, max_rank=0):
    """Extract fingerprinting related features from the javascript table
    of the crawl database.
    Although we use script_url to attribute the access or the function call,
    it may not always give the right script.
    For instance when a script uses jquery to listen to sensor events we'll
    attribute the (e.g. sensor related) event listening to jquery. The script
    that uses jquery should still be in the call_stack, but not necessarily at
    the top or bottom).
    TODO: use call_stack to get other potential scripts.
    The problem is how to do the attribution then, assign all access to all
    scripts that appear in the call_stack?"""

    
    # high level features
    canvas_reads = defaultdict(set)
    canvas_writes = defaultdict(set)
    canvas_texts = defaultdict(set)
    canvas_banned_calls = defaultdict(set)
    canvas_styles = defaultdict(lambda: defaultdict(set))
    battery_level_access = defaultdict(set)
    battery_charging_time_access = defaultdict(set)
    battery_discharging_time_access = defaultdict(set)
    audio_ctx_calls = defaultdict(lambda: defaultdict(set))
    webrtc_calls = defaultdict(lambda: defaultdict(set))
    canvas_used_fonts = defaultdict(lambda: defaultdict(set))
    canvas_measure_text_calls = defaultdict(int)

    # simple features
    script_ranks = defaultdict(set)  # site ranks where a script is embedded
    script_features = defaultdict(set)

    # sensor type -> set(visit_ids)
    sensor_visit_ids = defaultdict(set)
    # visit ids where a script from a domain is embedded and
    # a sensor was accessed
    # domain-> set(visit_ids)
    sensor_script_domain_visit_ids = defaultdict(lambda: defaultdict(set))
    sensor_script_url_visit_ids = defaultdict(lambda: defaultdict(set))

    # To check script URLs against adblock rules
    easylist_blocked_scripts = set()
    easyprivacy_blocked_scripts = set()
    ublock_blocked_scripts = set()
    disconnect_blocked_scripts = set()
    easylist_rules, easyprivacy_rules, ublock_rules = get_adblock_rules()
    disconnect_blocklist = get_disconnect_blocked_hosts()
    adblock_checked_scripts = set()  # to prevent repeated lookups
    third_party_scripts = set()

    script_categories = {}
    script_countries = {}

    if isfile(SCRIPT_CATEGORY_JSON):
        script_categories = json.loads(open(SCRIPT_CATEGORY_JSON).read())

    if isfile(SCRIPT_COUNTRY_JSON):
        script_countries = json.loads(open(SCRIPT_COUNTRY_JSON).read())

    overall_script_ranks = get_script_freqs_from_db(db_file)

    connection = sqlite3.connect(db_file)
    connection.row_factory = sqlite3.Row
    c = connection.cursor()

    query = """SELECT sv.site_url, sv.visit_id,
        js.script_url, js.operation, js.arguments, js.symbol, js.value
        FROM javascript as js LEFT JOIN site_visits as sv
        ON sv.visit_id = js.visit_id WHERE
        js.script_url <> ''
        """

    if max_rank:
        query += " AND js.visit_id <= %i" % max_rank

    for row in c.execute(query):
        visit_id = row["visit_id"]
        site_url = row["site_url"]
        script_url = row["script_url"]
        operation = row["operation"]
        arguments = row["arguments"]
        symbol = row["symbol"]
        value = row["value"]

        # Exclude relative URLs, data urls, blobs, javascript URLs
        if not (script_url.startswith("http://")
                or script_url.startswith("https://")):
            continue

        script_adress = get_base_script_url(script_url)
        third_party_script = False
        if is_third_party(script_url, site_url):
            third_party_scripts.add(script_adress)
            third_party_script = True

        # get the simple feature for this call
        feat = get_simple_feature_from_js_info(operation, arguments, symbol)
        if feat is not None:
            script_features[script_adress].add(feat)

        script_ranks[script_adress].add(visit_id)

        if feat in SENSOR_FEATURES:
            script_domain = get_ps1_or_host(script_url)
            sensor_visit_ids[feat].add(visit_id)
            sensor_script_domain_visit_ids[feat][script_domain].add(visit_id)
            sensor_script_url_visit_ids[feat][script_adress].add(visit_id)

        # Check easylist and easyprivacy blocked status
        # if we didn't do it for this script url before
        if (CHECK_ADBLOCK_STATUS_OF_ALL_JS or feat in SENSOR_FEATURES) and \
                script_url not in adblock_checked_scripts:
            adblock_checked_scripts.add(script_url)
            # Some (most?) adblock rules only match third parties.
            # We need to pass the options to avoid false negatives
            # https://pypi.python.org/pypi/adblockparser
            if easylist_rules.should_block(
                    script_url, {'script': True,
                                 'third-party': third_party_script}):
                easylist_blocked_scripts.add(script_adress)

            if easyprivacy_rules.should_block(
                    script_url, {'script': True,
                                 'third-party': third_party_script}):
                easyprivacy_blocked_scripts.add(script_adress)

            if ENABLE_UBLOCK:
                if ublock_rules.should_block(
                        script_url, {'script': True,
                                     'third-party': third_party_script}):
                    ublock_blocked_scripts.add(script_adress)
            if is_blocked_by_disconnect(script_url, disconnect_blocklist):
                disconnect_blocked_scripts.add(script_adress)

        # High level features
        # Canvas fingerprinting
        if symbol in CANVAS_READ_FUNCS and operation == "call":
            if (symbol == "CanvasRenderingContext2D.getImageData" and
                    is_get_image_data_dimensions_too_small(arguments)):
                continue
            canvas_reads[script_adress].add(visit_id)
        elif symbol in CANVAS_WRITE_FUNCS:
            text = get_canvas_text(arguments)
            # Python miscalculates the length of unicode strings that contain
            # surrogate pairs such as emojis. This make the string look longer
            # it really is and cause false positives.
            # For instance "🏴​󠁧​󠁢​󠁥​󠁮​󠁧", which is written onto canvas by
            # Wordpress to check emoji support, gives a length of 13.
            # We ignore non-ascii characters to prevent these false positives.
            if len(text.encode('ascii', 'ignore')) >= MIN_CANVAS_TEXT_LEN:
                canvas_writes[script_adress].add(visit_id)
                # the following is used to debug false positives
                canvas_texts[(script_adress, visit_id)].add(text)
        elif symbol == "CanvasRenderingContext2D.fillStyle" and \
                operation == "call":
            canvas_styles[script_adress][visit_id].add(value)
        elif operation == "call" and symbol in CANVAS_FP_DO_NOT_CALL_LIST:
            canvas_banned_calls[script_adress].add(visit_id)
        # Canvas font fingerprinting
        elif symbol == "CanvasRenderingContext2D.font" and operation == "set":
            canvas_used_fonts[script_adress][visit_id].add(value)
        elif symbol == "CanvasRenderingContext2D.measureText" and \
                operation == "call":
            text = json.loads(arguments)["0"]
            canvas_measure_text_calls[(script_adress, visit_id, text)] += 1
        elif (operation == "call" and symbol in WEBRTC_FP_CALLS) or \
                (operation == "set" and
                 symbol == "RTCPeerConnection.onicecandidate"):
            webrtc_calls[script_adress][visit_id].add(symbol)

        # Battery Status API
        elif operation == "get" and symbol in "BatteryManager.level":
            battery_level_access[script_adress].add(visit_id)
        elif operation == "get" and symbol in BATTERY_CHARGING_TIME_CALLS:
            battery_charging_time_access[script_adress].add(visit_id)
        elif operation == "get" and symbol in BATTERY_DISCHARGING_TIME_CALLS:
            battery_discharging_time_access[script_adress].add(visit_id)
        elif (operation == "call"
              and symbol == "BatteryManager.addEventListener"):
            event_type = json.loads(arguments)["0"]
            if event_type == "levelchange":
                battery_level_access[script_adress].add(visit_id)
            elif event_type == "chargingtimechange":
                battery_charging_time_access[script_adress].add(visit_id)
            elif event_type == "dischargingtimechange":
                battery_discharging_time_access[script_adress].add(visit_id)

        # Audio Context API
        elif symbol in AUDIO_CONTEXT_FUNCS:
            audio_ctx_calls[script_adress][visit_id].add(symbol)

    canvas_fingerprinters = get_canvas_fingerprinters(canvas_reads,
                                                      canvas_writes,
                                                      canvas_styles,
                                                      canvas_banned_calls,
                                                      canvas_texts)
    canvas_font_fingerprinters = \
        get_canvas_font_fingerprinters(canvas_used_fonts,
                                       canvas_measure_text_calls)
    audio_ctx_fingerprinters = get_audio_ctx_fingerprinters(audio_ctx_calls)
    webrtc_fingerprinters = get_webrtc_fingerprinters(webrtc_calls)
    battery_fingerprinters = get_battery_fingerprinters(
        battery_level_access, battery_charging_time_access,
        battery_discharging_time_access)

    request_triggering_scripts, third_party_request_triggering_scripts = \
        get_request_triggering_scripts(db_file)

    if DEBUG:
        print("audio_ctx_fingerprinters", audio_ctx_fingerprinters)
        print("canvas_fingerprinters", canvas_fingerprinters)
        print("canvas_font_fingerprinters", canvas_font_fingerprinters)
        print("webrtc_fingerprinters", webrtc_fingerprinters)
        print("battery_fingerprinters", battery_fingerprinters)
        print("request_triggering_scripts", request_triggering_scripts)
        print("third_party_request_triggering_scripts", third_party_request_triggering_scripts)
        print(THIRD_PARTY_SCRIPT, third_party_scripts)
        print(EASYLIST_BLOCKED, easylist_blocked_scripts)
        print(EASYPRIVACY_BLOCKED, easyprivacy_blocked_scripts)
        # print UBLOCK_ORIGIN_BLOCKED, ublock_blocked_scripts
        print(DISCONNECT_BLOCKED, disconnect_blocked_scripts)
    
    print("high level in extract features")
    high_level_feat_dict = {
        CANVAS_FP: canvas_fingerprinters,
        CANVAS_FONT_FP: canvas_font_fingerprinters,
        AUDIO_CTX_FP: audio_ctx_fingerprinters,
        WEBRTC_FP: webrtc_fingerprinters,
        BATTERY_FP: battery_fingerprinters,
        TRIGGERS_REQUEST: request_triggering_scripts,
        TRIGGERS_TP_REQUEST: third_party_request_triggering_scripts,
        EASYLIST_BLOCKED: easylist_blocked_scripts,
        EASYPRIVACY_BLOCKED: easyprivacy_blocked_scripts,
        # UBLOCK_ORIGIN_BLOCKED: ublock_blocked_scripts,
        DISCONNECT_BLOCKED: disconnect_blocked_scripts,
        THIRD_PARTY_SCRIPT: third_party_scripts
    }
    
    sorted_feature_list = get_sorted_feature_list(script_features)
    global PENIS
    PENIS = high_level_feat_dict 
    global g_SCRIPT_FEATURES
    g_SCRIPT_FEATURES = script_features
    global g_sorted_feature_list
    g_sorted_feature_list
    global g_high_level_feat_dict
    g_high_level_feat_dict = high_level_feat_dict
    global g_script_ranks
    g_script_ranks = script_ranks
    global g_overall_script_ranks
    g_overall_script_ranks = overall_script_ranks
    global g_script_categories
    g_script_categories = script_categories
    global g_script_countries
    g_script_countries = script_countries
    
    """ 
    write_feats_to_csv(script_features,
                            sorted_feature_list, high_level_feat_dict,
                            script_ranks,
                            overall_script_ranks,
                            script_categories,
                            script_countries, out_csv)
    write_site_domain_counts_binaries(sensor_visit_ids,
                                      sensor_script_domain_visit_ids,

    #write_site_domain_counts(sensor_visit_ids,
                             sensor_script_domain_visit_ids,
                             sensor_script_url_visit_ids,
                             out_csv)
                
"""


def write_site_domain_counts(sensor_visit_ids,
                             sensor_script_domain_visit_ids,
                             sensor_script_url_visit_ids,
                             out_csv):
    domain_counts_out = "%s_domain_visit_ids.csv" % out_csv.replace(".csv", "")
    site_counts_out = "%s_site_counts.csv" % out_csv.replace(".csv", "")
    script_url_counts_out = "%s_script_url_visit_ids.csv" % \
                            out_csv.replace(".csv", "")
    print("Will write sensor->visit-ids to", domain_counts_out)
    print("Will write script domain->visit-ids to", site_counts_out)
    print("Will write script url->visit-ids to", script_url_counts_out)
    with open(site_counts_out, "w") as f:
        for sensor_feat, visit_ids in sensor_visit_ids.items():
            feat_name = sensor_feat.split("_")[-1]
            print()
            "Total sites for feat %s: %d" % (feat_name, len(visit_ids))
            visit_ids_str = ",".join(str(visit_id) for visit_id in visit_ids)
            f.write("%s\t%s\n" % (sensor_feat, visit_ids_str))

    with open(domain_counts_out, "w") as f:
        for sensor_feat, domain_visit_dict in \
                sensor_script_domain_visit_ids.items():
            feat_name = sensor_feat.split("_")[-1]
            print()
            "Total domains for feat %s: %d" % (feat_name,
                                               len(domain_visit_dict))
            for script_domain, visit_ids in domain_visit_dict.items():
                visit_ids_str = ",".join(str(visit_id)
                                         for visit_id in visit_ids)
                f.write("%s\t%s\t%s\n" % (feat_name, script_domain,
                                          visit_ids_str))

    with open(script_url_counts_out, "w") as f:
        for sensor_feat, script_url_visit_dict in \
                sensor_script_url_visit_ids.items():
            feat_name = sensor_feat.split("_")[-1]
            print()
            "Total sites for feat %s: %d" % (feat_name,
                                             len(script_url_visit_dict))
            for script_url, visit_ids in script_url_visit_dict.items():
                visit_ids_str = ",".join(str(visit_id) for visit_id in visit_ids)
                f.write("%s\t%s\t%s\n" % (feat_name, script_url, visit_ids_str))


MIN_FONT_FP_FONT_COUNT = 50


def get_script_urls_from_req_call_stack(req_call_stack):
    """
    An example stack frame:
      udm_@https://sb.scorecardresearch.com/beacon.js:1:611;null"  # noqa

    Another example, this time with eval:
      null@http://static-alias-1.360buyimg.com/jzt/libs/behavior/v2.3/behavior.js line 1 > eval:1:619;null  # noqa
    """
    script_urls = set()
    frames = req_call_stack.split("\n")
    for frame in frames:
        script_url = frame. \
            rsplit(":", 2)[0]. \
            split("@", 1)[-1]. \
            split(" line")[0]
        if not (script_url.startswith("http://")
                or script_url.startswith("https://")):
            continue

        script_url_no_param = script_url.split("?")[0].split("&")[0]
        script_adress = script_url_no_param.split("://")[-1]
        script_urls.add(script_adress)
    return script_urls


def get_request_triggering_scripts(db_file):
    request_triggering_scripts = set()
    third_party_request_triggering_scripts = set()
    connection = sqlite3.connect(db_file)
    c = connection.cursor()
    query = """SELECT visit_id, url, is_third_party_channel, req_call_stack
                   FROM http_requests
                   WHERE req_call_stack <> ''
                   """
    for row in c.execute(query):
        _, _, is_third_party_channel, req_call_stack = row[0:4]
        script_addrs = get_script_urls_from_req_call_stack(req_call_stack)
        request_triggering_scripts.update(script_addrs)
        if is_third_party_channel == 1:
            third_party_request_triggering_scripts.update(script_addrs)
    return request_triggering_scripts, third_party_request_triggering_scripts


def get_battery_fingerprinters(battery_level_access,
                               battery_charging_time_access,
                               battery_discharging_time_access):
    """Find visits where all three battery related features are accessed.
    We require scripts to access three properties:
        battery level, charging and discharging time.
    """
    battery_fingerprinters = set()
    for script_address, visit_ids in battery_level_access.items():
        if script_address in battery_fingerprinters:
            continue
        fp_visits = visit_ids. \
            intersection(battery_charging_time_access[script_address],
                         battery_discharging_time_access[script_address])
        if not fp_visits:
            continue
        battery_fingerprinters.add(script_address)
        print(("Battery fingerprinter", script_address, "visit#",
               fp_visits))

    return battery_fingerprinters


def get_canvas_font_fingerprinters(canvas_used_fonts,
                                   canvas_measure_text_calls):
    """
    From: http://randomwalker.info/publications/OpenWPM_1_million_site_tracking_measurement.pdf  # noqa
    "the script sets the font property to at least 50 distinct, valid values and
    also calls the measureText method at least 50 times on the same text string."

    """
    canvas_font_fingerprinters = set()
    for script_adress, visit_id_calls_dict in canvas_used_fonts.items():
        for font_use_visit_id, canvas_fonts in visit_id_calls_dict.items():
            if len(canvas_fonts) < MIN_FONT_FP_FONT_COUNT:
                continue
            # check if there's 50+ measureText calls in this visit
            for (script_adress, font_measure_visit_id, arguments), call_count \
                    in canvas_measure_text_calls.items():
                if script_adress in canvas_font_fingerprinters:
                    continue
                if font_use_visit_id == font_measure_visit_id and \
                        call_count >= MIN_FONT_FP_FONT_COUNT:
                    canvas_font_fingerprinters.add(script_adress)
                    print(("Canvas font fingerprinter:", script_adress,
                           "visit#", font_use_visit_id,
                           arguments, len(canvas_fonts), canvas_fonts))
                    break
    return canvas_font_fingerprinters


def get_webrtc_fingerprinters(webrtc_calls_dict):
    webrtc_fingerprinters = set()
    for script_adress, visit_id_calls_dict in webrtc_calls_dict.items():
        if script_adress in webrtc_fingerprinters:
            continue
        for visit_id, webrtc_calls in visit_id_calls_dict.items():
            # we require the script to call all 2 webrtc functions
            # and set onicecandidate event listener
            # +1 for set onicecandidate
            if len(webrtc_calls) == len(WEBRTC_FP_CALLS) + 1:
                webrtc_fingerprinters.add(script_adress)
                print(("WebRTC fingerprinter:", script_adress,
                       "visit#", visit_id))
                break
    return webrtc_fingerprinters


def get_audio_ctx_fingerprinters(audio_ctx_calls_dict):
    """Return scripts who call the Audio Context API functions we monitor."""
    audio_context_fingerprinters = set()
    for script_adress, visit_id_calls_dict in audio_ctx_calls_dict.items():
        if script_adress in audio_context_fingerprinters:
            continue
        for visit_id, audio_ctx_calls in visit_id_calls_dict.items():
            # we require the script to call all five audio context functions
            if len(audio_ctx_calls) == len(AUDIO_CONTEXT_FUNCS):
                audio_context_fingerprinters.add(script_adress)
                print(("Audio context fingerprinter:", script_adress,
                       "visit#", visit_id))
                break
    return audio_context_fingerprinters


MIN_CANVAS_STYLE_CALLS = 0


def get_canvas_fingerprinters(canvas_reads, canvas_writes, canvas_styles,
                              canvas_banned_calls, canvas_texts):
    """
    We don't require text to be written to canvas with at least two color
    as done by Englehardt and Narayanan, 2016
    Our preliminary analysis showed that several canvas fingerprinting scripts
    uses a single color.
    Following are sample scripts that uses a single color:
    https://secure.bankofamerica.com/login/sign-in/entry/cc.go?_=1498293938310
    https://aug.americanexpress.com/collector/cc.js?v=4.4.3
    https://deviceinfo.capitalone.com/collector/cc.js?tid=HOME_5a9c9ed4-b977-4e85-9e6e-d7ca84983d0b
    Use the following query to find out some of the scripts we'd miss
    if we required this condition:
    SELECT *
      FROM javascript
     WHERE (symbol LIKE "%CanvasRenderingContext2D%" OR
            symbol LIKE "%HTMLCanvasElement.toDataURL%") AND
           id < 1000000 AND
           (script_url LIKE "%deviceinfo.capitalone.com%" OR
            script_url LIKE "%secure.bankofamerica.com/login/sign-in/entry/cc.go%" OR  # noqa
            script_url LIKE "%aug.americanexpress.com/collector/cc.js%");
    """
    canvas_fingerprinters = set()
    for script_address, visit_ids in canvas_reads.items():
        if script_address in canvas_fingerprinters:
            continue
        canvas_rw_visits = visit_ids. \
            intersection(canvas_writes[script_address])
        if not canvas_rw_visits:
            continue
        # we can remove the following, we don't use the style/color condition
        for canvas_rw_visit in canvas_rw_visits:
            if len(canvas_styles[script_address][canvas_rw_visit]) < \
                    MIN_CANVAS_STYLE_CALLS:
                continue

            # check if the script has made a call to save, restore or
            # addEventListener of the Canvas API. We exclude scripts making
            # these calls to eliminate false positives
            if canvas_rw_visit in canvas_banned_calls[script_address]:
                print(("Excluding potential canvas FP script", script_address,
                       "visit#", canvas_rw_visit,
                       canvas_texts[(script_address, canvas_rw_visit)]))
                continue
            canvas_fingerprinters.add(script_address)
            print(("Canvas fingerprinter", script_address, "visit#",
                   canvas_rw_visit,
                   canvas_texts[(script_address, canvas_rw_visit)]))
            break

    return canvas_fingerprinters


def get_sorted_feature_list(script_features):
    return sorted(list(reduce(set.union, list(script_features.values()))))


def empty_file(file_handle):
    file_handle.truncate(0)


def filter_out_non_absolute_urls(script_features):
    for script_url in script_features.keys():
        print()
        script_url, urlparse(script_url).netloc
    return script_features


def read_ab_rules_from_file(filename):
    filter_list = set()
    for l in open(filename):
        if len(l) == 0 or l[0] == '!':  # ignore these lines
            continue
        else:
            filter_list.add(l.strip())
    return filter_list


def get_adblock_rules():
    raw_easylist_rules = read_ab_rules_from_file("analysis_utils/easylist.txt")
    raw_easyprivacy_rules = read_ab_rules_from_file("analysis_utils/easyprivacy.txt")
    if ENABLE_UBLOCK:
        raw_ublock_rules = read_ab_rules_from_file("analysis_utils/adblock_blacklist_white.txt")
    else:
        raw_ublock_rules = []
    print(("Loaded %s from EasyList, %s rules from EasyPrivacy"
           " and %s rules from UBlockOrigin" %
           (len(raw_easylist_rules), len(raw_easyprivacy_rules),
            len(raw_ublock_rules))))
    easylist_rules = AdblockRules(raw_easylist_rules)
    easyprivacy_rules = AdblockRules(raw_easyprivacy_rules)
    ublock_rules = AdblockRules(raw_ublock_rules)
    return easylist_rules, easyprivacy_rules, ublock_rules


def write_feats_to_csv(script_features,
                       sorted_feature_list,
                       high_level_feat_dict,
                       script_ranks,
                       overall_script_ranks,
                       script_categories,
                       script_countries,
                       out_csv):
    with open(out_csv, "a", newline='', encoding='utf8') as f:
        empty_file(f)  # start a fresh file
        f.write("script_url\t" + "\t".join(sorted_feature_list) +
                "\t" + "\t".join(HIGH_LEVEL_FEATURES) + "\t" + "min_rank" +
                "\t" + "num_sites" + "\t" "num_sites_overall" +
                "\t" + "category" + "\t" + "country" + "\n")
        for script_url, script_features in script_features.items():
            binary_feats = []  # binary feature vector
            for feature in sorted_feature_list:  # iterate over sorted feats
                if feature in script_features:  # if this script has this feat
                    binary_feats.append("1")
                else:
                    binary_feats.append("0")

            f.write(script_url + "\t")  # write the script url
            f.write("\t".join(binary_feats) + "\t")  # write binary features

            hi_level_feats = []  # binary hi level feature vector
            for hi_level_feat in HIGH_LEVEL_FEATURES:
                if script_url in high_level_feat_dict[hi_level_feat]:
                    hi_level_feats.append("1")
                    # print "HIGH_LEVEL_FEATURES", hi_level_feat, script_url
                else:
                    hi_level_feats.append("0")
            f.write("\t".join(hi_level_feats))  # write binary features
            if script_ranks[script_url] is None:
                continue
            if script_ranks[script_url] < 0:
                continue
            smallest_rank = (min(script_ranks[script_url]), len(script_ranks[script_url]))
            f.write("\t%s\t%s" % smallest_rank)
            f.write("\t%s" % len(overall_script_ranks[script_url]))
            f.write("\t%s\t%s\n" % (script_categories.get(script_url,
                                                          "Unknown"),
                                    script_countries.get(script_url,
                                                         "Unknown")))


def write_script_visit_ids(script_visit_ids, out_csv):
    with open(out_csv, "a") as f:
        empty_file(f)  # start a fresh file
        for script_url, visit_ids in script_visit_ids.items():
            visit_ids_str = ",".join(str(visit_id) for visit_id in visit_ids)
            f.write("%s\t%s\n" % (script_url.encode("utf-8"), visit_ids_str))

# %%
"""
Usage
To extract features, run:
python extract_features.py
To extract script URL, visit_ids mapping, run:
python extract_features.py extract_frequencies_only
"""
if __name__ == '__main__':
    t0 = time.time()
    out_csv = "features.csv"
    db = "/home/marleensteinhoff/UNi/Projektseminar/Datenanalyse/data/Samples/2018-06.sqlite"

    if "extract_frequencies_only" in sys.argv:
        script_freqs = get_script_freqs_from_db(db)
        write_script_visit_ids(script_freqs, 'script_visit_ids.csv')
        sys.exit(0)
    ########################################
    LIMIT_SITE_RANK = False  # Only to be used with the home-page only crawls
    MAX_RANK = 10000  # for debugging testing
    if LIMIT_SITE_RANK:
        extract_features(db, out_csv, MAX_RANK)
    else:
        DB = db
        DB_NAME = str(DB).split('_')[0].split('/')[8]
        RESULTS_PATH = join(RESULTS_PATH)
        extract_features(db, out_csv)  # process all rows
    ########################################
    print(("Feature extraction completed in", time.time() - t0, "seconds"))
    print(("Features are written into:", realpath(out_csv)))
# Out:
# Loaded 54173 from EasyList, 29570 rules from EasyPrivacy and 0 rules from UBlockOrigin
# (3184, 'blocked hosts')
# ('Canvas fingerprinter', 'vk.com/js/cmodules/web/grip.js', 'visit#', 14, {'Cwm fjordbank glyphs vext quiz'})
# ('Canvas fingerprinter', 'static.licdn.com/scds/concat/common/js', 'visit#', 16, {'92UV<v=Xd&N@Ig_P#1iqrWHBoclz>FZkyYu4xf(O^A8TJh)mbnGs$S]3-k!%j0Q{+w[RCKEat?L56}M~`D7e*'})
# ('Canvas fingerprinter', 'www.redditstatic.com/reddit-init.en.xE6foQQcI8M.js', 'visit#', 26, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'atanx.alicdn.com/t/tanxssp.js', 'visit#', 128, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'atanx2.alicdn.com/g/mm/tanx-cdn2/t/tanxssp.js', 'visit#', 18, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'aeu.alicdn.com/js/cj/109.js', 'visit#', 77, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'g.alicdn.com/security/umscript/3.3.28/um.js', 'visit#', 77, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 's.pixanalytics.com/js/pi.min.js', 'visit#', 83, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.txxx.com/sizo/eris.js', 'visit#', 102, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.rakuten.co.jp/akam/10/4a84f18', 'visit#', 111, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'static.dditscdn.com/arms-datacollectorjs/arms-lubet-1.3.4.js', 'visit#', 139, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.cnet.com/akam/10/5e256288', 'visit#', 162, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'buckridge.link/js/lib.js', 'visit#', 196, {'Cwm fjordbank glyphs vext quiz, рџ\x98ѓ'})
# ('Canvas fingerprinter', 'upornia.com/husik/upCtrl.js', 'visit#', 202, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 's1.hdslb.com/bfs/seed/log/report/log-reporter.js', 'visit#', 201, {'i am the finger-printing in this broswer'})
# ('Canvas fingerprinter', 'secure.bankofamerica.com/login/sign-in/cc.go', 'visit#', 206, {'AaBbCcDdEeFfGgHhIiJjKkLlMmNnOoPpQqRrSsTtUuVvWwXxYyZz0123456789'})
# ('Canvas fingerprinter', 'www.yelp.com/yly-uvuduydqsy.js', 'visit#', 254, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.wittyfeed.com/akam/10/2fe2244c', 'visit#', 266, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'www.ikea.com/akam/10/605d3abc', 'visit#', 271, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'yummy.consumable.com/3542/cnsmbl-audio-728x90-slider/widget/iframe.js', 'visit#', 273, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'client.perimeterx.net/PXHYx10rg3/main.min.js', 'visit#', 287, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'cdn.tokopedia.net/built/assets-201806-412b8a54dce37b51b7266ef000bae23b.js', 'visit#', 288, {'Cwm fjordbank glyphs vext quiz, ??'})
# ('Canvas fingerprinter', 'ecs7.tokopedia.net/scripts/global.fingerprintjs2.1.4.2.min.js', 'visit#', 288, {'Cwm fjordbank glyphs vext quiz, ??'})
# ('Canvas fingerprinter', 'cdn.tokopedia.net/built/e11858506b9142ee56d28349ba6c017c.js', 'visit#', 288, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.fiverr.com/px/client/PXK3bezZfO/main.min.js', 'visit#', 299, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'image.nametests.com/cache/js/cc5f6fa608f4.js', 'visit#', 305, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'client.perimeterx.net/PXSs13U803/main.min.js', 'visit#', 310, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'cdnbigdata.azureedge.net/scripts/fingerprint2.min.js', 'visit#', 318, {'Cwm fjordbank glyphs vext quiz, ðŸ˜ƒ'})
# ('Canvas fingerprinter', 'cdn1-a.production.vidio.static6.com/assets/ahoy-b182b001b52c44184ed9ee472c1d7398d73d6fb38a4e9b0537e271e092c069fe.js', 'visit#', 326, {'i9asdm..$#po((^@KbXrww!~cz'})
# ('Canvas fingerprinter', 'www.asos.com/akam/10/e477ca8', 'visit#', 333, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'ad-specs.guoshipartners.com/static/js/onead-pixel.min.js', 'visit#', 931, {'Cwm fjordbank glyphs vext quiz, https://github.com/valve ὠ'})
# ('Canvas fingerprinter', 'client.perimeterx.net/PX8FCGYgk4/main.min.js', 'visit#', 353, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'h5.360buyimg.com/ws_js/jdwebm.js', 'visit#', 350, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.sberbank.ru/portalserver/static/sb-bundle/js/group-ib-script.js', 'visit#', 370, {'Verdana Ref', 'Engravers MT', 'Goudy Old Style', 'sans-serif', 'Roboto Condensed', 'Arial Rounded MT Bold', 'Devanagari Sangam MN', 'High Tower Text', 'Bangla Sangam MN', 'Synchro LET', 'Droid Sans', 'Beesknees ITC', 'Kabel Ult BT', 'Baskerville', 'Champignon', 'Smudger LET', 'Haettenschweiler', 'Lucida Console', 'Lucida Sans', 'Jokerman LET', 'Hoefler Text', 'Baby Kruffy', 'Estrangelo Edessa', 'Bookman Old Style', 'Droid Sans Mono', 'Chalkduster', 'ParkAvenue BT', 'Adobe Fangsong Std', 'Niagara Solid', 'Kannada MN', 'Courier New', 'DejaVu Sans', 'Franklin Gothic Book', 'Abadi MT Condensed', 'Matisse ITC', 'Trebuchet MS', 'Bradley Hand ITC', 'Lucida Sans Typewriter', 'Scruff LET', 'Helvetica Neue', 'Monotype Corsiva', 'Cataneo BT', 'News Gothic MT', 'Viner Hand ITC', 'MisterEarl BT', 'Adobe Arabic', 'Arial Narrow', 'Comic Sans MS', 'Square721 BT', 'Baskerville Old Face', 'Arabic Typesetting', 'MS Reference Serif', 'DejaVu Serif', 'Segoe Print', 'Microsoft Himalaya', 'Kristen ITC', 'Roboto Slab', 'Lucida Handwriting', 'Bitstream Vera Sans', 'Malayalam MN', 'Staccato222 BT', 'Bitstream Vera Sans Mono', 'Abadi MT Condensed Light', 'Century Gothic', 'Malgun Gothic', 'Book Antiqua', 'Maiandra GD', 'Adobe Kaiti Std', 'Showcard Gothic', 'Microsoft YaHei', 'Times New Roman', 'Microsoft JhengHei', 'John Handy LET', 'Adobe Fan Heiti Std', 'Harrington'})
# ('Canvas fingerprinter', 'www.bestbuy.com/akam/10/158173e8', 'visit#', 377, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'yummy.consumable.com/3541/cnsmbl-audio-728x90-slider/widget/iframe.js', 'visit#', 378, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'aug.americanexpress.com/collector/cc.js', 'visit#', 386, {'AaBbCcDdEeFfGgHhIiJjKkLlMmNnOoPpQqRrSsTtUuVvWwXxYyZz0123456789'})
# ('Canvas fingerprinter', 'stc.qiyipic.com/', 'visit#', 382, {'Cwm fjordbank glyphs vext quiz, 😃Linux x86_64Firefox'})
# ('Canvas fingerprinter', 'security.iqiyi.com/static/cook/v1/cooksdk.js', 'visit#', 382, {'Cwm fjordbank glyphs vext quiz, 😃Linux x86_64Firefox'})
# ('Canvas fingerprinter', 's0.bukalapak.com/ast/vendor-496a5b08a478b21701ebcc2a022639e6cdda398c2d82a84dd0a508f2d48f3e83.js', 'visit#', 390, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'sdfestaticassets-us-west-2.sciencedirectassets.com/prod/ff6bc86f8536f22168461558301e24d1d1b41728/client.js', 'visit#', 409, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'assets.targetimg1.com/ssx/ssx.mod.js', 'visit#', 407, {'Hel$&?6%){mZ+#@'})
# ('Canvas fingerprinter', 'gateway.foresee.com/code/19.6.1/fs.utils.js', 'visit#', 422, {'ForeSee,CloudUser <canvas> 1.0'})
# ('Canvas fingerprinter', 'www.dell.com/akam/10/767c090f', 'visit#', 434, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'tags.tiqcdn.com/utag/orange/dnu/prod/utag.68.js', 'visit#', 435, {'٩(͡๏̯͡๏)۶٩(-̮̮̃•̃)۶٩(̾●̮̮̃̾•̃̾)۶٩(-̮̮̃-̃)۶(͡°͜ʖ͡°)', 'Mr. Jock, TV quiz Ph-D, bags few lynx!'})
# ('Canvas fingerprinter', 'www.homedepot.com/akam/10/49c9d94c', 'visit#', 436, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'www.homedepot.com/_bm/bd-1-30', 'visit#', 436, {'<@nv45. F1n63r,Pr1n71n6!'})
# ('Canvas fingerprinter', 'client.perimeterx.net/PXJ770cP7Y/main.min.js', 'visit#', 436, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.capitalone.com/_bm/bd-1-30', 'visit#', 438, {'<@nv45. F1n63r,Pr1n71n6!'})
# ('Canvas fingerprinter', 'deviceinfo.capitalone.com/collector/cc.js', 'visit#', 438, {'AaBbCcDdEeFfGgHhIiJjKkLlMmNnOoPpQqRrSsTtUuVvWwXxYyZz0123456789'})
# ('Canvas fingerprinter', 'gateway.foresee.com/code/19.5.0/fs.utils.js', 'visit#', 447, {'ForeSee,CloudUser <canvas> 1.0'})
# ('Canvas fingerprinter', 'client.perimeterx.net/PXZHh9f9x0/main.min.js', 'visit#', 464, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 't1.musthird.com/fp/check.js;CIS3SID=CBBD25536BA156C77C0A44EB120B3B38', 'visit#', 465, {'@Browsers~%fingGPRint$&,<canvas>'})
# ('Canvas fingerprinter', 'www.fedex.com/akam/10/42fcd055', 'visit#', 471, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'www.fedex.com/_bm/bd-1-30', 'visit#', 471, {'<@nv45. F1n63r,Pr1n71n6!'})
# ('Canvas fingerprinter', 'www.groupon.com/_bm/bd-1-30', 'visit#', 470, {'<@nv45. F1n63r,Pr1n71n6!'})
# ('Canvas fingerprinter', 'ad-specs.guoshipartners.com/static/js/isip.js', 'visit#', 483, {'Cwm fjordbank glyphs vext quiz, https://github.com/valve ὠ'})
# ('Canvas fingerprinter', 'g.alicdn.com/security/umscript/3.3.32/um.js', 'visit#', 489, {'Cwm fjordbank glyphs vext quiz, 馃槂'})
# ('Canvas fingerprinter', 'vk.me/js/cmodules/web/grip.js', 'visit#', 501, {'Cwm fjordbank glyphs vext quiz'})
# ('Canvas fingerprinter', 'chaoshi.tmall.com/', 'visit#', 504, {'Cwm fjordbank glyphs vext quiz'})
# ('Canvas fingerprinter', 'g.alicdn.com/mm/tanx-cdn/t/tanxssp.js', 'visit#', 504, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'h.imedia.cz/js/dot-small.js', 'visit#', 512, {'`abcdefghijklmnopqrstuvwx', '@ABCDEFGHIJKLMNOPQRSTUVWX', ' !"#$%&\'()*+,-./012345678'})
# ('Canvas fingerprinter', 'yummy.consumable.com/3913/cnsmbl-audio-responsive/widget/iframe.js', 'visit#', 507, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'online.citi.com/US/login.do', 'visit#', 535, {'Hel$&?6%){mZ+#@'})
# ('Canvas fingerprinter', 'cdn0-a.production.vidio.static6.com/assets/ahoy-dbdab142d5f4859e99e30730b0e7153afc91b13a21a9e1953fa96ac2b9a0b1c1.js', 'visit#', 667, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'gateway.foresee.com/code/19.6.8/fs.utils.js', 'visit#', 555, {'ForeSee,CloudUser <canvas> 1.0'})
# ('Canvas fingerprinter', 'cdn.simility.com/b.js', 'visit#', 569, {'QmWnEbRv TcYxUz IlOkPjAhSgDf'})
# ('Canvas fingerprinter', 'www.naukri.com/akam/10/21475a', 'visit#', 579, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'icdn.lenta.ru/assets/webpack/440b4f8140db8d3550fa.vendors.js', 'visit#', 590, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'gateway.answerscloud.com/code/19.6.1/fs.utils.js', 'visit#', 594, {'ForeSee,CloudUser <canvas> 1.0'})
# ('Canvas fingerprinter', 'www.macys.com/akam/10/8e98aff', 'visit#', 607, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'cdn.selectablemedia.com/tg/p/tZHQmLNp/js/sm_uber.js', 'visit#', 645, {'http://valve.github.io'})
# ('Canvas fingerprinter', 'static.adtima.vn/resource/js/libs/fingerprint2.min.js', 'visit#', 648, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.mobile.de/akam/10/48c82282', 'visit#', 676, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'pf.newegg.com/na.js', 'visit#', 681, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'res.suning.cn/', 'visit#', 680, {'Suning Fingerprints/Canvas 1.0'})
# ('Canvas fingerprinter', 'www.porn.com/static/main-126.js', 'visit#', 710, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'tags.tiqcdn.com/utag/cisco/collaboration/prod/utag.16.js', 'visit#', 712, {'٩(͡๏̯͡๏)۶٩(-̮̮̃•̃)۶٩(̾●̮̮̃̾•̃̾)۶٩(-̮̮̃-̃)۶(͡°͜ʖ͡°)', 'Mr. Jock, TV quiz Ph-D, bags few lynx!'})
# ('Canvas fingerprinter', 'shop.nordstrom.com/_bm/bd-1-30', 'visit#', 714, {'<@nv45. F1n63r,Pr1n71n6!'})
# ('Canvas fingerprinter', 'gateway.answerscloud.com/code/19.6.8/fs.utils.js', 'visit#', 714, {'ForeSee,CloudUser <canvas> 1.0'})
# ('Canvas fingerprinter', 'd2fbkzyicji7c4.cloudfront.net/', 'visit#', 720, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.olx.ua/akam/10/2d38a754', 'visit#', 734, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'www.olx.ua/_bm/bd-1-30', 'visit#', 734, {'<@nv45. F1n63r,Pr1n71n6!'})
# ('Canvas fingerprinter', 'tags.tiqcdn.com/utag/cisco/home/prod/utag.56.js', 'visit#', 748, {'٩(͡๏̯͡๏)۶٩(-̮̮̃•̃)۶٩(̾●̮̮̃̾•̃̾)۶٩(-̮̮̃-̃)۶(͡°͜ʖ͡°)', 'Mr. Jock, TV quiz Ph-D, bags few lynx!'})
# ('Canvas fingerprinter', 'www.hotels.com/_bm/bd-1-30', 'visit#', 754, {'<@nv45. F1n63r,Pr1n71n6!'})
# ('Canvas fingerprinter', 'www.cdn-net.com/cc.js', 'visit#', 754, {'AaBbCcDdEeFfGgHhIiJjKkLlMmNnOoPpQqRrSsTtUuVvWwXxYyZz0123456789'})
# ('Canvas fingerprinter', 'hotmovs.com/husik/htmCtrl.js', 'visit#', 783, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.pof.com/', 'visit#', 800, {'http://www.plentyoffish.com'})
# ('Canvas fingerprinter', 'www.olx.pl/akam/10/329653d1', 'visit#', 804, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'www.myntra.com/akam/10/779e8e39', 'visit#', 808, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'www.myntra.com/_bm/bd-1-30', 'visit#', 808, {'<@nv45. F1n63r,Pr1n71n6!'})
# ('Canvas fingerprinter', 'cdn.selectablemedia.com/tg/p/ioRpChND/js/sm_uber.js', 'visit#', 807, {'http://valve.github.io'})
# ('Canvas fingerprinter', 'yummy.consumable.com/2438/cnsmbl-audio-300x250-slider/widget/iframe.js', 'visit#', 827, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.bhphotovideo.com/otohphnbwwwbtebxcxvyrdxvqvwzavvuusrvd.js', 'visit#', 874, {'Cwm fjordbank glyphs vext quiz, ðŸ˜ƒ'})
# ('Canvas fingerprinter', 'www.kohls.com/akam/10/48fd8e6', 'visit#', 880, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'www.kohls.com/_bm/bd-1-30', 'visit#', 880, {'<@nv45. F1n63r,Pr1n71n6!'})
# ('Canvas fingerprinter', 'squid.gazeta.pl/bdtrck/getBdIf', 'visit#', 881, {'http://valve.github.io'})
# ('Canvas fingerprinter', 'www.fidelity.com/_bm/bd-1-30', 'visit#', 895, {'<@nv45. F1n63r,Pr1n71n6!'})
# ('Canvas fingerprinter', 'www.clarin.com/weizenbock/dist/min.js', 'visit#', 904, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.costco.com/akam/10/586297a0', 'visit#', 925, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'www.kayak.com/px/client/main.min.js', 'visit#', 927, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'tags.tiqcdn.com/utag/wsjdn/marketwatch/prod/utag.79.js', 'visit#', 935, {'٩(͡๏̯͡๏)۶٩(-̮̮̃•̃)۶٩(̾●̮̮̃̾•̃̾)۶٩(-̮̮̃-̃)۶(͡°͜ʖ͡°)', 'Mr. Jock, TV quiz Ph-D, bags few lynx!'})
# ('Canvas fingerprinter', 'i.imedia.cz/js/im3light.js', 'visit#', 939, {'`abcdefghijklmnopqrstuvwx', '@ABCDEFGHIJKLMNOPQRSTUVWX', ' !"#$%&\'()*+,-./012345678'})
# ('Canvas fingerprinter', 'www.southwest.com/assets/app/scripts/swa-common.js', 'visit#', 946, {'Hel$&?6%){mZ+#@'})
# ('Canvas fingerprinter', 'www.cbc.ca/akam/10/7840c69', 'visit#', 957, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'cdn.viafoura.net/vf.js', 'visit#', 957, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'teja10.kuikr.com/public/core/js/bakerst-min.1525432696.js', 'visit#', 963, {'You know my methods, Watson'})
# ('Canvas fingerprinter', 'a.libertystmedia.com/static', 'visit#', 962, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'himado.in/client.min.js', 'visit#', 969, {'ClientJS,org <canvas> 1.0'})
# ('Canvas fingerprinter', 'himado.in/fingerprint2.js', 'visit#', 969, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'c.adsco.re/', 'visit#', 981, {'mmiillII,)#!>⛄⛇ኹဪ߷֎៘'})
# ('Canvas fingerprinter', 'us.static.reallifecam.com/static/ng/js/rlc_standard.20180625-00.bundle.min.js', 'visit#', 979, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'www.gap.com/akam/10/472430f2', 'visit#', 976, {'Soft Ruddy Foothold 2', '!H71JCaj)]# 1@#'})
# ('Canvas fingerprinter', 'i.hh.ru/jsbuild/640419b5-libs.js', 'visit#', 989, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas fingerprinter', 'cdn.pulpix.com/static/pulpix.js', 'visit#', 985, {'Cwm fjordbank glyphs vext quiz, 😃'})
# ('Canvas font fingerprinter:', 'mathid.mathtag.com/d/i.js', 'visit#', 115, 'mmmmmmmmmmlli', 500, {'72px MicrogrammaDMedExt,sans-serif', '72px Star Jedi Hollow,monospace', '72px Budmo Jiggler,monospace', '72px Blue Highway Linocut,sans-serif', '72px LongIsland,serif', '72px Antique Olive CompactPS,monospace', '72px Jenna Sue,monospace', '72px Alba Matter,monospace', '72px ESRI Enviro Hazard Incident,monospace', '72px CG Omega,monospace', '72px Monotxt,sans-serif', '72px JACKIE,monospace', '72px CAMPBELL,monospace', '72px always * forever,serif', '72px PAINTSTROKE,sans-serif', '72px BRODY,monospace', '72px AdineKirnberg-Script,sans-serif', '72px 28 Days Later,serif', '72px AdineKirnberg-Script,monospace', '72px Things We Said,serif', '72px BethsCuteHmk,serif', '72px Gentium Book Basic,sans-serif', '72px Blue Highway Linocut,monospace', '72px CG Omega,sans-serif', '72px BethsCuteHmk,sans-serif', '72px odstemplik,sans-serif', '72px CaslonAntT,monospace', '72px Luciano,serif', '72px Teletype,monospace', '72px Nanum Myeongjo,serif', '72px Weltron Urban,serif', '72px Tango BT,serif', '72px LongIsland,monospace', '72px Alba Matter,serif', '72px Castro Script PERSONAL USE ONLY,serif', '72px BRODY,sans-serif', '72px English Essay,sans-serif', '72px MapInfo Cartographic,sans-serif', '72px Denmark,serif', '72px Circus,sans-serif', '72px Stars & Stripes,serif', '72px Times New Roman Symbol,sans-serif', '72px MS SystemEx,monospace', '72px San Diego,monospace', '72px Fontdinerdotcom Sparkly,monospace', '72px Wickenden Cafe NDP,serif', '72px Earwig Factory,sans-serif', '72px Luciano,sans-serif', '72px Tall Paul,sans-serif', '72px OPENCLASSIC,serif', '72px Fat,serif', '72px Tango BT,monospace', '72px 8514oem,serif', '72px Kiev,sans-serif', '72px Earwig Factory,monospace', '72px Utah,sans-serif', '72px Tabitha,sans-serif', '72px Gentium Book Basic,monospace', '72px ESRI NIMA City Graphic LN,sans-serif', '72px Carnivalee Freakshow,monospace', '72px Connecticut,sans-serif', '72px Kiev,monospace', '72px SAS Monospace,serif', '72px San Diego,serif', '72px Ribbon,sans-serif', '72px Respective 2.0,sans-serif', '72px Wickenden Cafe NDP,sans-serif', '72px serif', '72px ABIGAIL,sans-serif', '72px Sweetly Broken,monospace', '72px Teletype,serif', '72px Mishafi,monospace', '72px Lucida Grande CY,monospace', '72px Ostrich Sans Dashed Medium,monospace', '72px Loki Cola,sans-serif', '72px Sitka Subheading,monospace', '72px Boopee,sans-serif', '72px IRIS,monospace', '72px Opus Japanese Chords,sans-serif', '72px StarbabeHmk,serif', '72px Budmo Jiggler,sans-serif', '72px Huxtable,serif', '72px OptimusPrinceps,sans-serif', '72px Bimini,monospace', '72px OCR-A,monospace', '72px Girls are Weird,serif', '72px MAXIMO,sans-serif', '72px Urdu Typesetting,serif', '72px AR DARLING,sans-serif', '72px Weltron Urban,monospace', '72px Denmark,monospace', '72px Utah,monospace', '72px OldCentury,monospace', '72px OldCentury,sans-serif', '72px Impact Label Reversed,sans-serif', '72px Jenna Sue,sans-serif', '72px Ethnocentric,sans-serif', '72px Incised901 BdCn BT,sans-serif', '72px Nanum Myeongjo,monospace', '72px Fontdinerdotcom Sparkly,serif', '72px KG Skinny Latte,serif', '72px Taffy,serif', '72px NewZurica,sans-serif', '72px 1942 report,monospace', '72px GilliesGotDLig,sans-serif', '72px TextilePiEF,sans-serif', '72px DK Crayon Crumble,sans-serif', '72px ESRI Enviro Hazard Incident,serif', '72px Ribbon,monospace', '72px Almonte Snow,sans-serif', '72px Jenna Sue,serif', '72px AR DARLING,monospace', '72px Connecticut,monospace', '72px Agent Orange,serif', '72px Kefa,serif', '72px HUNTSON,serif', '72px Josefin Slab,monospace', '72px Kefa,monospace', '72px HenryMorganHand,sans-serif', '72px Before the Rain Swashes DEMO,monospace', '72px Nanum Myeongjo,sans-serif', '72px GilliesGotDLig,monospace', '72px MARKETPRO,serif', '72px Oxford,monospace', '72px JACKIE,serif', '72px OttumHmk,monospace', '72px Rod Transparent,monospace', '72px Stereofidelic,sans-serif', '72px Jenkins v2.0,s ...
# ('Canvas font fingerprinter:', 'assets.targetimg1.com/ssx/ssx.mod.js', 'visit#', 407, '0-_{w.', 500, {'72px MicrogrammaDMedExt,sans-serif', '72px Star Jedi Hollow,monospace', '72px Budmo Jiggler,monospace', '72px Blue Highway Linocut,sans-serif', '72px LongIsland,serif', '72px Antique Olive CompactPS,monospace', '72px Jenna Sue,monospace', '72px Alba Matter,monospace', '72px ESRI Enviro Hazard Incident,monospace', '72px CG Omega,monospace', '72px Monotxt,sans-serif', '72px JACKIE,monospace', '72px CAMPBELL,monospace', '72px always * forever,serif', '72px PAINTSTROKE,sans-serif', '72px BRODY,monospace', '72px AdineKirnberg-Script,sans-serif', '72px 28 Days Later,serif', '72px AdineKirnberg-Script,monospace', '72px Things We Said,serif', '72px BethsCuteHmk,serif', '72px Gentium Book Basic,sans-serif', '72px Blue Highway Linocut,monospace', '72px CG Omega,sans-serif', '72px BethsCuteHmk,sans-serif', '72px odstemplik,sans-serif', '72px CaslonAntT,monospace', '72px Luciano,serif', '72px Teletype,monospace', '72px Nanum Myeongjo,serif', '72px Weltron Urban,serif', '72px Tango BT,serif', '72px LongIsland,monospace', '72px Alba Matter,serif', '72px Castro Script PERSONAL USE ONLY,serif', '72px BRODY,sans-serif', '72px English Essay,sans-serif', '72px MapInfo Cartographic,sans-serif', '72px Denmark,serif', '72px Circus,sans-serif', '72px Stars & Stripes,serif', '72px Times New Roman Symbol,sans-serif', '72px MS SystemEx,monospace', '72px San Diego,monospace', '72px Fontdinerdotcom Sparkly,monospace', '72px Wickenden Cafe NDP,serif', '72px Earwig Factory,sans-serif', '72px Luciano,sans-serif', '72px Tall Paul,sans-serif', '72px OPENCLASSIC,serif', '72px Fat,serif', '72px Tango BT,monospace', '72px 8514oem,serif', '72px Kiev,sans-serif', '72px Earwig Factory,monospace', '72px Utah,sans-serif', '72px Tabitha,sans-serif', '72px Gentium Book Basic,monospace', '72px ESRI NIMA City Graphic LN,sans-serif', '72px Carnivalee Freakshow,monospace', '72px Connecticut,sans-serif', '72px Kiev,monospace', '72px SAS Monospace,serif', '72px San Diego,serif', '72px Ribbon,sans-serif', '72px Respective 2.0,sans-serif', '72px Wickenden Cafe NDP,sans-serif', '72px serif', '72px ABIGAIL,sans-serif', '72px Sweetly Broken,monospace', '72px Teletype,serif', '72px Mishafi,monospace', '72px Lucida Grande CY,monospace', '72px Ostrich Sans Dashed Medium,monospace', '72px Loki Cola,sans-serif', '72px Sitka Subheading,monospace', '72px Boopee,sans-serif', '72px IRIS,monospace', '72px Opus Japanese Chords,sans-serif', '72px StarbabeHmk,serif', '72px Budmo Jiggler,sans-serif', '72px Huxtable,serif', '72px OptimusPrinceps,sans-serif', '72px Bimini,monospace', '72px OCR-A,monospace', '72px Girls are Weird,serif', '72px MAXIMO,sans-serif', '72px Urdu Typesetting,serif', '72px AR DARLING,sans-serif', '72px Weltron Urban,monospace', '72px Denmark,monospace', '72px Utah,monospace', '72px OldCentury,monospace', '72px OldCentury,sans-serif', '72px Impact Label Reversed,sans-serif', '72px Jenna Sue,sans-serif', '72px Ethnocentric,sans-serif', '72px Incised901 BdCn BT,sans-serif', '72px Nanum Myeongjo,monospace', '72px Fontdinerdotcom Sparkly,serif', '72px KG Skinny Latte,serif', '72px Taffy,serif', '72px NewZurica,sans-serif', '72px 1942 report,monospace', '72px GilliesGotDLig,sans-serif', '72px TextilePiEF,sans-serif', '72px DK Crayon Crumble,sans-serif', '72px ESRI Enviro Hazard Incident,serif', '72px Ribbon,monospace', '72px Almonte Snow,sans-serif', '72px Jenna Sue,serif', '72px AR DARLING,monospace', '72px Connecticut,monospace', '72px Agent Orange,serif', '72px Kefa,serif', '72px HUNTSON,serif', '72px Josefin Slab,monospace', '72px Kefa,monospace', '72px HenryMorganHand,sans-serif', '72px Before the Rain Swashes DEMO,monospace', '72px Nanum Myeongjo,sans-serif', '72px GilliesGotDLig,monospace', '72px MARKETPRO,serif', '72px Oxford,monospace', '72px JACKIE,serif', '72px OttumHmk,monospace', '72px Rod Transparent,monospace', '72px Stereofidelic,sans-serif', '72px Jenkins v2 ...
# ('Canvas font fingerprinter:', 'connect.secure.wellsfargo.com/jenny/nd', 'visit#', 226, 'mmmmmmmmmmlli', 69, {'72px "Impact"', '72px "Arial Black"', '72px "Cambria Math"', '72px "Georgia"', '72px "Andale Mono"', '72px "Lucida Console"', '72px "Century Gothic"', '72px "Garamond"', '72px "Bookman Old Style"', '72px "Segoe Script"', '72px "Lucida Sans"', '72px "Arial Rounded MT Bold"', '72px "Bitstream Vera Sans Mono"', '72px "Comic Sans"', '72px "Courier"', '72px "Geneva"', '72px "MS Outlook"', '72px "Arial"', '72px "MS Reference Sans Serif"', '72px "Segoe UI"', '72px "Comic Sans MS"', '72px "Helvetica"', '72px "Lucida Fax"', '72px "MYRIAD PRO"', '72px "Times New Roman PS"', '72px "Monotype Corsiva"', '72px "MYRIAD"', '72px "Verdana"', '72px "serif"', '72px "Lucida Sans Unicode"', '72px "MS Gothic"', '72px "Wingdings 3"', '72px "Arial Unicode MS"', '72px "Lucida Calligraphy"', '72px "Wingdings 2"', '72px "Times"', '72px "Trebuchet MS"', '72px "Cambria"', '72px "Century"', '72px "Palatino Linotype"', '72px "Helvetica Neue"', '72px "Century Schoolbook"', '72px "Courier New"', '72px "MS Serif"', '72px "Arial MT"', '72px "Segoe Print"', '72px "Segoe UI Symbol"', '72px "Tahoma"', '72px "Arial Hebrew"', '72px "Microsoft Sans Serif"', '72px "Book Antiqua"', '72px "Monaco"', '72px "Segoe UI Semibold"', '72px "Wingdings"', '18pt Arial', '72px "sans-serif"', '72px "Lucida Bright"', '72px "Arial Narrow"', '72px "Times New Roman"', '72px "MS Sans Serif"', '72px "Lucida Sans Typewriter"', '72px "monospace"', '72px "LUCIDA GRANDE"', '72px "Palatino"', '72px "Calibri"', '72px "Segoe UI Light"', '72px "Lucida Handwriting"', '72px "Consolas"', '72px "MS PGothic"'})
# ('Canvas font fingerprinter:', 't1.musthird.com/fp/check.js;CIS3SID=CBBD25536BA156C77C0A44EB120B3B38', 'visit#', 465, 'gMcdefghijklmnopqrstuvwxyz0123456789', 176, {"72px 'System', serif", "72px 'Loma', monospace", "72px 'Nimbus Sans L Condensed', serif", "72px 'DejaVu Sans', serif", "72px 'DejaVu Sans Mono', serif", "72px 'TlwgTypewriter', serif", "72px 'Ubuntu', monospace", "72px 'Ume Mincho', serif", "72px 'OpenSymbol', monospace", "72px 'Norasi', serif", "72px 'Ume P Gothic', serif", "72px 'Norasi', monospace", "72px 'Comic Sans MS', monospace", "72px 'FreeSerif', monospace", "72px 'Dotum', monospace", "72px 'Ubuntu', serif", "72px 'Pothana2000', serif", "72px 'DejaVu LGC Sans', monospace", "72px 'Phetsarath OT', serif", "72px 'Times', serif", "72px 'Sawasdee', serif", "72px 'Monospace', monospace", "72px 'Rachana', monospace", "72px 'DejaVu Serif', serif", "72px 'Purisa', monospace", "72px 'Times', monospace", "72px 'Waree', monospace", "72px 'Hei', serif", "72px 'Ume Gothic', serif", "72px 'ori1Uni', monospace", "72px 'Tlwg Typist', serif", "72px 'UnBatang', serif", "72px 'Kinnari', monospace", "72px 'Droid Sans', serif", "72px 'gargi', monospace", "72px 'Lucida Bright', serif", "72px 'Untitled1', monospace", "72px 'Vemana2000', serif", "72px 'gargi', serif", "72px 'Garuda', monospace", "72px 'mry_KacstQurn', monospace", "72px 'Mukti Narrow', serif", "72px 'NanumGothic', serif", "72px 'Ume Mincho', monospace", "72px 'Lohit Bengali', monospace", "72px 'Mallige', serif", "72px 'DejaVu Sans', monospace", "72px 'Meera', monospace", "72px 'UnGungseo', serif", "72px 'UnPilgi', monospace", "72px 'Andale Mono', serif", "72px 'DejaVu Serif', monospace", "72px 'Bitstream Vera Sans', monospace", "72px 'Nimbus Sans L Condensed', monospace", "72px 'Ume P Gothic', monospace", "72px 'Ume P Mincho', monospace", "72px 'WenQuanYi Micro Hei', monospace", "72px 'Khmer OS', monospace", "72px 'Mallige', monospace", "72px 'Georgia', serif", "72px 'Phetsarath OT', monospace", "72px 'WenQuanYi Micro Hei', serif", "72px 'Comic Sans MS', serif", "72px 'Courier New', serif", "72px 'OpenSymbol', serif", "72px 'FreeMono', monospace", "72px 'KacstArt', serif", "72px 'Cursor', serif", "72px 'Monospace', serif", "72px 'ori1Uni', serif", "72px 'Ubuntu Condensed', monospace", "72px 'TakaoPGothic', monospace", "72px 'Lucida Sans', monospace", "72px 'Waree', serif", "72px 'TlwgMono', serif", "72px 'NanumGothic', monospace", "72px 'Saab', serif", "72px 'Webdings', serif", "72px 'Lucida Sans Typewriter', monospace", "72px 'Ume Gothic', monospace", "72px 'NanumMyeongjo', monospace", "72px 'TakaoPGothic', serif", '72px serif', '8px Arial', '72px monospace', "72px 'Dotum', serif", "72px 'Georgia', monospace", "72px 'Arial Black', serif", "72px 'FreeSans', serif", "72px 'UnGraphic', serif", "72px 'Kinnari', serif", "72px 'Droid Sans', monospace", "72px 'UnDotum', monospace", "72px 'KacstArt', monospace", "72px 'WenQuanYi Bitmap Song', serif", "72px 'Luxi Mono', serif", "72px 'Garuda', serif", "72px 'Tlwg Typo', monospace", "72px 'UnDinaru', serif", "72px 'FreeMono', serif", "72px 'Arial', monospace", "72px 'Kedage', monospace", "72px 'Ume UI Gothic', serif", "72px 'Bitstream Vera Sans', serif", "72px 'AR PL UKai CN', monospace", "72px 'Lucida Sans', serif", "72px 'Luxi Mono', monospace", "72px 'DejaVu Sans Mono', monospace", "72px 'AR PL UMing CN', monospace", "72px 'DejaVu LGC Sans', serif", "72px 'System', monospace", "72px 'Hei', monospace", "72px 'UnGungseo', monospace", "72px 'WenQuanYi Zen Hei', serif", "72px 'Lucida Sans Typewriter', serif", "72px 'Arial Black', monospace", '12px Arial', "72px 'Rekha', monospace", "72px 'Rekha', serif", "72px 'TlwgTypewriter', monospace", "72px 'Trebuchet MS', serif", "72px 'Mukti Narrow', monospace", "72px 'Ubuntu Condensed', serif", "72px 'Webdings', monospace", "72px 'Untitled1', serif", "72px 'FreeSans', monospace", "72px 'Purisa', serif", "72px 'Saab', monospace", "72px 'Batang', monospace", "72px 'Liberation Sans Narr ...
# ('Canvas font fingerprinter:', 'online.citi.com/US/login.do', 'visit#', 535, '0-_{w.', 94, {"50px 'Calibri', serif", "50px 'Brush Script MT', serif", "50px 'Microsoft Uighur', sans-serif", "50px 'Urdu Typesetting', sans-serif", "50px 'Traditional Arabic', sans-serif", "50px 'Geneva', serif", "50px 'Brush Script', sans-serif", "50px 'Wingdings 3', sans-serif", "50px 'Liberation Sans Narrow', serif", "50px 'DejaVu Serif Condensed', sans-serif", "50px 'Wingdings', serif", "50px 'Microsoft YaHei UI', sans-serif", "50px 'Futura', serif", "50px 'Forte', sans-serif", "50px 'Urdu Typesetting', serif", "50px 'Bell MT', serif", "50px 'Courier New', sans-serif", "50px 'STSong', sans-serif", "50px 'Curlz MT', sans-serif", "50px 'Bell MT', sans-serif", "50px 'Droid Sans Fallback', sans-serif", "50px 'Marlett', sans-serif", "50px 'NanumGothic', serif", "50px 'Curlz MT', serif", "50px 'Andale Mono', sans-serif", "50px 'Charter', serif", "50px 'Liberation Sans Narrow', sans-serif", "50px 'Charter', sans-serif", "50px 'Arial Narrow', sans-serif", "50px 'Levenim MT', serif", "50px 'MS Mincho', serif", "50px 'DejaVu Serif Condensed', serif", "50px 'Courier New', serif", "50px 'Levenim MT', sans-serif", "50px 'Calibri', sans-serif", "50px 'Forte', serif", "50px 'SimHei', sans-serif", "50px 'Traditional Arabic', serif", "50px 'Verdana', serif", "50px 'Geneva', sans-serif", "50px 'PT Serif', serif", "50px 'Microsoft YaHei UI', serif", "50px 'DejaVu Sans Mono', sans-serif", "50px 'Brush Script', serif", "50px 'PT Serif', sans-serif", "50px 'PMingLiU', serif", "50px 'Droid Serif', serif", "50px 'Hei', sans-serif", "50px 'Microsoft Uighur', serif", "50px 'SimHei', serif", "50px 'Wingdings 3', serif", "50px 'MS Mincho', sans-serif", "50px 'STIXVariants', serif", "50px 'serif', serif", "50px 'Wingdings', sans-serif", "50px 'sans-serif', sans-serif", "50px 'Arial Narrow', serif", "50px 'MS UI Gothic', serif", "50px 'Andale Mono', serif", "50px 'STSong', serif", "50px 'MS UI Gothic', sans-serif", "50px 'Liberation Sans', serif", "50px 'Papyrus', serif", "50px 'Droid Sans Fallback', serif", "50px 'Arial Unicode MS', serif", "50px 'Arial Unicode MS', sans-serif", "50px 'Droid Serif', sans-serif", "50px 'PMingLiU', sans-serif", "50px 'NanumGothic', sans-serif", "50px 'Hei', serif", "50px 'Droid Sans', sans-serif", "50px 'Batang', serif", "50px 'Courier', serif", "50px 'Meiryo UI', sans-serif", "50px 'Meiryo UI', serif", "50px 'Nirmala UI', sans-serif", "50px 'Brush Script MT', sans-serif", "50px 'Leelawadee', sans-serif", "50px 'Droid Sans', serif", "50px 'Nirmala UI', serif", '18pt Sans', "50px 'Liberation Sans', sans-serif", "50px 'Palatino', serif", "50px 'Courier', sans-serif", "50px 'Futura', sans-serif", "50px 'DejaVu Sans', sans-serif", "50px 'Leelawadee', serif", "50px 'Marlett', serif", "50px 'STIXVariants', sans-serif", "50px 'Batang', sans-serif", "50px 'Palatino', sans-serif", "50px 'DejaVu Sans', serif", "50px 'Papyrus', sans-serif", "50px 'Verdana', sans-serif"})
# ('Canvas font fingerprinter:', 'www.southwest.com/assets/app/scripts/swa-common.js', 'visit#', 946, '0-_{w.', 96, {"50px 'Calibri', serif", "50px 'Brush Script MT', serif", "50px 'Microsoft Uighur', sans-serif", "50px 'Urdu Typesetting', sans-serif", "50px 'Traditional Arabic', sans-serif", "50px 'Geneva', serif", "50px 'Brush Script', sans-serif", "50px 'Wingdings 3', sans-serif", "50px 'Liberation Sans Narrow', serif", "50px 'DejaVu Serif Condensed', sans-serif", "50px 'Wingdings', serif", "50px 'Microsoft YaHei UI', sans-serif", "50px 'Futura', serif", "50px 'Forte', sans-serif", "50px 'Urdu Typesetting', serif", "50px 'Bell MT', serif", "50px 'Courier New', sans-serif", "50px 'STSong', sans-serif", "50px 'Curlz MT', sans-serif", "50px 'Bell MT', sans-serif", "50px 'Droid Sans Fallback', sans-serif", "50px 'Marlett', sans-serif", "50px 'NanumGothic', serif", "50px 'Curlz MT', serif", "50px 'Andale Mono', sans-serif", "50px 'Charter', serif", "50px 'Liberation Sans Narrow', sans-serif", "50px 'Charter', sans-serif", "50px 'Arial Narrow', sans-serif", "50px 'Levenim MT', serif", "50px 'MS Mincho', serif", "50px 'DejaVu Serif Condensed', serif", "50px 'Courier New', serif", "50px 'Levenim MT', sans-serif", "50px 'Helkevtrica', sans-serif", "50px 'Calibri', sans-serif", "50px 'Forte', serif", "50px 'SimHei', sans-serif", "50px 'Helkevtrica', serif", "50px 'Traditional Arabic', serif", "50px 'Verdana', serif", "50px 'Geneva', sans-serif", "50px 'PT Serif', serif", "50px 'Microsoft YaHei UI', serif", "50px 'DejaVu Sans Mono', sans-serif", "50px 'Brush Script', serif", "50px 'PT Serif', sans-serif", "50px 'PMingLiU', serif", "50px 'Droid Serif', serif", "50px 'Hei', sans-serif", "50px 'Microsoft Uighur', serif", "50px 'SimHei', serif", "50px 'Wingdings 3', serif", "50px 'MS Mincho', sans-serif", "50px 'STIXVariants', serif", "50px 'serif', serif", "50px 'Wingdings', sans-serif", "50px 'sans-serif', sans-serif", "50px 'Arial Narrow', serif", "50px 'MS UI Gothic', serif", "50px 'Andale Mono', serif", "50px 'STSong', serif", "50px 'MS UI Gothic', sans-serif", "50px 'Liberation Sans', serif", "50px 'Papyrus', serif", "50px 'Droid Sans Fallback', serif", "50px 'Arial Unicode MS', serif", "50px 'Arial Unicode MS', sans-serif", "50px 'Droid Serif', sans-serif", "50px 'PMingLiU', sans-serif", "50px 'NanumGothic', sans-serif", "50px 'Hei', serif", "50px 'Droid Sans', sans-serif", "50px 'Batang', serif", "50px 'Courier', serif", "50px 'Meiryo UI', sans-serif", "50px 'Meiryo UI', serif", "50px 'Nirmala UI', sans-serif", "50px 'Brush Script MT', sans-serif", "50px 'Leelawadee', sans-serif", "50px 'Droid Sans', serif", "50px 'Nirmala UI', serif", '18pt Sans', "50px 'Liberation Sans', sans-serif", "50px 'Palatino', serif", "50px 'Courier', sans-serif", "50px 'Futura', sans-serif", "50px 'DejaVu Sans', sans-serif", "50px 'Leelawadee', serif", "50px 'Marlett', serif", "50px 'STIXVariants', sans-serif", "50px 'Batang', sans-serif", "50px 'Palatino', sans-serif", "50px 'DejaVu Sans', serif", "50px 'Papyrus', sans-serif", "50px 'Verdana', sans-serif"})
# ('Audio context fingerprinter:', 'client.perimeterx.net/PXHYx10rg3/main.min.js', 'visit#', 287)
# ('Audio context fingerprinter:', 'www.fiverr.com/px/client/PXK3bezZfO/main.min.js', 'visit#', 299)
# ('Audio context fingerprinter:', 'client.perimeterx.net/PXSs13U803/main.min.js', 'visit#', 310)
# ('Audio context fingerprinter:', 'client.perimeterx.net/PX8FCGYgk4/main.min.js', 'visit#', 353)
# ('Audio context fingerprinter:', 'h5.360buyimg.com/ws_js/jdwebm.js', 'visit#', 350)
# ('Audio context fingerprinter:', 'client.perimeterx.net/PXJ770cP7Y/main.min.js', 'visit#', 436)
# ('Audio context fingerprinter:', 'client.perimeterx.net/PXZHh9f9x0/main.min.js', 'visit#', 464)
# ('Audio context fingerprinter:', 'online.citi.com/US/login.do', 'visit#', 535)
# ('Audio context fingerprinter:', 'www.kayak.com/px/client/main.min.js', 'visit#', 927)
# ('WebRTC fingerprinter:', 'g.alicdn.com/secdev/sufei_data/3.5.3/index.js', 'visit#', 12)
# ('WebRTC fingerprinter:', 'assets.alicdn.com/g/secdev/sufei_data/3.5.3/index.js', 'visit#', 42)
# ('WebRTC fingerprinter:', 'g.alicdn.com/security/umscript/3.3.28/um.js', 'visit#', 77)
# ('WebRTC fingerprinter:', 'static-hw.xvideos.com/v-d31bdf90334/v3/js/skins/min/default.header.static.js', 'visit#', 91)
# ('WebRTC fingerprinter:', 'i.bimbolive.com/js-min/1Fy3LY/hg.js', 'visit#', 110)
# ('WebRTC fingerprinter:', 'secure.bankofamerica.com/login/sign-in/cc.go', 'visit#', 206)
# ('WebRTC fingerprinter:', 'static-hw.xvideos.com/v-b969d7273a9/v3/js/skins/min/xnxx.header.static.js', 'visit#', 258)
# ('WebRTC fingerprinter:', 'fyrsbckgi-c.global.ssl.fastly.net/UP4R77Y9Z.js', 'visit#', 310)
# ('WebRTC fingerprinter:', 'aug.americanexpress.com/collector/cc.js', 'visit#', 386)
# ('WebRTC fingerprinter:', 'assets.targetimg1.com/ssx/ssx.mod.js', 'visit#', 407)
# ('WebRTC fingerprinter:', 't1.musthird.com/fp/check.js;CIS3SID=CBBD25536BA156C77C0A44EB120B3B38', 'visit#', 465)
# ('WebRTC fingerprinter:', 'g.alicdn.com/security/umscript/3.3.32/um.js', 'visit#', 489)
# ('WebRTC fingerprinter:', 'online.citi.com/US/login.do', 'visit#', 535)
# ('WebRTC fingerprinter:', 'pixel.yabidos.com/flimpobj.js', 'visit#', 546)
# ('WebRTC fingerprinter:', 'cdn.simility.com/b.js', 'visit#', 569)
# ('WebRTC fingerprinter:', 'pixel.cdnwidget.com/cdn/c.min.js', 'visit#', 585)
# ('WebRTC fingerprinter:', 'scdn.eclick.vn/delivery/asset/306001761/adsbyeclick.js', 'visit#', 735)
# ('WebRTC fingerprinter:', 'www.cdn-net.com/cc.js', 'visit#', 754)
# ('WebRTC fingerprinter:', 'c.adsco.re/', 'visit#', 981)
# high level in extract features
# ('Feature extraction completed in', 13.091511249542236, 'seconds')
# ('Features are written into:', '/home/marleensteinhoff/UNi/Projektseminar/Datenanalyse/analysis/features.csv')

# %%
def get_adblock_rules():
    raw_easylist_rules = read_ab_rules_from_file("analysis_utils/easylist.txt")
    raw_easyprivacy_rules = read_ab_rules_from_file("analysis_utils/easyprivacy.txt")
    raw_cookie_rules = read_ab_rules_from_file("analysis_utils/fanboy-cookiemonster.txt")
    if ENABLE_UBLOCK:
        raw_ublock_rules = read_ab_rules_from_file("analysis_utils/adblock_blacklist_white.txt")
    else:
        raw_ublock_rules = []
    print(("Loaded %s from EasyList, %s rules from EasyPrivacy, %s from Cookiemonster"
           " and %s rules from UBlockOrigin" %
           (len(raw_easylist_rules), len(raw_easyprivacy_rules), len(raw_cookie_rules),
            len(raw_ublock_rules))))
    easylist_rules = AdblockRules(raw_easylist_rules)
    easyprivacy_rules = AdblockRules(raw_easyprivacy_rules)
    ublock_rules = AdblockRules(raw_ublock_rules)
    cookie_rules = AdblockRules(raw_cookie_rules)

    return easylist_rules, easyprivacy_rules, ublock_rules, cookie_rules
def get_base_script_url(script_url):
    return script_url.split("//")[1].split("/")[0]

easylist_rules, easyprivacy_rules, ublock_rules, cookie_rules = get_adblock_rules()
# Out:
# Loaded 54173 from EasyList, 29570 rules from EasyPrivacy, 23687 from Cookiemonster and 0 rules from UBlockOrigin

# %%
def get_cookies(max_rank=0):
    db_file= "/home/marleensteinhoff/UNi/Projektseminar/Datenanalyse/data/Samples/2018-06.sqlite"
    connection = sqlite3.connect(db_file)
    connection.row_factory = sqlite3.Row
    c = connection.cursor()
    querycookie = """SELECT *
            FROM javascript_cookies as js 
            """

    if max_rank:
        query += " AND js.visit_id <= %i" % max_rank

    for row in c.execute(querycookie):
        print(row.keys())
        visit_id = row["visit_id"]
        is_http_only = row["is_http_only"]
        name = row["name"]
        path = row["path"]
        value = row["value"]
        is_session = row["is_session"]
        policy = row["policy"]
        host = row["host"]
        is_domain=row["is_domain"]
        is_secure=row["is_secure"]

        #print(visit_id, is_http_only, name, path, value, is_session, policy, host, is_domain, is_secure)
        is_tracking_cookie = False
  
        
        break

# %%
get_cookies()
# Out:
# ['id', 'crawl_id', 'visit_id', 'change', 'creationTime', 'expiry', 'is_http_only', 'is_session', 'last_accessed', 'raw_host', 'expires', 'host', 'is_domain', 'is_secure', 'name', 'path', 'policy', 'status', 'value']

# %%
    querycookie = """SELECT js.visit_id, js.record_type, js.is_http_only, 
    js.is_host_only, js.name, js.path, js.value, js.same_site, js.first_party_domain
            FROM javascript_cookies as js LEFT JOIN site_visits as sv
            ON sv.visit_id = js.visit_id WHERE
            js.script_url <> ''
            """
# Out:
# ['www.google-analytics.com/analytics.js',
#  'connect.facebook.net/en_US/sdk.js',
#  'staticxx.facebook.com/connect/xd_arbiter/r/xaOI6zd9HW9.js',
#  'ssl.google-analytics.com/ga.js',
#  'pagead2.googlesyndication.com/pagead/js/adsbygoogle.js',
#  'www.googleadservices.com/pagead/conversion_async.js',
#  'vars.hotjar.com/rcj-99d43ead6bdf30da8ed5ffcb4f17100c.html',
#  'platform.twitter.com/widgets.js',
#  'platform.twitter.com/widgets/widget_iframe.c5b006ac082bc92aa829181b9ce63af1.html',
#  'www.googletagmanager.com/gtm.js',
#  'www.google-analytics.com/plugins/ua/linkid.js',
#  'js-agent.newrelic.com/nr-1071.min.js',
#  'cdn.siftscience.com/s.js',
#  's0.wp.com/wp-content/js/devicepx-jetpack.js',
#  'cdn.onesignal.com/sdks/OneSignalSDK.js',
#  'googleads.g.doubleclick.net/pagead/ads',
#  'maps.googleapis.com/maps/api/js',
#  'js.hsleadflows.net/leadflows.js',
#  'maps.googleapis.com/maps-api-v3/api/js/33/5/common.js',
#  'maps.googleapis.com/maps-api-v3/api/js/33/5/util.js',
#  'secure.gravatar.com/js/gprofiles.js',
#  'load.sumo.com/',
#  'www.google-analytics.com/analytics.js',
#  'connect.facebook.net/en_US/sdk.js',
#  'staticxx.facebook.com/connect/xd_arbiter/r/xaOI6zd9HW9.js',
#  'ssl.google-analytics.com/ga.js',
#  'pagead2.googlesyndication.com/pagead/js/adsbygoogle.js',
#  'www.googleadservices.com/pagead/conversion_async.js',
#  'vars.hotjar.com/rcj-99d43ead6bdf30da8ed5ffcb4f17100c.html',
#  'platform.twitter.com/widgets.js',
#  'platform.twitter.com/widgets/widget_iframe.c5b006ac082bc92aa829181b9ce63af1.html',
#  'www.googletagmanager.com/gtm.js',
#  'www.google-analytics.com/plugins/ua/linkid.js',
#  'js-agent.newrelic.com/nr-1071.min.js',
#  'cdn.siftscience.com/s.js',
#  's0.wp.com/wp-content/js/devicepx-jetpack.js',
#  'cdn.onesignal.com/sdks/OneSignalSDK.js',
#  'googleads.g.doubleclick.net/pagead/ads',
#  'maps.googleapis.com/maps/api/js',
#  'js.hsleadflows.net/leadflows.js',
#  'maps.googleapis.com/maps-api-v3/api/js/33/5/common.js',
#  'maps.googleapis.com/maps-api-v3/api/js/33/5/util.js',
#  'secure.gravatar.com/js/gprofiles.js',
#  'load.sumo.com/']

# %%
NO_RANK
# Out:
# ['www.edgenuity.com/wp-content/themes/html5blank-stable/js/lib/modernizr-2.7.1.min.js',
#  'www.edgenuity.com/wp-includes/js/wp-embed.min.js',
#  'app.cdn.lookbookhq.com/production/jukebox/current/jukebox.js',
#  'maps.gstatic.com/maps-api-v3/embed/js/33/5/init_embed.js',
#  'rum-static.pingdom.net/pa-5abd39c74c40770007000562.js',
#  'jukebox.lookbookhq.com/cookie-iframe.html',
#  'home.pandorabots.com/lib/require.js',
#  'home.pandorabots.com/lib/ace/ace.js',
#  'home.pandorabots.com/lib/jquery.history.js',
#  'home.pandorabots.com/lib/jQuery-File-Upload/js/jquery.fileupload.js',
#  'home.pandorabots.com/lib/jquery.cookie.js',
#  'www.wanderio.com/',
#  'cloudfront.wanderio.com/client/vendor-dc34ae1d84546327e479.js',
#  'cloudfront.wanderio.com/client/main-e14039d68970e22a8a29.js',
#  'cloudfront.wanderio.com/client/LandingPage-54ecef370ffe476553d0.js',
#  'd24n15hnbwhuhn.cloudfront.net/libs/amplitude-2.1.0-min.js',
#  'cloudfront.wanderio.com/client/ProductsPage-7579d407b8ee37f8ceb8.js',
#  'mundoseo.com.br/',
#  'mundoseo.com.br/wp-includes/js/jquery/jquery-migrate.min.js',
#  'mundoseo.com.br/wp-includes/js/wp-emoji-release.min.js',
#  'www.gstatic.com/recaptcha/api2/v1529908317173/recaptcha__en.js',
#  'maps.gstatic.com/maps-api-v3/embed/js/33/5/intl/pt_br/init_embed.js',
#  'maps.googleapis.com/maps-api-v3/api/js/33/5/intl/pt_br/common.js',
#  'maps.googleapis.com/maps-api-v3/api/js/33/5/intl/pt_br/util.js',
#  'www.careerwebsite.com/distrib/jobs/widget.js',
#  'www.digitalanalyticsassociation.org/js/doubletaptogo.min.js',
#  'js.hscollectedforms.net/collectedforms.js',
#  'www.digitalanalyticsassociation.org/',
#  'script.hotjar.com/modules-b909a0a0c35c91be4150585a8f64f593.js',
#  'js.hs-analytics.net/analytics/1530658500000/1718033.js',
#  'pagead2.googlesyndication.com/pagead/js/r20180627/r20180604/show_ads_impl.js',
#  'googleads.g.doubleclick.net/pagead/html/r20180627/r20180604/zrt_lookup.html',
#  'tpc.googlesyndication.com/pagead/js/r20180627/r20110914/abg_lite.js',
#  'tpc.googlesyndication.com/pagead/js/r20180627/r20110914/activeview/osd_listener.js',
#  'stats.wp.com/e-201827.js',
#  'pagead2.googlesyndication.com/pub-config/r20160913/ca-pub-8725917246886629.js',
#  'latestmobileplans.com/wp-content/cache/autoptimize/js/autoptimize_171b49e98137c3674c72178e36f3ad63.js',
#  'pagead2.googlesyndication.com/pagead/js/r20180627/r20180604/osd.js',
#  'latestmobileplans.com/wp-includes/js/wp-emoji-release.min.js',
#  'pagead2.googlesyndication.com/pagead/js/r20180627/r20180604/rum.js',
#  'tpc.googlesyndication.com/pagead/js/r20180627/r20110914/rum.js',
#  'pagead2.googlesyndication.com/bg/9aks9_ZJAlgXRwnnYqgl737mC-ILDd-Q7GHg10j5JC8.js',
#  'www.joegage.com/',
#  'www.joegage.com/wp-includes/js/wp-embed.min.js',
#  'www.joegage.com/wp-includes/js/wp-emoji-release.min.js',
#  'www.edgenuity.com/wp-content/themes/html5blank-stable/js/lib/modernizr-2.7.1.min.js',
#  'www.edgenuity.com/wp-includes/js/wp-embed.min.js',
#  'app.cdn.lookbookhq.com/production/jukebox/current/jukebox.js',
#  'maps.gstatic.com/maps-api-v3/embed/js/33/5/init_embed.js',
#  'rum-static.pingdom.net/pa-5abd39c74c40770007000562.js',
#  'jukebox.lookbookhq.com/cookie-iframe.html',
#  'home.pandorabots.com/lib/require.js',
#  'home.pandorabots.com/lib/ace/ace.js',
#  'home.pandorabots.com/lib/jquery.history.js',
#  'home.pandorabots.com/lib/jQuery-File-Upload/js/jquery.fileupload.js',
#  'home.pandorabots.com/lib/jquery.cookie.js',
#  'www.wanderio.com/',
#  'cloudfront.wanderio.com/client/vendor-dc34ae1d84546327e479.js',
#  'cloudfront.wanderio.com/client/main-e14039d68970e22a8a29.js',
#  'cloudfront.wanderio.com/client/LandingPage-54ecef370ffe476553d0.js',
#  'd24n15hnbwhuhn.cloudfront.net/libs/amplitude-2.1.0-min.js',
#  'cloudfront.wanderio.com/client/ProductsPage-7579d407b8ee37f8ceb8.js',
#  'mundoseo.com.br/',
#  'mundoseo.com.br/wp-includes/js/jquery/jquery-migrate.min.js',
#  'mundoseo.com.br/wp-includes/js/wp-emoji-release.min.js',
#  'www.gstatic.com/recaptcha/api2/v1529908317173/recaptcha__en.js',
#  'maps.gstatic.com/maps-api-v3/embed/js/33/5/intl/pt_br/init_embed.js',
#  'maps.googleapis.com/maps-api-v3/api/js/33/5/intl/pt_br/common.js',
#  'maps.googleapis.com/maps-api-v3/api/js/33/5/intl/pt_br/util.js',
#  'www.careerwebsite.com/distrib/jobs/widget.js',
#  'www.digitalanalyticsassociation.org/js/doubletaptogo.min.js',
#  'js.hscollectedforms.net/collectedforms.js',
#  'www.digitalanalyticsassociation.org/',
#  'script.hotjar.com/modules-b909a0a0c35c91be4150585a8f64f593.js',
#  'js.hs-analytics.net/analytics/1530658500000/1718033.js',
#  'pagead2.googlesyndication.com/pagead/js/r20180627/r20180604/show_ads_impl.js',
#  'googleads.g.doubleclick.net/pagead/html/r20180627/r20180604/zrt_lookup.html',
#  'tpc.googlesyndication.com/pagead/js/r20180627/r20110914/abg_lite.js',
#  'tpc.googlesyndication.com/pagead/js/r20180627/r20110914/activeview/osd_listener.js',
#  'stats.wp.com/e-201827.js',
#  'pagead2.googlesyndication.com/pub-config/r20160913/ca-pub-8725917246886629.js',
#  'latestmobileplans.com/wp-content/cache/autoptimize/js/autoptimize_171b49e98137c3674c72178e36f3ad63.js',
#  'pagead2.googlesyndication.com/pagead/js/r20180627/r20180604/osd.js',
#  'latestmobileplans.com/wp-includes/js/wp-emoji-release.min.js',
#  'pagead2.googlesyndication.com/pagead/js/r20180627/r20180604/rum.js',
#  'tpc.googlesyndication.com/pagead/js/r20180627/r20110914/rum.js',
#  'pagead2.googlesyndication.com/bg/9aks9_ZJAlgXRwnnYqgl737mC-ILDd-Q7GHg10j5JC8.js',
#  'www.joegage.com/',
#  'www.joegage.com/wp-includes/js/wp-embed.min.js',
#  'www.joegage.com/wp-includes/js/wp-emoji-release.min.js']

# %%
def write_feats_to_json(script_features,
                       sorted_feature_list,
                       high_level_feat_dict,
                       script_ranks,
                       overall_script_ranks,
                       out_json):
    with open("high_level_feat_dict.json", "w") as outfile:
        json.dump(high_level_feat_dict, outfile, indent=4, sort_keys=False, cls=SetEncoder)
        
class SetEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, set):
            return list(obj)
        return json.JSONEncoder.default(self, obj)

# %%
write_feats_to_json(g_SCRIPT_FEATURES,
                       g_sorted_feature_list,
                       g_high_level_feat_dict,
                       g_script_ranks,
                       g_overall_script_ranks,
                       out_csv)

# %%
# Out:
# <class 'str'>
# <class 'list'>
# False
# du kannst nicht coden

# %%
# Out:
# ['["http://target.com"',
#  ' "http://google.com.co"',
#  ' "http://nih.gov"',
#  ' "http://reimageplus.com"',
#  ' "http://softonic.com"',
#  ' "http://tripadvisor.com"',
#  ' "http://vimeo.com"',
#  ' "http://hclips.com"',
#  ' "http://daum.net"',
#  ' "http://youm7.com"',
#  ' "http://ikea.com"',
#  ' "http://feedly.com"',
#  ' "http://zol.com.cn"',
#  ' "http://orange.fr"',
#  ' "http://google.cn"',
#  ' "http://tribunnews.com"',
#  ' "http://9gag.com"',
#  ' "http://google.com.sg"',
#  ' "http://force.com"',
#  ' "http://babytree.com"',
#  ' "http://google.ro"',
#  ' "http://web.de"',
#  ' "http://steamcommunity.com"',
#  ' "http://espncricinfo.com"',
#  ' "http://gmx.net"',
#  ' "http://comcast.net"',
#  ' "http://americanexpress.com"',
#  ' "http://google.be"',
#  ' "http://allegro.pl"',
#  ' "http://steampowered.com"',
#  ' "http://udn.com"',
#  ' "http://about.com"',
#  ' "http://wikihow.com"',
#  ' "http://gamer.com.tw"',
#  ' "http://google.com.ph"',
#  ' "http://wix.com"',
#  ' "http://mozilla.org"',
#  ' "http://w3schools.com"',
#  ' "http://livejournal.com"',
#  ' "http://skype.com"',
#  ' "http://hdfcbank.com"',
#  ' "http://bestbuy.com"',
#  ' "http://usps.com"',
#  ' "http://nametests.com"',
#  ' "http://xuite.net"',
#  ' "http://homedepot.com"',
#  ' "http://shutterstock.com"',
#  ' "http://capitalone.com"',
#  ' "http://onet.pl"',
#  ' "http://businessinsider.com"',
#  ' "http://xywy.com"',
#  ' "http://groupon.com"',
#  ' "http://deviantart.com"',
#  ' "http://google.at"',
#  ' "http://hulu.com"',
#  ' "http://ndtv.com"',
#  ' "http://speedtest.net"',
#  ' "http://slickdeals.net"',
#  ' "http://bitauto.com"',
#  ' "http://files.wordpress.com"',
#  ' "http://xfinity.com"',
#  ' "http://bet365.com"',
#  ' "http://rambler.ru"',
#  ' "http://blastingnews.com"',
#  ' "http://mega.nz"',
#  ' "http://wikimedia.org"',
#  ' "http://t-online.de"',
#  ' "http://amazon.es"',
#  ' "http://weebly.com"',
#  ' "http://icicibank.com"',
#  ' "http://pandora.com"',
#  ' "http://archive.org"',
#  ' "http://huanqiu.com"',
#  ' "http://seznam.cz"',
#  ' "http://google.co.ve"',
#  ' "http://blog.jp"',
#  ' "http://google.se"',
#  ' "http://wordpress.org"',
#  ' "http://goodreads.com"',
#  ' "http://liputan6.com"',
#  ' "http://spotify.com"',
#  ' "http://samsung.com"',
#  ' "http://eksisozluk.com"',
#  ' "http://ups.com"',
#  ' "http://google.pt"',
#  ' "http://wp.pl"',
#  ' "http://terraclicks.com"',
#  ' "http://google.ae"',
#  ' "http://google.ch"',
#  ' "http://mama.cn"',
#  ' "http://hp.com"',
#  ' "http://usatoday.com"',
#  ' "http://1905.com"',
#  ' "http://webmd.com"',
#  ' "http://sberbank.ru"',
#  ' "http://popcash.net"',
#  ' "http://kaskus.co.id"',
#  ' "http://onedio.com"',
#  ' "http://fedex.com"',
#  ' "http://rediff.com"',
#  ' "http://google.dz"',
#  ' "http://telegraph.co.uk"',
#  ' "http://cnnic.cn"',
#  ' "http://2ch.net"',
#  ' "http://thesaurus.com"',
#  ' "http://google.co.il"',
#  ' "http://sourceforge.net"',
#  ' "http://ltn.com.tw"',
#  ' "http://gsmarena.com"',
#  ' "http://addthis.com"',
#  ' "http://siteadvisor.com"',
#  ' "http://mashable.com"',
#  ' "http://google.hu"',
#  ' "http://att.com"',
#  ' "http://milliyet.com.tr"',
#  ' "http://bloomberg.com"',
#  ' "http://dell.com"',
#  ' "http://google.cz"',
#  ' "http://mailchimp.com"',
#  ' "http://icloud.com"',
#  ' "http://zendesk.com"',
#  ' "http://gizmodo.com"',
#  ' "http://kompas.com"',
#  ' "http://sabah.com.tr"',
#  ' "http://mystart.com"',
#  ' "http://chaturbate.com"',
#  ' "http://hurriyet.com.tr"',
#  ' "http://verizonwireless.com"',
#  ' "http://media.tumblr.com"',
#  ' "http://trello.com"',
#  ' "http://google.ie"',
#  ' "http://irctc.co.in"',
#  ' "http://paytm.com"',
#  ' "http://merdeka.com"',
#  ' "http://badoo.com"',
#  ' "http://medium.com"',
#  ' "http://google.cl"',
#  ' "http://impress.co.jp"',
#  ' "http://slack.com"',
#  ' "http://eastday.com"',
#  ' "http://livejasmin.com"',
#  ' "http://bukalapak.com"',
#  ' "http://enet.com.cn"',
#  ' "http://doublepimp.com"',
#  ' "http://oracle.com"',
#  ' "http://blogfa.com"',
#  ' "http://varzesh3.com"',
#  ' "http://wsj.com"',
#  ' "http://blackboard.com"',
#  ' "http://ign.com"',
#  ' "http://yandex.ua"',
#  ' "http://dmm.com"',
#  ' "http://pinimg.com"',
#  ' "http://savefrom.net"',
#  ' "http://macys.com"',
#  ' "http://irs.gov"',
#  ' "http://reuters.com"',
#  ' "http://taleo.net"',
#  ' "http://giphy.com"',
#  ' "http://evernote.com"',
#  ' "http://tube8.com"',
#  ' "http://ebay.in"',
#  ' "http://avg.com"',
#  ' "http://expedia.com"',
#  ' "http://eyny.com"',
#  ' "http://hootsuite.com"',
#  ' "http://kinopoisk.ru"',
#  ' "http://bhaskar.com"',
#  ' "http://libero.it"',
#  ' "http://livedoor.com"',
#  ' "http://airbnb.com"',
#  ' "http://engadget.com"',
#  ' "http://amazon.ca"',
#  ' "http://spiegel.de"',
#  ' "http://mi.com"',
#  ' "http://instructure.com"',
#  ' "http://kohls.com"',
#  ' "http://bild.de"',
#  ' "http://urdupoint.com"',
#  ' "http://jabong.com"',
#  ' "http://google.fi"',
#  ' "http://google.sk"',
#  ' "http://scribd.com"',
#  ' "http://realtor.com"',
#  ' "http://haber7.com"',
#  ' "http://google.no"',
#  ' "http://infusionsoft.com"',
#  ' "http://ebay.it"',
#  ' "http://box.com"',
#  ' "http://shopify.com"',
#  ' "http://newegg.com"',
#  ' "http://thefreedictionary.com"',
#  ' "http://mobile.de"',
#  ' "http://tistory.com"',
#  ' "http://stumbleupon.com"',
#  ' "http://4shared.com"',
#  ' "http://tabelog.com"',
#  ' "http://playstation.com"',
#  ' "http://google.dk"',
#  ' "http://quikr.com"',
#  ' "http://ancestry.com"',
#  ' "http://lifehacker.com"',
#  ' "http://surveymonkey.com"',
#  ' "http://battle.net"',
#  ' "http://gearbest.com"',
#  ' "http://roblox.com"',
#  ' "http://freepik.com"',
#  ' "http://patch.com"',
#  ' "http://friv.com"',
#  ' "http://list-manage.com"',
#  ' "http://yallakora.com"',
#  ' "http://58.com"',
#  ' "http://free.fr"',
#  ' "http://shopclues.com"',
#  ' "http://nbcnews.com"',
#  ' "http://elpais.com"',
#  ' "http://fidelity.com"',
#  ' "http://baike.com"',
#  ' "http://repubblica.it"',
#  ' "http://asos.com"',
#  ' "http://discovercard.com"',
#  ' "http://rbc.ru"',
#  ' "http://google.az"',
#  ' "http://allrecipes.com"',
#  ' "http://npr.org"',
#  ' "http://messenger.com"',
#  ' "http://gap.com"',
#  ' "http://hespress.com"',
#  ' "http://youdao.com"',
#  ' "http://bleacherreport.com"',
#  ' "http://theverge.com"',
#  ' "http://billdesk.com"',
#  ' "http://wunderground.com"',
#  ' "http://rutracker.org"',
#  ' "http://meetup.com"',
#  ' "http://fiverr.com"',
#  ' "http://aparat.com"',
#  ' "http://nifty.com"',
#  ' "http://hatena.ne.jp"',
#  ' "http://xe.com"',
#  ' "http://answers.com"',
#  ' "http://ca.gov"',
#  ' "http://marca.com"',
#  ' "http://teepr.com"',
#  ' "http://ebay.com.au"',
#  ' "http://hotels.com"',
#  ' "http://lifebuzz.com"',
#  ' "http://goal.com"',
#  ' "http://woot.com"',
#  ' "http://retailmenot.com"',
#  ' "http://kickstarter.com"',
#  ' "http://albawabhnews.com"',
#  ' "http://politico.com"',
#  ' "http://southwest.com"',
#  ' "http://xunlei.com"',
#  ' "http://olx.in"',
#  ' "http://exoclick.com"',
#  ' "http://wayfair.com"',
#  ' "http://hdzog.com"',
#  ' "http://chip.de"',
#  ' "http://hotstar.com"',
#  ' "http://verizon.com"',
#  ' "http://vid.me"',
#  ' "http://photobucket.com"',
#  ' "http://ask.fm"',
#  ' "http://india.com"',
#  ' "http://cnblogs.com"',
#  ' "http://seesaa.net"',
#  ' "http://nba.com"',
#  ' "http://airtel.in"',
#  ' "http://ero-advertising.com"',
#  ' "http://indianexpress.com"',
#  ' "http://xda-developers.com"',
#  ' "http://nordstrom.com"',
#  ' "http://kooora.com"',
#  ' "http://ebates.com"',
#  ' "http://udemy.com"',
#  ' "http://jimdo.com"',
#  ' "http://zippyshare.com"',
#  ' "http://okezone.com"',
#  ' "http://lenovo.com"',
#  ' "http://kayak.com"',
#  ' "http://so-net.ne.jp"',
#  ' "http://drudgereport.com"',
#  ' "http://reference.com"',
#  ' "http://sh.st"',
#  ' "http://squarespace.com"',
#  ' "http://adcash.com"',
#  ' "http://gamefaqs.com"',
#  ' "http://mercadolibre.com.ar"',
#  ' "http://yandex.com.tr"',
#  ' "http://worldlifestyle.com"',
#  ' "http://uploaded.net"',
#  ' "http://biglobe.ne.jp"',
#  ' "http://kijiji.ca"',
#  ' "http://liveinternet.ru"',
#  ' "http://independent.co.uk"',
#  ' "http://moneycontrol.com"',
#  ' "http://hatenablog.com"',
#  ' "http://sabq.org"',
#  ' "http://wikiwiki.jp"',
#  ' "http://meaww.com"',
#  ' "http://intoday.in"',
#  ' "http://adp.com"',
#  ' "http://souq.com"',
#  ' "http://zulily.com"',
#  ' "http://overstock.com"',
#  ' "http://sakura.ne.jp"',
#  ' "http://abcnews.go.com"',
#  ' "http://google.com.vn"',
#  ' "http://beeg.com"',
#  ' "http://tsite.jp"',
#  ' "http://zoho.com"',
#  ' "http://latimes.com"',
#  ' "http://clipconverter.cc"',
#  ' "http://tutorialspoint.com"',
#  ' "http://myfitnesspal.com"',
#  ' "http://quizlet.com"',
#  ' "http://slate.com"',
#  ' "http://elmundo.es"',
#  ' "http://leagueoflegends.com"',
#  ' "http://cbsnews.com"',
#  ' "http://oeeee.com"',
#  ' "http://telegram.org"',
#  ' "http://104.com.tw"',
#  ' "http://people.com"',
#  ' "http://upwork.com"',
#  ' "http://java.com"',
#  ' "http://fitbit.com"',
#  ' "http://ensonhaber.com"',
#  ' "http://eventbrite.com"',
#  ' "http://makemytrip.com"',
#  ' "http://disqus.com"',
#  ' "http://usaa.com"',
#  ' "http://instructables.com"',
#  ' "http://time.com"',
#  ' "http://timeanddate.com"',
#  ' "http://cookpad.com"',
#  ' "http://4dsply.com"',
#  ' "http://mydala.com"',
#  ' "http://thekitchn.com"',
#  ' "http://mackolik.com"',
#  ' "http://aa.com"',
#  ' "http://jrj.com.cn"',
#  ' "http://livescore.com"',
#  ' "http://glassdoor.com"',
#  ' "http://subito.it"',
#  ' "http://infoseek.co.jp"',
#  ' "http://myway.com"',
#  ' "http://google.com.my"',
#  ' "http://chinaso.com"',
#  ' "http://urbandictionary.com"',
#  ' "http://mixi.jp"',
#  ' "http://google.bg"',
#  ' "http://ibm.com"',
#  ' "http://delta.com"',
#  ' "http://custhelp.com"',
#  ' "http://researchgate.net"',
#  ' "http://manoramaonline.com"',
#  ' "http://asana.com"',
#  ' "http://google.lk"',
#  ' "http://www.gov.uk"',
#  ' "http://lenta.ru"',
#  ' "http://yandex.kz"',
#  ' "http://investing.com"',
#  ' "http://fivethirtyeight.com"',
#  ' "http://twoo.com"',
#  ' "http://constantcontact.com"',
#  ' "http://nikkeibp.co.jp"',
#  ' "http://agar.io"',
#  ' "http://shaparak.ir"',
#  ' "http://change.org"',
#  ' "http://bhphotovideo.com"',
#  ' "http://issuu.com"',
#  ' "http://interia.pl"',
#  ' "http://prezi.com"',
#  ' "http://cbssports.com"',
#  ' "http://wetransfer.com"',
#  ' "http://slimspots.com"',
#  ' "http://weblio.jp"',
#  ' "http://agoda.com"',
#  ' "http://google.kz"',
#  ' "http://mlb.com"',
#  ' "http://gamersky.com"',
#  ' "http://zhaopin.com"',
#  ' "http://sciencedirect.com"',
#  ' "http://fanpage.gr"',
#  ' "http://pch.com"',
#  ' "http://reverso.net"',
#  ' "http://kdnet.net"',
#  ' "http://norton.com"',
#  ' "http://coursera.org"',
#  ' "http://google.com.kw"',
#  ' "http://mcafee.com"',
#  ' "http://tmz.com"',
#  ' "http://eonline.com"',
#  ' "http://6pm.com"',
#  ' "http://usbank.com"',
#  ' "http://ero-video.net"',
#  ' "http://gmarket.co.kr"',
#  ' "http://openload.co"',
#  ' "http://cisco.com"',
#  ' "http://abplive.in"',
#  ' "http://pof.com"',
#  ' "http://eastmoney.com"',
#  ' "http://atwiki.jp"',
#  ' "http://corriere.it"',
#  ' "http://rightmove.co.uk"',
#  ' "http://webex.com"',
#  ' "http://swagbucks.com"',
#  ' "http://academia.edu"',
#  ' "http://techcrunch.com"',
#  ' "http://mynavi.jp"',
#  ' "http://life.tw"',
#  ' "http://google.rs"',
#  ' "http://filehippo.com"',
#  ' "http://clien.net"',
#  ' "http://mit.edu"',
#  ' "http://okcupid.com"',
#  ' "http://sears.com"',
#  ' "http://wp.com"',
#  ' "http://prpops.com"',
#  ' "http://nypost.com"',
#  ' "http://foodnetwork.com"',
#  ' "http://faithtap.com"',
#  ' "http://popsugar.com"',
#  ' "http://cnbc.com"',
#  ' "http://nydailynews.com"',
#  ' "http://chron.com"',
#  ' "http://yadi.sk"',
#  ' "http://gigazine.net"',
#  ' "http://ouo.io"',
#  ' "http://google.by"',
#  ' "http://yaolan.com"',
#  ' "http://thehindu.com"',
#  ' "http://seasonvar.ru"',
#  ' "http://behance.net"',
#  ' "http://gismeteo.ru"',
#  ' "http://superuser.com"',
#  ' "http://howtogeek.com"',
#  ' "http://jcpenney.com"',
#  ' "http://gamepedia.com"',
#  ' "http://google.co.nz"',
#  ' "http://pcmag.com"',
#  ' "http://atlassian.net"',
#  ' "http://y8.com"',
#  ' "http://yandex.by"',
#  ' "http://google.com.bd"',
#  ' "http://gutefrage.net"',
#  ' "http://commentcamarche.net"',
#  ' "http://ebay.fr"',
#  ' "http://suning.com"',
#  ' "http://bomb01.com"',
#  ' "http://126.com"',
#  ' "http://duckduckgo.com"',
#  ' "http://wattpad.com"',
#  ' "http://bodybuilding.com"',
#  ' "http://biobiochile.cl"',
#  ' "http://exblog.jp"',
#  ' "http://123rf.com"',
#  ' "http://priceline.com"',
#  ' "http://mirror.co.uk"',
#  ' "http://gawker.com"',
#  ' "http://neobux.com"',
#  ' "http://abril.com.br"',
#  ' "http://gyazo.com"',
#  ' "http://gazetaexpress.com"',
#  ' "http://php.net"',
#  ' "http://bt.com"',
#  ' "http://huaban.com"',
#  ' "http://e-hentai.org"',
#  ' "http://wish.com"',
#  ' "http://inquirer.net"',
#  ' "http://yomiuri.co.jp"',
#  ' "http://europa.eu"',
#  ' "http://thedailybeast.com"',
#  ' "http://merriam-webster.com"',
#  ' "http://buy.tmall.com"',
#  ' "http://shareasale.com"',
#  ' "http://google.hr"',
#  ' "http://wiktionary.org"',
#  ' "http://carview.co.jp"',
#  ' "http://zara.com"',
#  ' "http://yenisafak.com"',
#  ' "http://mayoclinic.org"',
#  ' "http://vetogate.com"',
#  ' "http://googleadservices.com"',
#  ' "http://cdiscount.com"',
#  ' "http://realclearpolitics.com"',
#  ' "http://3dmgame.com"',
#  ' "http://lun.com"',
#  ' "http://investopedia.com"',
#  ' "http://4399.com"',
#  ' "http://sfr.fr"',
#  ' "http://mapquest.com"',
#  ' "http://codecanyon.net"',
#  ' "http://android.com"',
#  ' "http://google.com.do"',
#  ' "http://wired.com"',
#  ' "http://gmanetwork.com"',
#  ' "http://hotnewhiphop.com"',
#  ' "http://4pda.ru"',
#  ' "http://hilton.com"',
#  ' "http://google.com.ec"',
#  ' "http://elmogaz.com"',
#  ' "http://goo.gl"',
#  ' "http://getpocket.com"',
#  ' "http://weather.gov"',
#  ' "http://xbox.com"',
#  ' "http://ria.ru"',
#  ' "http://himado.in"',
#  ' "http://appledaily.com.tw"',
#  ' "http://milanuncios.com"',
#  ' "http://zappos.com"',
#  ' "http://bestadbid.com"',
#  ' "http://marriott.com"',
#  ' "http://sky.com"',
#  ' "http://otto.de"',
#  ' "http://internethaber.com"',
#  ' "http://ted.com"',
#  ' "http://redfin.com"',
#  ' "http://marketwatch.com"',
#  ' "http://rollingstone.com"',
#  ' "http://mercadolibre.com.mx"',
#  ' "http://youjizz.com"',
#  ' "http://dianping.com"',
#  ' "http://ew.com"',
#  ' "http://whitepages.com"',
#  ' "http://sankei.com"',
#  ' "http://hostgator.com"',
#  ' "http://kotaku.com"',
#  ' "http://gazeta.pl"',
#  ' "http://babycenter.com"',
#  ' "http://focus.de"',
#  ' "http://intel.com"',
#  ' "http://livestrong.com"',
#  ' "http://informer.com"',
#  ' "http://vox.com"',
#  ' "http://homepage-web.com"',
#  ' "http://novinky.cz"',
#  ' "http://11st.co.kr"',
#  ' "http://as.com"',
#  ' "http://nhl.com"',
#  ' "http://uzone.id"',
#  ' "http://lapatilla.com"',
#  ' "http://jin115.com"',
#  ' "http://wav.tv"',
#  ' "http://voyeurhit.com"',
#  ' "http://duolingo.com"',
#  ' "http://ukr.net"',
#  ' "http://legacy.com"',
#  ' "http://theatlantic.com"',
#  ' "http://excite.co.jp"',
#  ' "http://panasonic.jp"',
#  ' "http://pbs.org"',
#  ' "http://fatosdesconhecidos.com.br"',
#  ' "http://state.gov"',
#  ' "http://breitbart.com"',
#  ' "http://4chan.org"',
#  ' "http://dailypakistan.com.pk"',
#  ' "http://google.lt"',
#  ' "http://rapidgator.net"',
#  ' "http://wiley.com"',
#  ' "http://backpage.com"',
#  ' "http://hh.ru"',
#  ' "http://tomshardware.com"',
#  ' "http://primewire.ag"',
#  ' "http://pole-emploi.fr"',
#  ' "http://cbs.com"',
#  ' "http://ccm.net"',
#  ' "http://aweber.com"',
#  ' "http://auto.ru"',
#  ' "http://dmv.org"',
#  ' "http://mihanblog.com"',
#  ' "http://dafont.com"',
#  ' "http://creditkarma.com"',
#  ' "http://leadzupc.com"',
#  ' "http://walgreens.com"',
#  ' "http://credit-agricole.fr"',
#  ' "http://sfgate.com"',
#  ' "http://mynet.com"',
#  ' "http://cda.pl"',
#  ' "http://hubspot.com"',
#  ' "http://pnc.com"',
#  ' "http://match.com"',
#  ' "http://mega.co.nz"',
#  ' "http://cracked.com"',
#  ' "http://line.me"',
#  ' "http://ecnavi.jp"',
#  ' "http://marktplaats.nl"',
#  ' "http://zougla.gr"',
#  ' "http://rarbg.to"',
#  ' "http://lequipe.fr"',
#  ' "http://banggood.com"',
#  ' "http://ryanair.com"',
#  ' "http://ecollege.com"',
#  ' "http://deezer.com"',
#  ' "http://nairaland.com"',
#  ' "http://gittigidiyor.com"',
#  ' "http://o2.pl"',
#  ' "http://duba.com"',
#  ' "http://basecamp.com"',
#  ' "http://bitly.com"',
#  ' "http://caixa.gov.br"',
#  ' "http://yellowpages.com"',
#  ' "http://springer.com"',
#  ' "http://hepsiburada.com"',
#  ' "http://lemonde.fr"',
#  ' "http://114la.com"',
#  ' "http://bitbucket.org"',
#  ' "http://yjc.ir"',
#  ' "http://pretty52.com"',
#  ' "http://mbc.net"',
#  ' "http://allocine.fr"',
#  ' "http://monster.com"',
#  ' "http://disq.us"',
#  ' "http://histats.com"',
#  ' "http://acunn.com"',
#  ' "http://biblegateway.com"',
#  ' "http://hamariweb.com"',
#  ' "http://office365.com"',
#  ' "http://androidcentral.com"',
#  ' "http://haberturk.com"',
#  ' "http://dreamstime.com"',
#  ' "http://harvard.edu"',
#  ' "http://mysmartprice.com"',
#  ' "http://immobilienscout24.de"',
#  ' "http://apache.org"',
#  ' "http://statcounter.com"',
#  ' "http://mint.com"',
#  ' "http://klikbca.com"',
#  ' "http://mercadolibre.com.ve"',
#  ' "http://fanli.com"',
#  ' "http://nfl.com"',
#  ' "http://qvc.com"',
#  ' "http://clarin.com"',
#  ' "http://etao.com"',
#  ' "http://express.pk"',
#  ' "http://saramin.co.kr"',
#  ' "http://drive2.ru"',
#  ' "http://askubuntu.com"',
#  ' "http://lefigaro.fr"',
#  ' "http://stanford.edu"',
#  ' "http://garmin.com"',
#  ' "http://6park.com"',
#  ' "http://tabnak.ir"',
#  ' "http://thisav.com"',
#  ' "http://digitaltrends.com"',
#  ' "http://labanquepostale.fr"',
#  ' "http://oneindia.com"',
#  ' "http://jagran.com"',
#  ' "http://techradar.com"',
#  ' "http://rakuten-card.co.jp"',
#  ' "http://donga.com"',
#  ' "http://sopitas.com"',
#  ' "http://idnes.cz"',
#  ' "http://pagesjaunes.fr"',
#  ' "http://gofundme.com"',
#  ' "http://onliner.by"',
#  ' "http://chouftv.ma"',
#  ' "http://ehow.com"',
#  ' "http://tnaflix.com"',
#  ' "http://ozon.ru"',
#  ' "http://schwab.com"',
#  ' "http://gazzetta.it"',
#  ' "http://prothom-alo.com"',
#  ' "http://javedch.com"',
#  ' "http://lloydsbank.co.uk"',
#  ' "http://fishki.net"',
#  ' "http://pogo.com"',
#  ' "http://uptobox.com"',
#  ' "http://jezebel.com"',
#  ' "http://canva.com"',
#  ' "http://genius.com"',
#  ' "http://folha.uol.com.br"',
#  ' "http://khanacademy.org"',
#  ' "http://blog.me"',
#  ' "http://sephora.com"',
#  ' "http://deadspin.com"',
#  ' "http://plarium.com"',
#  ' "http://commbank.com.au"',
#  ' "http://cambridge.org"',
#  ' "http://telegram.me"',
#  ' "http://sony.jp"',
#  ' "http://tripadvisor.co.uk"',
#  ' "http://forever21.com"',
#  ' "http://discover.com"',
#  ' "http://nexusmods.com"',
#  ' "http://fang.com"',
#  ' "http://cbc.ca"',
#  ' "http://jumia.com.ng"',
#  ' "http://istockphoto.com"',
#  ' "http://sindonews.com"',
#  ' "http://dostor.org"',
#  ' "http://makeuseof.com"',
#  ' "http://drtuber.com"',
#  ' "http://jalan.net"',
#  ' "http://ctrip.com"',
#  ' "http://wargaming.net"',
#  ' "http://ebay.ca"',
#  ' "http://panda.tv"',
#  ' "http://ascii.jp"',
#  ' "http://wiocha.pl"',
#  ' "http://takungpao.com"',
#  ' "http://lynda.com"',
#  ' "http://liveleak.com"',
#  ' "http://toysrus.com"',
#  ' "http://tattoodo.com"',
#  ' "http://donanimhaber.com"',
#  ' "http://sapo.pt"',
#  ' "http://dailykos.com"',
#  ' "http://clixsense.com"',
#  ' "http://elevenia.co.id"',
#  ' "http://tgbus.com"',
#  ' "http://truecaller.com"',
#  ' "http://xing.com"',
#  ' "http://entrepreneur.com"',
#  ' "http://finn.no"',
#  ' "http://arstechnica.com"',
#  ' "http://keepvid.com"',
#  ' "http://nasa.gov"',
#  ' "http://avito.ma"',
#  ' "http://fandango.com"',
#  ' "http://1337x.to"',
#  ' "http://efukt.com"',
#  ' "http://yaplakal.com"',
#  ' "http://r10.net"',
#  ' "http://duowan.com"',
#  ' "http://ebay.es"',
#  ' "http://battlefield.com"',
#  ' "http://today.com"',
#  ' "http://royalbank.com"',
#  ' "http://gongchang.com"',
#  ' "http://panet.co.il"',
#  ' "http://lanacion.com.ar"',
#  ' "http://hindustantimes.com"',
#  ' "http://bidvertiser.com"',
#  ' "http://gumtree.com.au"',
#  ' "http://shutterfly.com"',
#  ' "http://firstpost.com"',
#  ' "http://movie4k.to"',
#  ' "http://usmagazine.com"',
#  ' "http://mackeeper.com"',
#  ' "http://myfreecams.com"',
#  ' "http://scoop.it"',
#  ' "http://disney.go.com"',
#  ' "http://what-character-are-you.com"',
#  ' "http://skysports.com"',
#  ' "http://tagged.com"',
#  ' "http://tesco.com"',
#  ' "http://rozblog.com"',
#  ' "http://ccb.com"',
#  ' "http://bluehost.com"',
#  ' "http://dict.cc"',
#  ' "http://garanti.com.tr"',
#  ' "http://porn.com"',
#  ' "http://google.tn"',
#  ' "http://autotrader.com"',
#  ' "http://salon.com"',
#  ' "http://cvs.com"',
#  ' "http://cbslocal.com"',
#  ' "http://nextdoor.com"',
#  ' "http://google.si"',
#  ' "http://icims.com"',
#  ' "http://telekom.com"',
#  ' "http://givemesport.com"',
#  ' "http://capitalone360.com"',
#  ' "http://elcomercio.pe"',
#  ' "http://iherb.com"',
#  ' "http://yahoo-mbga.jp"',
#  ' "http://deviantart.net"',
#  ' "http://gamewith.jp"',
#  ' "http://minecraft.net"',
#  ' "http://lockerdome.com"',
#  ' "http://foursquare.com"',
#  ' "http://dlsite.com"',
#  ' "http://feng.com"',
#  ' "http://chicagotribune.com"',
#  ' "http://barnesandnoble.com"',
#  ' "http://gotowebinar.com"',
#  ' "http://inc.com"',
#  ' "http://food.com"',
#  ' "http://olx.co.id"',
#  ' "http://wildberries.ru"',
#  ' "http://blog.ir"',
#  ' "http://discogs.com"',
#  ' "http://chefkoch.de"',
#  ' "http://jobrapido.com"',
#  ' "http://jw.org"',
#  ' "http://spankbang.com"',
#  ' "http://autoscout24.de"',
#  ' "http://auction.co.kr"',
#  ' "http://tut.by"',
#  ' "http://theblaze.com"',
#  ' "http://argos.co.uk"',
#  ' "http://topix.com"',
#  ' "http://bankrate.com"',
#  ' "http://tvguide.com"',
#  ' "http://mileroticos.com"',
#  ' "http://teamviewer.com"',
#  ' "http://nbcsports.com"',
#  ' "http://barclaycardus.com"',
#  ' "http://kizlarsoruyor.com"',
#  ' "http://hsbc.co.uk"',
#  ' "http://abc.go.com"',
#  ' "http://bookmyshow.com"',
#  ' "http://fortune.com"',
#  ' "http://lego.com"',
#  ' "http://haberler.com"',
#  ' "http://2gis.ru"',
#  ' "http://digg.com"',
#  ' "http://discuss.com.hk"',
#  ' "http://bahn.de"',
#  ' "http://ubi.com"',
#  ' "http://2ch-c.net"',
#  ' "http://drugs.com"',
#  ' "http://si.com"',
#  ' "http://privatbank.ua"',
#  ' "http://grammarly.com"',
#  ' "http://kizi.com"',
#  ' "http://leo.org"',
#  ' "http://welt.de"',
#  ' "http://thevideo.me"',
#  ' "http://vente-privee.com"',
#  ' "http://archiveofourown.org"',
#  ' "http://td.com"',
#  ' "http://kompasiana.com"',
#  ' "http://uniqlo.com"',
#  ' "http://fotostrana.ru"',
#  ' "http://adme.ru"',
#  ' "http://hollywoodreporter.com"',
#  ' "http://littlethings.com"',
#  ' "http://macrumors.com"',
#  ' "http://juksy.com"',
#  ' "http://postbank.de"',
#  ' "http://kinja.com"',
#  ' "http://patheos.com"',
#  ' "http://mediaset.it"',
#  ' "http://vrbo.com"',
#  ' "http://wunderlist.com"',
#  ' "http://alfalfalfa.com"',
#  ' "http://tunein.com"',
#  ' "http://pcworld.com"',
#  ' "http://news.com.au"',
#  ' "http://24h.com.vn"',
#  ' "http://bmi.ir"',
#  ' "http://engageya.com"',
#  ' "http://google.iq"',
#  ' "http://msnbc.com"',
#  ' "http://sprint.com"',
#  ' "http://autotrader.co.uk"',
#  ' "http://4gamer.net"',
#  ' "http://hibapress.com"',
#  ' "http://serverfault.com"',
#  ' "http://indiegogo.com"',
#  ' "http://rei.com"',
#  ' "http://dhgate.com"',
#  ' "http://virginmedia.com"',
#  ' "http://suara.com"',
#  ' "http://telegrafi.com"',
#  ' "http://ing.nl"',
#  ' "http://junbi-tracker.com"',
#  ' "http://facenama.com"',
#  ' "http://docin.com"',
#  ' "http://doodle.com"',
#  ' "http://foxsports.com"',
#  ' "http://super.cz"',
#  ' "http://pixabay.com"',
#  ' "http://okta.com"',
#  ' "http://gorillavid.in"',
#  ' "http://trafficserving.com"',
#  ' "http://nationalgeographic.com"',
#  ' "http://argaam.com"',
#  ' "http://voluumtrk.com"',
#  ' "http://ranker.com"',
#  ' "http://kbb.com"',
#  ' "http://ea.com"',
#  ' "http://1and1.com"',
#  ' "http://eenadu.net"',
#  ' "http://reallifecam.com"',
#  ' "http://convert2mp3.net"',
#  ' "http://ig.com.br"',
#  ' "http://gotomeeting.com"',
#  ' "http://gotporn.com"',
#  ' "http://vine.co"',
#  ' "http://asriran.com"',
#  ' "http://bustle.com"',
#  ' "http://cinemablend.com"',
#  ' "http://mail.com"',
#  ' "http://editor.wix.com"',
#  ' "http://eztv.ag"',
#  ' "http://daily.co.jp"',
#  ' "http://mediaplex.com"',
#  ' "http://fool.com"',
#  ' "http://psu.edu"',
#  ' "http://opentable.com"',
#  ' "http://videodownloadconverter.com"',
#  ' "http://turbobit.net"',
#  ' "http://digitalocean.com"',
#  ' "http://humblebundle.com"',
#  ' "http://indeed.co.uk"',
#  ' "http://mydrivers.com"',
#  ' "http://17track.net"',
#  ' "http://vistaprint.com"',
#  ' "http://cdc.gov"',
#  ' "http://newyorker.com"',
#  ' "http://typepad.com"',
#  ' "http://talk.tw"',
#  ' "http://directv.com"',
#  ' "http://seekingalpha.com"',
#  ' "http://renren.com"',
#  ' "http://id.net"',
#  ' "http://programme-tv.net"',
#  ' "http://mts.ru"',
#  ' "http://1111.com.tw"',
#  ' "http://gaana.com"',
#  ' "http://1und1.de"',
#  ' "http://kicker.de"',
#  ' "http://aftonbladet.se"',
#  ' "http://sitepoint.com"',
#  ' "http://dpreview.com"',
#  ' "http://infobae.com"',
#  ' "http://macromill.com"',
#  ' "http://ubuntu.com"',
#  ' "http://gamestop.com"',
#  ' "http://miniclip.com"',
#  ' "http://codeproject.com"',
#  ' "http://mainichi.jp"',
#  ' "http://dawn.com"',
#  ' "http://here.com"',
#  ' "http://fnb.co.za"',
#  ' "http://sbnation.com"',
#  ' "http://google.com.gt"',
#  ' "http://premierleague.com"',
#  ' "http://piriform.com"',
#  ' "http://jqw.com"',
#  ' "http://hubpages.com"',
#  ' "http://virgilio.it"',
#  ' "http://linternaute.com"',
#  ' "http://lg.com"',
#  ' "http://filmweb.pl"',
#  ' "http://ulmart.ru"',
#  ' "http://qz.com"',
#  ' "http://gazeta.ru"',
#  ' "http://autodesk.com"',
#  ' "http://abc.net.au"',
#  ' "http://shasha.ps"',
#  ' "http://itau.com.br"',
#  ' "http://allmyvideos.net"',
#  ' "http://edmunds.com"',
#  ' "http://xtube.com"',
#  ' "http://bab.la"',
#  ' "http://strava.com"',
#  ' "http://google.lv"',
#  ' "http://cars.com"',
#  ' "http://realestate.com.au"',
#  ' "http://crunchyroll.com"',
#  ' "http://nmisr.com"',
#  ' "http://am15.net"',
#  ' "http://wowhead.com"',
#  ' "http://ilmeteo.it"',
#  ' "http://berkeley.edu"',
#  ' "http://lightinthebox.com"',
#  ' "http://himasoku.com"',
#  ' "http://refinery29.com"',
#  ' "http://vg.no"',
#  ' "http://healthline.com"',
#  ' "http://smh.com.au"',
#  ' "http://baixaki.com.br"',
#  ' "http://idealo.de"',
#  ' "http://cnki.net"',
#  ' "http://paidverts.com"',
#  ' "http://poste.it"',
#  ' "http://brainyquote.com"',
#  ' "http://motherless.com"',
#  ' "http://sulekha.com"',
#  ' "http://10086.cn"',
#  ' "http://tomsguide.com"',
#  ' "http://aarp.org"',
#  ' "http://vanguard.com"',
#  ' "http://dhl.com"',
#  ' "http://epochtimes.com"',
#  ' "http://myanimelist.net"',
#  ' "http://softbank.jp"',
#  ' "http://purdue.edu"',
#  ' "http://metrolyrics.com"',
#  ' "http://getbootstrap.com"',
#  ' "http://timewarnercable.com"',
#  ' "http://thehill.com"',
#  ' "http://unity3d.com"',
#  ' "http://mirtesen.ru"',
#  ' "http://greatergood.com"',
#  ' "http://bb.com.br"',
#  ' "http://evite.com"',
#  ' "http://weheartit.com"',
#  ' "http://goodgamestudios.com"',
#  ' "http://bandcamp.com"',
#  ' "http://ali213.net"',
#  ' "http://bc.vc"',
#  ' "http://wnd.com"',
#  ...]

# %%
test=["www.instagram.com/static/bundles/base/Vendor.js/4f7146874e51.js","www.instagram.com/static/bundles/base/ConsumerCommons.js/865b8ab22627.js"]
for it in
